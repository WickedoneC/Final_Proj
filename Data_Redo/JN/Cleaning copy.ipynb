# %%
import pandas as pd

# %%
import numpy as np

# %%
df_to_clean = pd.read_csv('largers_messy.csv')

# %%
pd.set_option("display.max_rows", 100)

# %%
df_to_clean
# Out:
#       Unnamed: 0  Unnamed: 0_x               Issuer Currency   Coupon  Yield  \
# 0              0            44                AECOM      USD  5.1250%  4.21%
# 1              1            45                AECOM      USD  5.8750%  3.54%
# 2              2            49           AFLAC Inc.      USD  3.2500%  3.58%
# 3              3            50           AFLAC Inc.      USD  4.0000%  3.44%
# 4              4            51           AFLAC Inc.      USD  6.4500%      -
# ...          ...           ...                  ...      ...      ...    ...
# 6937        6937          6999            eBay Inc.      USD  4.0000%  4.16%
# 6938        6938          7000            eBay Inc.      USD  2.8750%  2.06%
# 6939        6939          7001            eBay Inc.      USD  2.6000%  2.27%
# 6940        6940          7003  salesforce.com Inc.      USD  3.7000%  2.39%
# 6941        6941          7004  salesforce.com Inc.      USD  3.2500%  1.98%
#
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Unnamed: 0                                           0
# Unnamed: 0_x                                         0
# Issuer                                               0
# Currency                                             0
# Coupon                                               0
# Yield                                                0
# Moody's Rating                                     597
# Maturity Date                                        8
# Bid                                                  0
# Ask                                                  0
# Names                                                0
# Ticker                                               0
# Name                                                 0
# Asset Class                                          0
# Weight (%)                                           0
# Price                                                0
# Shares                                               0
# ...

# %%
list(df_to_clean.columns)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 0_x',
#  'Issuer',
#  'Currency',
#  'Coupon',
#  'Yield',
#  "Moody's Rating",
#  'Maturity Date',
#  'Bid',
#  'Ask',
#  'Names',
#  'Ticker',
#  'Name',
#  'Asset Class',
#  'Weight (%)',
#  'Price',
#  'Shares',
#  'Market Value',
#  'Notional Value',
#  'Sector',
#  'SEDOL',
#  'ISIN',
#  'Exchange',
#  'Unnamed: 0_y',
#  'Market Cap (intraday) 5',
#  'Enterprise Value 3',
#  'Trailing P/E',
#  'Forward P/E 1',
#  'PEG Ratio (5 yr expected) 1',
#  'Price/Sales (ttm)',
#  'Price/Book (mrq)',
#  'Enterprise Value/Revenue 3',
#  'Enterprise Value/EBITDA 6',
#  'Beta (5Y Monthly)',
#  '52-Week Change 3',
#  'S&P500 52-Week Change 3',
#  '52 Week High 3',
#  '52 Week Low 3',
#  '50-Day Moving Average 3',
#  '200-Day Moving Average 3',
#  '% Held by Insiders 1',
#  '% Held by Institutions 1',
#  'Avg Vol (10 day) 3',
#  'Avg Vol (3 month) 3',
#  'Float',
#  'Shares Outstanding 5',
#  'Shares Short (Dec 30, 2019) 4',
#  'Shares Short (Feb 13, 2020) 4',
# ...

# %%
df_to_clean
# Out:
#       Unnamed: 0  Unnamed: 0_x               Issuer Currency   Coupon  Yield  \
# 0              0            44                AECOM      USD  5.1250%  4.21%
# 1              1            45                AECOM      USD  5.8750%  3.54%
# 2              2            49           AFLAC Inc.      USD  3.2500%  3.58%
# 3              3            50           AFLAC Inc.      USD  4.0000%  3.44%
# 4              4            51           AFLAC Inc.      USD  6.4500%      -
# ...          ...           ...                  ...      ...      ...    ...
# 6937        6937          6999            eBay Inc.      USD  4.0000%  4.16%
# 6938        6938          7000            eBay Inc.      USD  2.8750%  2.06%
# 6939        6939          7001            eBay Inc.      USD  2.6000%  2.27%
# 6940        6940          7003  salesforce.com Inc.      USD  3.7000%  2.39%
# 6941        6941          7004  salesforce.com Inc.      USD  3.2500%  1.98%
#
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6942 entries, 0 to 6941
# Data columns (total 99 columns):
# Unnamed: 0                                        6942 non-null int64
# Unnamed: 0_x                                      6942 non-null int64
# Issuer                                            6942 non-null object
# Currency                                          6942 non-null object
# Coupon                                            6942 non-null object
# Yield                                             6942 non-null object
# Moody's Rating                                    6345 non-null object
# Maturity Date                                     6934 non-null object
# Bid                                               6942 non-null object
# Ask                                               6942 non-null object
# Names                                             6942 non-null object
# Ticker                                            6942 non-null object
# ...

# %%
columns_to_drop = ['Shares Short (Dec 30, 2019) 4', 'Shares Short (Jan 14, 2020) 4', 'Shares Short (prior month ) 4',
                  'Shares Short (prior month Dec 12, 2019) 4', 'Shares Short (prior month Nov 28, 2019) 4', 'Shares Short 4', 
                   'Short % of Float (Dec 30, 2019) 4', 'Short % of Float (Jan 14, 2020) 4', 'Short % of Float 4', 
                  'Short % of Shares Outstanding (Dec 30, 2019) 4', 'Short % of Shares Outstanding (Jan 14, 2020) 4',
                  'Short % of Shares Outstanding 4', 'Short Ratio (Dec 30, 2019) 4', 'Short Ratio (Jan 14, 2020) 4', 
                  'Short Ratio 4']

# %%
df_to_clean = df_to_clean.drop(columns=columns_to_drop)

# %%
df_to_clean
# Out:
#       Unnamed: 0  Unnamed: 0_x               Issuer Currency   Coupon  Yield  \
# 0              0            44                AECOM      USD  5.1250%  4.21%
# 1              1            45                AECOM      USD  5.8750%  3.54%
# 2              2            49           AFLAC Inc.      USD  3.2500%  3.58%
# 3              3            50           AFLAC Inc.      USD  4.0000%  3.44%
# 4              4            51           AFLAC Inc.      USD  6.4500%      -
# ...          ...           ...                  ...      ...      ...    ...
# 6937        6937          6999            eBay Inc.      USD  4.0000%  4.16%
# 6938        6938          7000            eBay Inc.      USD  2.8750%  2.06%
# 6939        6939          7001            eBay Inc.      USD  2.6000%  2.27%
# 6940        6940          7003  salesforce.com Inc.      USD  3.7000%  2.39%
# 6941        6941          7004  salesforce.com Inc.      USD  3.2500%  1.98%
#
# ...

# %%
uns_to_drop = ['Unnamed: 0', 'Unnamed: 0_x']

# %%
df_to_clean = df_to_clean.drop(columns=uns_to_drop)

# %%
df_to_clean
# Out:
#                    Issuer Currency   Coupon  Yield Moody's Rating  \
# 0                   AECOM      USD  5.1250%  4.21%            Ba3
# 1                   AECOM      USD  5.8750%  3.54%            Ba3
# 2              AFLAC Inc.      USD  3.2500%  3.58%             A3
# 3              AFLAC Inc.      USD  4.0000%  3.44%             A3
# 4              AFLAC Inc.      USD  6.4500%      -             A3
# ...                   ...      ...      ...    ...            ...
# 6937            eBay Inc.      USD  4.0000%  4.16%           Baa1
# 6938            eBay Inc.      USD  2.8750%  2.06%           Baa1
# 6939            eBay Inc.      USD  2.6000%  2.27%           Baa1
# 6940  salesforce.com Inc.      USD  3.7000%  2.39%             A3
# 6941  salesforce.com Inc.      USD  3.2500%  1.98%             A3
#
#      Maturity Date     Bid     Ask   Names Ticker  ... Diluted EPS (ttm)  \
# 0        3/15/2027  105.51  107.01   aecom    ACM  ...             -1.73
# ...

# %%
columns_to_drop_1 = ['Shares Short (Dec 30, 2019) 4', 'Shares Short (Jan 14, 2020) 4 ', ]

# %%
list(df_to_clean.columns)
# Out:
# ['Issuer',
#  'Currency',
#  'Coupon',
#  'Yield',
#  "Moody's Rating",
#  'Maturity Date',
#  'Bid',
#  'Ask',
#  'Names',
#  'Ticker',
#  'Name',
#  'Asset Class',
#  'Weight (%)',
#  'Price',
#  'Shares',
#  'Market Value',
#  'Notional Value',
#  'Sector',
#  'SEDOL',
#  'ISIN',
#  'Exchange',
#  'Unnamed: 0_y',
#  'Market Cap (intraday) 5',
#  'Enterprise Value 3',
#  'Trailing P/E',
#  'Forward P/E 1',
#  'PEG Ratio (5 yr expected) 1',
#  'Price/Sales (ttm)',
#  'Price/Book (mrq)',
#  'Enterprise Value/Revenue 3',
#  'Enterprise Value/EBITDA 6',
#  'Beta (5Y Monthly)',
#  '52-Week Change 3',
#  'S&P500 52-Week Change 3',
#  '52 Week High 3',
#  '52 Week Low 3',
#  '50-Day Moving Average 3',
#  '200-Day Moving Average 3',
#  '% Held by Insiders 1',
#  '% Held by Institutions 1',
#  'Avg Vol (10 day) 3',
#  'Avg Vol (3 month) 3',
#  'Float',
#  'Shares Outstanding 5',
#  'Shares Short (Feb 13, 2020) 4',
#  'Shares Short (prior month Dec 30, 2019) 4',
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6942 entries, 0 to 6941
# Data columns (total 82 columns):
# Issuer                                            6942 non-null object
# Currency                                          6942 non-null object
# Coupon                                            6942 non-null object
# Yield                                             6942 non-null object
# Moody's Rating                                    6345 non-null object
# Maturity Date                                     6934 non-null object
# Bid                                               6942 non-null object
# Ask                                               6942 non-null object
# Names                                             6942 non-null object
# Ticker                                            6942 non-null object
# Name                                              6942 non-null object
# Asset Class                                       6942 non-null object
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Issuer                                               0
# Currency                                             0
# Coupon                                               0
# Yield                                                0
# Moody's Rating                                     597
# Maturity Date                                        8
# Bid                                                  0
# Ask                                                  0
# Names                                                0
# Ticker                                               0
# Name                                                 0
# Asset Class                                          0
# Weight (%)                                           0
# Price                                                0
# Shares                                               0
# Market Value                                         0
# Notional Value                                       0
# ...

# %%
others_cols_to_drop = ['Levered Free Cash Flow (ttm)', 'Operating Cash Flow (ttm)', 'Current Ratio (mrq)', 
                      'EBITDA', 'Gross Profit (ttm)', 'Revenue (ttm)', 'Most Recent Quarter (mrq)', 'Fiscal Year Ends',
                      'Last Split Date 3', 'Last Split Factor 2', 'Ex-Dividend Date 4', 'Dividend Date 3']

# %%
df_to_clean = df_to_clean.drop(columns=others_cols_to_drop)

# %%
df_to_clean.Bid.value_counts()
# Out:
# -         516
# 100.19     34
# 103.05     30
# 99.97      30
# 100.35     27
#          ...
# 117.84      1
# 136.47      1
# 117.06      1
# 92.52       1
# 129.17      1
# Name: Bid, Length: 1988, dtype: int64

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6942 entries, 0 to 6941
# Data columns (total 70 columns):
# Issuer                                            6942 non-null object
# Currency                                          6942 non-null object
# Coupon                                            6942 non-null object
# Yield                                             6942 non-null object
# Moody's Rating                                    6345 non-null object
# Maturity Date                                     6934 non-null object
# Bid                                               6942 non-null object
# Ask                                               6942 non-null object
# Names                                             6942 non-null object
# Ticker                                            6942 non-null object
# Name                                              6942 non-null object
# Asset Class                                       6942 non-null object
# ...

# %%
dropping = ['Currency', 'Bid', 'Ask', 'Asset Class', 'SEDOL', 'ISIN', 'Unnamed: 0_y', '52 Week High 3', 
           '52 Week Low 3', '50-Day Moving Average 3', '200-Day Moving Average 3',
           'Net Income Avi to Common (ttm)', 'Diluted EPS (ttm)', 'Total Cash (mrq)']

# %%
df_to_clean = df_to_clean.drop(columns=dropping)

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6942 entries, 0 to 6941
# Data columns (total 56 columns):
# Issuer                                            6942 non-null object
# Coupon                                            6942 non-null object
# Yield                                             6942 non-null object
# Moody's Rating                                    6345 non-null object
# Maturity Date                                     6934 non-null object
# Names                                             6942 non-null object
# Ticker                                            6942 non-null object
# Name                                              6942 non-null object
# Weight (%)                                        6942 non-null float64
# Price                                             6942 non-null object
# Shares                                            6942 non-null object
# Market Value                                      6942 non-null object
# ...

# %%
dropping_2 = ['Issuer', 'Enterprise Value/EBITDA 6', 'Total Debt/Equity (mrq)', 
             'Quarterly Earnings Growth (yoy)', ]

# %%
df_to_clean = df_to_clean.drop(columns=dropping_2)

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6942 entries, 0 to 6941
# Data columns (total 52 columns):
# Coupon                                            6942 non-null object
# Yield                                             6942 non-null object
# Moody's Rating                                    6345 non-null object
# Maturity Date                                     6934 non-null object
# Names                                             6942 non-null object
# Ticker                                            6942 non-null object
# Name                                              6942 non-null object
# Weight (%)                                        6942 non-null float64
# Price                                             6942 non-null object
# Shares                                            6942 non-null object
# Market Value                                      6942 non-null object
# Notional Value                                    6942 non-null object
# ...

# %%
df_to_clean["Moody's Rating"].value_counts()
# Out:
# Baa1    1351
# A3      1065
# A2       989
# Baa2     877
# Baa3     839
# A1       297
# Ba1      170
# WR       136
# Aa2      109
# Ba3      109
# Aaa      104
# Aa3      103
# B2        56
# Ba2       53
# Aa1       37
# B3        30
# B1        18
# Caa1       1
# NR         1
# Name: Moody's Rating, dtype: int64

# %%
len(df_to_clean["Moody's Rating"].value_counts())
# Out:
# 19

# %%
df_to_clean = df_to_clean.loc[df_to_clean["Moody's Rating"] != "NR"]

# %%
df_to_clean = df_to_clean.loc[df_to_clean["Moody's Rating"] != 'WR']

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares  ... Payout Ratio 4  \
# 0                  AECOM        0.02   47.79  119,151.00  ...          0.00%
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                               0
# Yield                                                0
# Moody's Rating                                     597
# Maturity Date                                        8
# Names                                                0
# Ticker                                               0
# Name                                                 0
# Weight (%)                                           0
# Price                                                0
# Shares                                               0
# Market Value                                         0
# Notional Value                                       0
# Sector                                               0
# Exchange                                             0
# Market Cap (intraday) 5                             43
# Enterprise Value 3                                  10
# Trailing P/E                                       686
# ...

# %%
na_droppped_df = df_to_clean.dropna()

# %%
na_droppped_df
# Out:
# Empty DataFrame
# ...

# %%
na_droppped_df.Ticker.unique()
# Out:
# array([], dtype=object)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                               0
# Yield                                                0
# Moody's Rating                                     597
# Maturity Date                                        8
# Names                                                0
# Ticker                                               0
# Name                                                 0
# Weight (%)                                           0
# Price                                                0
# Shares                                               0
# Market Value                                         0
# Notional Value                                       0
# Sector                                               0
# Exchange                                             0
# Market Cap (intraday) 5                             43
# Enterprise Value 3                                  10
# Trailing P/E                                       686
# ...

# %%
nan_cols = ['Enterprise Value 3', 'Enterprise Value/Revenue 3','Shares Short (Feb 13, 2020) 4',
           'Shares Short (prior month Dec 30, 2019) 4', 'Short % of Float (Feb 13, 2020) 4',
           'Short % of Shares Outstanding (Feb 13, 2020) 4', 'Short Ratio (Feb 13, 2020) 4',
           'Forward Annual Dividend Rate 4', 'Forward Annual Dividend Yield 4', 'Trailing Annual Dividend Rate 3',
           'Trailing Annual Dividend Yield 3', 'Payout Ratio 4']

# %%
df_to_clean = df_to_clean.drop(columns=nan_cols)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                          0
# Yield                                           0
# Moody's Rating                                597
# Maturity Date                                   8
# Names                                           0
# Ticker                                          0
# Name                                            0
# Weight (%)                                      0
# Price                                           0
# Shares                                          0
# Market Value                                    0
# Notional Value                                  0
# Sector                                          0
# Exchange                                        0
# Market Cap (intraday) 5                        43
# Trailing P/E                                  686
# Forward P/E 1                                  46
# PEG Ratio (5 yr expected) 1                    71
# Price/Sales (ttm)                              43
# ...

# %%
df_to_clean['Price/Book (mrq)'].replace(np.nan, 0, inplace=True)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                          0
# Yield                                           0
# Moody's Rating                                597
# Maturity Date                                   8
# Names                                           0
# Ticker                                          0
# Name                                            0
# Weight (%)                                      0
# Price                                           0
# Shares                                          0
# Market Value                                    0
# Notional Value                                  0
# Sector                                          0
# Exchange                                        0
# Market Cap (intraday) 5                        43
# Trailing P/E                                  686
# Forward P/E 1                                  46
# PEG Ratio (5 yr expected) 1                    71
# Price/Sales (ttm)                              43
# ...

# %%
df_to_clean['Trailing P/E'].replace(np.nan, 0, inplace=True)

# %%
df_to_clean['Maturity Date'].isna().sum()
# Out:
# 8

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                          0
# Yield                                           0
# Moody's Rating                                597
# Maturity Date                                   8
# Names                                           0
# Ticker                                          0
# Name                                            0
# Weight (%)                                      0
# Price                                           0
# Shares                                          0
# Market Value                                    0
# Notional Value                                  0
# Sector                                          0
# Exchange                                        0
# Market Cap (intraday) 5                        43
# Trailing P/E                                    0
# Forward P/E 1                                  46
# PEG Ratio (5 yr expected) 1                    71
# Price/Sales (ttm)                              43
# ...

# %%
df_to_clean['Return on Equity (ttm)'].replace(np.nan, 0, inplace=True)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                          0
# Yield                                           0
# Moody's Rating                                597
# Maturity Date                                   8
# Names                                           0
# Ticker                                          0
# Name                                            0
# Weight (%)                                      0
# Price                                           0
# Shares                                          0
# Market Value                                    0
# Notional Value                                  0
# Sector                                          0
# Exchange                                        0
# Market Cap (intraday) 5                        43
# Trailing P/E                                    0
# Forward P/E 1                                  46
# PEG Ratio (5 yr expected) 1                    71
# Price/Sales (ttm)                              43
# ...

# %%
dropping_more = ['Float', '5 Year Average Dividend Yield 4']

# %%
df_to_clean = df_to_clean.drop(columns=dropping_more)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
bvps_mean = df_to_clean["Book Value Per Share (mrq)"].mean()

# %%
df_to_clean["Book Value Per Share (mrq)"].replace(np.nan, bvps_mean, inplace=True)

# %%
tcps_mean = df_to_clean["Total Cash Per Share (mrq)"].mean()

# %%
df_to_clean["Total Cash Per Share (mrq)"].replace(np.nan, tcps_mean, inplace=True)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6805 entries, 0 to 6941
# Data columns (total 38 columns):
# Coupon                                       6805 non-null object
# Yield                                        6805 non-null object
# Moody's Rating                               6208 non-null object
# Maturity Date                                6797 non-null object
# Names                                        6805 non-null object
# Ticker                                       6805 non-null object
# Name                                         6805 non-null object
# Weight (%)                                   6805 non-null float64
# Price                                        6805 non-null object
# Shares                                       6805 non-null object
# Market Value                                 6805 non-null object
# Notional Value                               6805 non-null object
# Sector                                       6805 non-null object
# ...

# %%
df_to_clean["Total Debt (mrq)"] = df_to_clean["Total Debt (mrq)"].str[:-1]

# %%
df_to_clean["Total Debt (mrq)"] = df_to_clean["Total Debt (mrq)"].astype(float)

# %%
total_debt_mean = df_to_clean["Total Debt (mrq)"].mean()

# %%
total_debt_mean
# Out:
# 69.74898454746257

# %%
df_to_clean[df_to_clean["Total Debt (mrq)"].isnull()]
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 4894  3.3750%  2.33%           Baa2     6/15/2021  netapp   NTAP
# 4895  3.3000%  2.49%           Baa2     9/29/2024  netapp   NTAP
# 6542  3.1500%  2.02%            Aa3    12/14/2025  visain      V
# 6543  2.1500%  1.79%            Aa3     9/15/2022  visain      V
# 6544  4.3000%  3.03%            Aa3    12/14/2045  visain      V
# 6545  4.1500%  2.65%            Aa3    12/14/2035  visain      V
# 6546  2.8000%  1.81%            Aa3    12/14/2022  visain      V
# 6547  3.6500%  3.01%            Aa3     9/15/2047  visain      V
# 6548  2.2000%  1.81%            Aa3    12/14/2020  visain      V
# 6549  2.7500%  2.11%            Aa3     9/15/2027  visain      V
#
#                   Name  Weight (%)   Price        Shares  ...  \
# 4894        NETAPP INC        0.04   54.24    178,645.00  ...
# 4895        NETAPP INC        0.04   54.24    178,645.00  ...
# ...

# %%
df_to_clean["Total Debt (mrq)"] = df_to_clean["Total Debt (mrq)"].replace(np.nan, 15.65)

# %%
df_to_clean[df_to_clean["Total Debt (mrq)"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Coupon, Yield, Moody's Rating, Maturity Date, Names, Ticker, Name, Weight (%), Price, Shares, Market Value, Notional Value, Sector, Exchange, Market Cap (intraday) 5, Trailing P/E, Forward P/E 1, PEG Ratio (5 yr expected) 1, Price/Sales (ttm), Price/Book (mrq), Beta (5Y Monthly), 52-Week Change 3, S&P500 52-Week Change 3, % Held by Insiders 1, % Held by Institutions 1, Avg Vol (10 day) 3, Avg Vol (3 month) 3, Shares Outstanding 5, Shares Short (prior month Jan 14, 2020) 4, Profit Margin, Operating Margin (ttm), Return on Assets (ttm), Return on Equity (ttm), Revenue Per Share (ttm), Quarterly Revenue Growth (yoy), Total Cash Per Share (mrq), Total Debt (mrq), Book Value Per Share (mrq)]
# Index: []
#
# [0 rows x 38 columns]

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean["Beta (5Y Monthly)"].mean()
# Out:
# 0.9751133165457044

# %%
df_to_clean[df_to_clean["Beta (5Y Monthly)"].isnull()]
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 1711  9.0000%  6.59%            NaN     10/1/2025  avanto   AVTR
# 2998  4.9000%      -            Ba2     8/28/2028  elanco   ELAN
# 2999  3.9120%  2.49%            NaN     8/27/2021  elanco   ELAN
# 3000  4.9000%  4.01%            NaN     8/28/2028  elanco   ELAN
# 3001  4.2720%  2.92%            NaN     8/28/2023  elanco   ELAN
# 3262  4.7090%  2.99%            NaN     1/25/2029  foxcor   FOXA
# 3263  4.7090%  2.99%            NaN     1/25/2029  foxcor    FOX
# 3264  5.4760%  3.84%            NaN     1/25/2039  foxcor   FOXA
# 3265  5.4760%  3.84%            NaN     1/25/2039  foxcor    FOX
# 3266  4.0300%  2.33%            NaN     1/25/2024  foxcor   FOXA
# 3267  4.0300%  2.33%            NaN     1/25/2024  foxcor    FOX
# 3268  3.6660%  1.96%            NaN     1/25/2022  foxcor   FOXA
# 3269  3.6660%  1.96%            NaN     1/25/2022  foxcor    FOX
# ...

# %%
df_to_clean["Beta (5Y Monthly)"] = df_to_clean["Beta (5Y Monthly)"].replace(np.nan, .97)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean["Return on Assets (ttm)"] = df_to_clean["Return on Assets (ttm)"].str[:-1]

# %%
df_to_clean["Return on Assets (ttm)"] = df_to_clean["Return on Assets (ttm)"].astype(float)

# %%
roa_mean = df_to_clean["Return on Assets (ttm)"].mean()

# %%
df_to_clean["Return on Assets (ttm)"] = df_to_clean["Return on Assets (ttm)"].replace(np.nan, roa_mean)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares  ...  \
# 0                  AECOM        0.02   47.79  119,151.00  ...
# ...

# %%
# Maturity Date
# df_to_clean[df_to_clean["Maturity Date"].isnull()]

# %%
# df_to_clean["Maturity Date"] = df_to_clean["Maturity Date"].dropna()

# %%
# df_to_clean[df_to_clean["Maturity Date"].isnull()]

# %%
# df_to_clean["Maturity Date"] = df_to_clean.loc[df_to_clean["Maturity Date"] != np.nan]

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean["Moody's Rating"].value_counts()
# Out:
# Baa1    1351
# A3      1065
# A2       989
# Baa2     877
# Baa3     839
# A1       297
# Ba1      170
# Ba3      109
# Aa2      109
# Aaa      104
# Aa3      103
# B2        56
# Ba2       53
# Aa1       37
# B3        30
# B1        18
# Caa1       1
# Name: Moody's Rating, dtype: int64

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares  ...  \
# 0                  AECOM        0.02   47.79  119,151.00  ...
# ...

# %%
df_to_clean[df_to_clean["Moody's Rating"].isnull()]
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 32    6.5000%  3.15%            NaN     3/15/2029  attinc      T
# 69    4.3000%      -            NaN     2/15/2030  attinc      T
# 70    4.1000%      -            NaN     2/15/2028  attinc      T
# 71    5.1500%  5.68%            NaN     2/15/2050  attinc      T
# 88    2.3000%  2.24%            NaN    11/21/2022  abbvie   ABBV
# ...       ...    ...            ...           ...     ...    ...
# 6901  5.3750%  4.70%            NaN     4/15/2026  wyndha     WH
# 6902  6.5000%  5.79%            NaN     6/15/2022  xpolog    XPO
# 6907  3.5000%  3.61%            NaN     12/1/2049  xcelen    XEL
# 6909  2.6000%  2.82%            NaN     12/1/2029  xcelen    XEL
# 6916  5.7500%  5.43%            NaN     1/15/2027  zayogr   ZAYO
#
#                             Name  Weight (%)  Price        Shares  ...  \
# 32                      AT&T INC        0.89  38.25  5,463,772.00  ...
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
df_to_clean[df_to_clean["Maturity Date"].isnull()]
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 1893  4.5000%  4.41%            NaN           NaN  bankof    BAC
# 1894  4.5000%  4.41%            NaN           NaN  bankof     BK
# 2914  4.8750%  4.37%            NaN           NaN  dukeen    DUK
# 3176  5.1000%  4.91%            NaN           NaN  fiftht   FITB
# 3459  5.0000%  5.37%            NaN           NaN  genera     GE
# 3460  5.0000%  5.37%            NaN           NaN  genera     GD
# 3461  5.0000%  5.37%            NaN           NaN  genera     GM
# 3462  5.0000%  5.37%            NaN           NaN  genera    GIS
#
#                               Name  Weight (%)   Price        Shares  ...  \
# 1893          BANK OF AMERICA CORP        0.91   34.85  6,089,264.00  ...
# 1894  BANK OF NEW YORK MELLON CORP        0.12    45.9    613,551.00  ...
# 2914              DUKE ENERGY CORP        0.24  101.28    544,983.00  ...
# 3176           FIFTH THIRD BANCORP        0.07    29.6    527,260.00  ...
# ...

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares  ...  \
# 0                  AECOM        0.02   47.79  119,151.00  ...
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                                         0
# Yield                                          0
# Moody's Rating                               597
# Maturity Date                                  8
# Names                                          0
# Ticker                                         0
# Name                                           0
# Weight (%)                                     0
# Price                                          0
# Shares                                         0
# Market Value                                   0
# Notional Value                                 0
# Sector                                         0
# Exchange                                       0
# Market Cap (intraday) 5                       43
# Trailing P/E                                   0
# Forward P/E 1                                 46
# PEG Ratio (5 yr expected) 1                   71
# Price/Sales (ttm)                             43
# ...

# %%
dropping_add_cols = ["Shares Short (prior month Jan 14, 2020) 4"]

# %%
df_to_clean = df_to_clean.drop(columns=dropping_add_cols)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                              0
# Yield                               0
# Moody's Rating                    597
# Maturity Date                       8
# Names                               0
# Ticker                              0
# Name                                0
# Weight (%)                          0
# Price                               0
# Shares                              0
# Market Value                        0
# Notional Value                      0
# Sector                              0
# Exchange                            0
# Market Cap (intraday) 5            43
# Trailing P/E                        0
# Forward P/E 1                      46
# PEG Ratio (5 yr expected) 1        71
# Price/Sales (ttm)                  43
# Price/Book (mrq)                    0
# Beta (5Y Monthly)                   0
# 52-Week Change 3                   44
# S&P500 52-Week Change 3            10
# % Held by Insiders 1               44
# % Held by Institutions 1           44
# ...

# %%
df_to_clean.shape
# Out:
# (6805, 37)

# %%
df_to_clean["Moody's Rating"].unique()
# Out:
# array(['Ba3', 'A3', 'Baa2', nan, 'Baa1', 'A2', 'B2', 'Baa3', 'Ba1', 'B1',
#        'Aa2', 'A1', 'Aa3', 'Aa1', 'Ba2', 'B3', 'Aaa', 'Caa1'],
#       dtype=object)

# %%
df_to_clean["Moody's Rating"] = df_to_clean["Moody's Rating"].replace(np.nan, "WR")

# %%
pd.set_option('display.max_columns', 500)

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares    Market Value  \
# 0                  AECOM        0.02   47.79  119,151.00    5,694,226.29
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                             0
# Yield                              0
# Moody's Rating                     0
# Maturity Date                      8
# Names                              0
# Ticker                             0
# Name                               0
# Weight (%)                         0
# Price                              0
# Shares                             0
# Market Value                       0
# Notional Value                     0
# Sector                             0
# Exchange                           0
# Market Cap (intraday) 5           43
# Trailing P/E                       0
# Forward P/E 1                     46
# PEG Ratio (5 yr expected) 1       71
# Price/Sales (ttm)                 43
# Price/Book (mrq)                   0
# Beta (5Y Monthly)                  0
# 52-Week Change 3                  44
# S&P500 52-Week Change 3           10
# % Held by Insiders 1              44
# % Held by Institutions 1          44
# ...

# %%
df_to_clean = df_to_clean.dropna()

# %%
df_to_clean
# Out:
#        Coupon  Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250%  4.21%            Ba3     3/15/2027   aecom    ACM
# 1     5.8750%  3.54%            Ba3    10/15/2024   aecom    ACM
# 2     3.2500%  3.58%             A3     3/17/2025  aflaci    AFL
# 3     4.0000%  3.44%             A3    10/15/2046  aflaci    AFL
# 4     6.4500%      -             A3     8/15/2040  aflaci    AFL
# ...       ...    ...            ...           ...     ...    ...
# 6937  4.0000%  4.16%           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750%  2.06%           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000%  2.27%           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000%  2.39%             A3     4/11/2028  salesf    CRM
# 6941  3.2500%  1.98%             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares    Market Value  \
# 0                  AECOM        0.02   47.79  119,151.00    5,694,226.29
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                            0
# Yield                             0
# Moody's Rating                    0
# Maturity Date                     0
# Names                             0
# Ticker                            0
# Name                              0
# Weight (%)                        0
# Price                             0
# Shares                            0
# Market Value                      0
# Notional Value                    0
# Sector                            0
# Exchange                          0
# Market Cap (intraday) 5           0
# Trailing P/E                      0
# Forward P/E 1                     0
# PEG Ratio (5 yr expected) 1       0
# Price/Sales (ttm)                 0
# Price/Book (mrq)                  0
# Beta (5Y Monthly)                 0
# 52-Week Change 3                  0
# S&P500 52-Week Change 3           0
# % Held by Insiders 1              0
# % Held by Institutions 1          0
# Avg Vol (10 day) 3                0
# ...

# %%
df_to_clean["Yield"] = df_to_clean["Yield"].replace('-', '0%')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean.loc[df_to_clean['Yield'] == "0%"]
# Out:
#        Coupon Yield Moody's Rating Maturity Date   Names Ticker  \
# 4     6.4500%    0%             A3     8/15/2040  aflaci    AFL
# 7     4.7500%    0%             A3     1/15/2049  aflaci    AFL
# 9     6.9000%    0%             A3    12/17/2039  aflaci    AFL
# 10    6.8000%    0%           Baa2     5/15/2036  attinc      T
# 23    6.3500%    0%           Baa2     3/15/2040  attinc      T
# ...       ...   ...            ...           ...     ...    ...
# 6897  7.3750%    0%            Ba2      3/1/2020  wyndha     WH
# 6900  3.9000%    0%            Ba2      3/1/2023  wyndha     WH
# 6904  3.3000%    0%           Baa1      6/1/2025  xcelen    XEL
# 6913  4.8750%    0%           Baa2     10/1/2021  xylemi    XYL
# 6917  3.3750%    0%           Baa3    11/30/2021  zimmer    ZBH
#
#                             Name  Weight (%)  Price        Shares  \
# 4                      AFLAC INC        0.12  52.81    543,134.00
# ...

# %%
df_to_clean["Yield"] = df_to_clean["Yield"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Yield"] = df_to_clean["Yield"].astype(float)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
yield_mean = df_to_clean["Yield"].mean()

# %%
df_to_clean["Yield"] = df_to_clean["Yield"].replace(0, yield_mean)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Coupon"] = df_to_clean["Coupon"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
list(df_to_clean.columns)
# Out:
# ['Coupon',
#  'Yield',
#  "Moody's Rating",
#  'Maturity Date',
#  'Names',
#  'Ticker',
#  'Name',
#  'Weight (%)',
#  'Price',
#  'Shares',
#  'Market Value',
#  'Notional Value',
#  'Sector',
#  'Exchange',
#  'Market Cap (intraday) 5',
#  'Trailing P/E',
#  'Forward P/E 1',
#  'PEG Ratio (5 yr expected) 1',
#  'Price/Sales (ttm)',
#  'Price/Book (mrq)',
#  'Beta (5Y Monthly)',
#  '52-Week Change 3',
#  'S&P500 52-Week Change 3',
#  '% Held by Insiders 1',
#  '% Held by Institutions 1',
#  'Avg Vol (10 day) 3',
#  'Avg Vol (3 month) 3',
#  'Shares Outstanding 5',
#  'Profit Margin',
#  'Operating Margin (ttm)',
#  'Return on Assets (ttm)',
#  'Return on Equity (ttm)',
#  'Revenue Per Share (ttm)',
#  'Quarterly Revenue Growth (yoy)',
#  'Total Cash Per Share (mrq)',
#  'Total Debt (mrq)',
#  'Book Value Per Share (mrq)']

# %%
# dropping_names = ['Name_x', 'Name_y']

# %%
# df_to_clean = df_to_clean.drop(columns=dropping_names)

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250  4.210000            Ba3     3/15/2027   aecom    ACM
# 1     5.8750  3.540000            Ba3    10/15/2024   aecom    ACM
# 2     3.2500  3.580000             A3     3/17/2025  aflaci    AFL
# 3     4.0000  3.440000             A3    10/15/2046  aflaci    AFL
# 4     6.4500  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937  4.0000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000  2.390000             A3     4/11/2028  salesf    CRM
# 6941  3.2500  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares    Market Value  \
# 0                  AECOM        0.02   47.79  119,151.00    5,694,226.29
# ...

# %%
cols_to_strip = ["Market Cap (intraday) 5", "52-Week Change 3", "S&P500 52-Week Change 3",
                "% Held by Insiders 1", "% Held by Institutions 1", "Avg Vol (10 day) 3", 
                "Avg Vol (3 month) 3", "Shares Outstanding 5", "Profit Margin", 
                "Operating Margin (ttm)", "Return on Equity (ttm)", "Quarterly Revenue Growth (yoy)"]

# %%
df_to_clean["Market Cap (intraday) 5"] = df_to_clean["Market Cap (intraday) 5"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["52-Week Change 3"] = df_to_clean["52-Week Change 3"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["S&P500 52-Week Change 3"] = df_to_clean["S&P500 52-Week Change 3"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["% Held by Insiders 1"] = df_to_clean["% Held by Insiders 1"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["% Held by Institutions 1"] = df_to_clean["% Held by Institutions 1"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Avg Vol (10 day) 3"] = df_to_clean["Avg Vol (10 day) 3"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Avg Vol (3 month) 3"] = df_to_clean["Avg Vol (3 month) 3"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Shares Outstanding 5"] = df_to_clean["Shares Outstanding 5"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Profit Margin"] = df_to_clean["Profit Margin"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Operating Margin (ttm)"] = df_to_clean["Operating Margin (ttm)"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Return on Equity (ttm)"] = df_to_clean["Return on Equity (ttm)"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean["Quarterly Revenue Growth (yoy)"] = df_to_clean["Quarterly Revenue Growth (yoy)"].str[:-1]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 37 columns):
# Coupon                            6712 non-null object
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null object
# Shares                            6712 non-null object
# Market Value                      6712 non-null object
# Notional Value                    6712 non-null object
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null object
# ...

# %%
list(df_to_clean.columns)
# Out:
# ['Coupon',
#  'Yield',
#  "Moody's Rating",
#  'Maturity Date',
#  'Names',
#  'Ticker',
#  'Name',
#  'Weight (%)',
#  'Price',
#  'Shares',
#  'Market Value',
#  'Notional Value',
#  'Sector',
#  'Exchange',
#  'Market Cap (intraday) 5',
#  'Trailing P/E',
#  'Forward P/E 1',
#  'PEG Ratio (5 yr expected) 1',
#  'Price/Sales (ttm)',
#  'Price/Book (mrq)',
#  'Beta (5Y Monthly)',
#  '52-Week Change 3',
#  'S&P500 52-Week Change 3',
#  '% Held by Insiders 1',
#  '% Held by Institutions 1',
#  'Avg Vol (10 day) 3',
#  'Avg Vol (3 month) 3',
#  'Shares Outstanding 5',
#  'Profit Margin',
#  'Operating Margin (ttm)',
#  'Return on Assets (ttm)',
#  'Return on Equity (ttm)',
#  'Revenue Per Share (ttm)',
#  'Quarterly Revenue Growth (yoy)',
#  'Total Cash Per Share (mrq)',
#  'Total Debt (mrq)',
#  'Book Value Per Share (mrq)']

# %%
floats = ['Coupon',
 'Yield',
#  "Moody's Rating",
#  'Maturity Date',
#  'Names',
#  'Ticker',
 'Weight (%)',
 'Price',
 'Shares',
 'Market Value',
 'Notional Value',
#  'Sector',
#  'Exchange',
 'Market Cap (intraday) 5',
 'Trailing P/E',
 'Forward P/E 1',
 'PEG Ratio (5 yr expected) 1',
 'Price/Sales (ttm)',
 'Price/Book (mrq)',
 'Beta (5Y Monthly)',
 'S&P500 52-Week Change 3',
 '% Held by Insiders 1',
 '% Held by Institutions 1',
 'Avg Vol (10 day) 3',
 'Avg Vol (3 month) 3',
 'Shares Outstanding 5',
 'Profit Margin',
 'Operating Margin (ttm)',
 'Return on Assets (ttm)',
 'Revenue Per Share (ttm)',
 'Quarterly Revenue Growth (yoy)',
 'Total Cash Per Share (mrq)',
 'Total Debt (mrq)',
 'Book Value Per Share (mrq)']

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250  4.210000            Ba3     3/15/2027   aecom    ACM
# 1     5.8750  3.540000            Ba3    10/15/2024   aecom    ACM
# 2     3.2500  3.580000             A3     3/17/2025  aflaci    AFL
# 3     4.0000  3.440000             A3    10/15/2046  aflaci    AFL
# 4     6.4500  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937  4.0000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000  2.390000             A3     4/11/2028  salesf    CRM
# 6941  3.2500  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares    Market Value  \
# 0                  AECOM        0.02   47.79  119,151.00    5,694,226.29
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 37 columns):
# Coupon                            6712 non-null object
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null object
# Shares                            6712 non-null object
# Market Value                      6712 non-null object
# Notional Value                    6712 non-null object
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null object
# ...

# %%
df_to_clean['Market Value'] = df_to_clean['Market Value'].apply(lambda x: x.replace(',', ''))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean['Notional Value'] = df_to_clean['Notional Value'].apply(lambda x: x.replace(',', ''))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0     5.1250  4.210000            Ba3     3/15/2027   aecom    ACM
# 1     5.8750  3.540000            Ba3    10/15/2024   aecom    ACM
# 2     3.2500  3.580000             A3     3/17/2025  aflaci    AFL
# 3     4.0000  3.440000             A3    10/15/2046  aflaci    AFL
# 4     6.4500  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937  4.0000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938  2.8750  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939  2.6000  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940  3.7000  2.390000             A3     4/11/2028  salesf    CRM
# 6941  3.2500  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price      Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119,151.00    5694226.29
# ...

# %%
df_to_clean['Price'] = df_to_clean['Price'].apply(lambda x: x.replace(',', ''))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_to_clean['Shares'] = df_to_clean['Shares'].apply(lambda x: x.replace(',', ''))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# df_to_clean['Yield'] = df_to_clean['Yield'].apply(pd.to_numeric)

# %%
# df_to_clean['Yield'].dtype

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 37 columns):
# Coupon                            6712 non-null object
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null object
# Shares                            6712 non-null object
# Market Value                      6712 non-null object
# Notional Value                    6712 non-null object
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null object
# ...

# %%
df_to_clean = df_to_clean.drop(columns="52-Week Change 3")

# %%
df_to_clean = df_to_clean.drop(columns="Return on Equity (ttm)")

# %%
df_to_clean["Coupon"].isna().sum()
# Out:
# 0

# %%
# df_to_clean["Coupon"].mean()

# %%
df_to_clean["Coupon"] = df_to_clean["Coupon"].replace(np.nan, "0")

# %%
df_to_clean[floats] = df_to_clean[floats].apply(pd.to_numeric)

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 35 columns):
# Coupon                            6707 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean['Sector'] = df_to_clean['Sector'].astype(str)

# %%
df_to_clean['Exchange'] = df_to_clean['Exchange'].astype(str)

# %%
df_to_clean["Moody's Rating"] = df_to_clean["Moody's Rating"].astype(str)

# %%
df_to_clean['Names'] = df_to_clean['Names'].astype(str)

# %%
df_to_clean['Ticker'] = df_to_clean['Ticker'].astype(str)

# %%
df_to_clean['Name'] = df_to_clean['Name'].astype(str)

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 35 columns):
# Coupon                            6707 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 35 columns):
# Coupon                            6707 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean["Pull_Date"] = '2/14/2020'

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 36 columns):
# Coupon                            6707 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean['Pull_Date'] = pd.to_datetime(df_to_clean['Pull_Date'])

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 36 columns):
# Coupon                            6707 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
pd.set_option('display.max_rows', 100)

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean.isna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 36 columns):
# Coupon                            6712 non-null bool
# Yield                             6712 non-null bool
# Moody's Rating                    6712 non-null bool
# Maturity Date                     6712 non-null bool
# Names                             6712 non-null bool
# Ticker                            6712 non-null bool
# Name                              6712 non-null bool
# Weight (%)                        6712 non-null bool
# Price                             6712 non-null bool
# Shares                            6712 non-null bool
# Market Value                      6712 non-null bool
# Notional Value                    6712 non-null bool
# Sector                            6712 non-null bool
# Exchange                          6712 non-null bool
# Market Cap (intraday) 5           6712 non-null bool
# Trailing P/E                      6712 non-null bool
# ...

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                            5
# Yield                             0
# Moody's Rating                    0
# Maturity Date                     0
# Names                             0
# Ticker                            0
# Name                              0
# Weight (%)                        0
# Price                             0
# Shares                            0
# Market Value                      0
# Notional Value                    0
# Sector                            0
# Exchange                          0
# Market Cap (intraday) 5           0
# Trailing P/E                      0
# Forward P/E 1                     0
# PEG Ratio (5 yr expected) 1       0
# Price/Sales (ttm)                 0
# Price/Book (mrq)                  0
# Beta (5Y Monthly)                 0
# S&P500 52-Week Change 3           0
# % Held by Insiders 1              0
# % Held by Institutions 1          0
# Avg Vol (10 day) 3                0
# Avg Vol (3 month) 3               0
# ...

# %%
df_to_clean["Coupon"] = df_to_clean["Coupon"].replace(np.nan, 0)

# %%
df_to_clean.isna().sum()
# Out:
# Coupon                            0
# Yield                             0
# Moody's Rating                    0
# Maturity Date                     0
# Names                             0
# Ticker                            0
# Name                              0
# Weight (%)                        0
# Price                             0
# Shares                            0
# Market Value                      0
# Notional Value                    0
# Sector                            0
# Exchange                          0
# Market Cap (intraday) 5           0
# Trailing P/E                      0
# Forward P/E 1                     0
# PEG Ratio (5 yr expected) 1       0
# Price/Sales (ttm)                 0
# Price/Book (mrq)                  0
# Beta (5Y Monthly)                 0
# S&P500 52-Week Change 3           0
# % Held by Insiders 1              0
# % Held by Institutions 1          0
# Avg Vol (10 day) 3                0
# Avg Vol (3 month) 3               0
# ...

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 36 columns):
# Coupon                            6712 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null object
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3     3/15/2027   aecom    ACM
# 1      5.875  3.540000            Ba3    10/15/2024   aecom    ACM
# 2      3.250  3.580000             A3     3/17/2025  aflaci    AFL
# 3      4.000  3.440000             A3    10/15/2046  aflaci    AFL
# 4      6.450  2.498236             A3     8/15/2040  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1     7/15/2042  ebayin   EBAY
# 6938   2.875  2.060000           Baa1      8/1/2021  ebayin   EBAY
# 6939   2.600  2.270000           Baa1     7/15/2022  ebayin   EBAY
# 6940   3.700  2.390000             A3     4/11/2028  salesf    CRM
# 6941   3.250  1.980000             A3     4/11/2023  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean["Maturity Date"].astype('datetime64[ns]')
# Out:
# 0      2027-03-15
# 1      2024-10-15
# 2      2025-03-17
# 3      2046-10-15
# 4      2040-08-15
#           ...
# 6937   2042-07-15
# 6938   2021-08-01
# 6939   2022-07-15
# 6940   2028-04-11
# 6941   2023-04-11
# Name: Maturity Date, Length: 6712, dtype: datetime64[ns]

# %%
df_to_clean["Maturity Date"] = df_to_clean["Maturity Date"].astype('datetime64[ns]')

# %%
df_to_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6712 entries, 0 to 6941
# Data columns (total 36 columns):
# Coupon                            6712 non-null float64
# Yield                             6712 non-null float64
# Moody's Rating                    6712 non-null object
# Maturity Date                     6712 non-null datetime64[ns]
# Names                             6712 non-null object
# Ticker                            6712 non-null object
# Name                              6712 non-null object
# Weight (%)                        6712 non-null float64
# Price                             6712 non-null float64
# Shares                            6712 non-null float64
# Market Value                      6712 non-null float64
# Notional Value                    6712 non-null float64
# Sector                            6712 non-null object
# Exchange                          6712 non-null object
# Market Cap (intraday) 5           6712 non-null float64
# ...

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3    2027-03-15   aecom    ACM
# 1      5.875  3.540000            Ba3    2024-10-15   aecom    ACM
# 2      3.250  3.580000             A3    2025-03-17  aflaci    AFL
# 3      4.000  3.440000             A3    2046-10-15  aflaci    AFL
# 4      6.450  2.498236             A3    2040-08-15  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1    2042-07-15  ebayin   EBAY
# 6938   2.875  2.060000           Baa1    2021-08-01  ebayin   EBAY
# 6939   2.600  2.270000           Baa1    2022-07-15  ebayin   EBAY
# 6940   3.700  2.390000             A3    2028-04-11  salesf    CRM
# 6941   3.250  1.980000             A3    2023-04-11  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean["Days_to_Maturity"] = df_to_clean["Maturity Date"] - df_to_clean["Pull_Date"]

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating Maturity Date   Names Ticker  \
# 0      5.125  4.210000            Ba3    2027-03-15   aecom    ACM
# 1      5.875  3.540000            Ba3    2024-10-15   aecom    ACM
# 2      3.250  3.580000             A3    2025-03-17  aflaci    AFL
# 3      4.000  3.440000             A3    2046-10-15  aflaci    AFL
# 4      6.450  2.498236             A3    2040-08-15  aflaci    AFL
# ...      ...       ...            ...           ...     ...    ...
# 6937   4.000  4.160000           Baa1    2042-07-15  ebayin   EBAY
# 6938   2.875  2.060000           Baa1    2021-08-01  ebayin   EBAY
# 6939   2.600  2.270000           Baa1    2022-07-15  ebayin   EBAY
# 6940   3.700  2.390000             A3    2028-04-11  salesf    CRM
# 6941   3.250  1.980000             A3    2023-04-11  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  Market Value  \
# 0                  AECOM        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
df_to_clean = df_to_clean.drop(columns="Pull_Date")
df_to_clean = df_to_clean.drop(columns="Maturity Date")

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating   Names Ticker                Name  \
# 0      5.125  4.210000            Ba3   aecom    ACM               AECOM
# 1      5.875  3.540000            Ba3   aecom    ACM               AECOM
# 2      3.250  3.580000             A3  aflaci    AFL           AFLAC INC
# 3      4.000  3.440000             A3  aflaci    AFL           AFLAC INC
# 4      6.450  2.498236             A3  aflaci    AFL           AFLAC INC
# ...      ...       ...            ...     ...    ...                 ...
# 6937   4.000  4.160000           Baa1  ebayin   EBAY            EBAY INC
# 6938   2.875  2.060000           Baa1  ebayin   EBAY            EBAY INC
# 6939   2.600  2.270000           Baa1  ebayin   EBAY            EBAY INC
# 6940   3.700  2.390000             A3  salesf    CRM  SALESFORCE.COM INC
# 6941   3.250  1.980000             A3  salesf    CRM  SALESFORCE.COM INC
#
#       Weight (%)   Price    Shares  Market Value  Notional Value  \
# ...

# %%
df_to_clean["Moody's Rating"].value_counts()
# Out:
# Baa1    1341
# A3      1050
# A2       976
# Baa2     865
# Baa3     839
# WR       581
# A1       293
# Ba1      170
# Ba3      109
# Aaa      104
# Aa3       95
# Aa2       94
# B2        56
# Ba2       53
# Aa1       37
# B3        30
# B1        18
# Caa1       1
# Name: Moody's Rating, dtype: int64

# %%
df_to_clean = df_to_clean.loc[df_to_clean["Moody's Rating"] != "WR"]

# %%
df_to_clean = df_to_clean.loc[df_to_clean["Moody's Rating"] != "Caa1"]

# %%
df_to_clean
# Out:
#       Coupon     Yield Moody's Rating   Names Ticker                Name  \
# 0      5.125  4.210000            Ba3   aecom    ACM               AECOM
# 1      5.875  3.540000            Ba3   aecom    ACM               AECOM
# 2      3.250  3.580000             A3  aflaci    AFL           AFLAC INC
# 3      4.000  3.440000             A3  aflaci    AFL           AFLAC INC
# 4      6.450  2.498236             A3  aflaci    AFL           AFLAC INC
# ...      ...       ...            ...     ...    ...                 ...
# 6937   4.000  4.160000           Baa1  ebayin   EBAY            EBAY INC
# 6938   2.875  2.060000           Baa1  ebayin   EBAY            EBAY INC
# 6939   2.600  2.270000           Baa1  ebayin   EBAY            EBAY INC
# 6940   3.700  2.390000             A3  salesf    CRM  SALESFORCE.COM INC
# 6941   3.250  1.980000             A3  salesf    CRM  SALESFORCE.COM INC
#
#       Weight (%)   Price    Shares  Market Value  Notional Value  \
# ...

# %%
# df_to_clean.to_csv('cleaned_df.csv')
