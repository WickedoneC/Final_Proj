# %%
url_list_1 = [ 'https://finance.yahoo.com/quote/AAPL/key-statistics?p=AAPL',
 'https://finance.yahoo.com/quote/MSFT/key-statistics?p=MSFT',
 'https://finance.yahoo.com/quote/AMZN/key-statistics?p=AMZN',
 'https://finance.yahoo.com/quote/FB/key-statistics?p=FB',
 'https://finance.yahoo.com/quote/GOOG/key-statistics?p=GOOG',
 'https://finance.yahoo.com/quote/GOOGL/key-statistics?p=GOOGL',
 'https://finance.yahoo.com/quote/BRKB/key-statistics?p=BRKB',
 'https://finance.yahoo.com/quote/JPM/key-statistics?p=JPM',
 'https://finance.yahoo.com/quote/JNJ/key-statistics?p=JNJ',
 'https://finance.yahoo.com/quote/V/key-statistics?p=V',
 'https://finance.yahoo.com/quote/PG/key-statistics?p=PG',
 'https://finance.yahoo.com/quote/MA/key-statistics?p=MA',
 'https://finance.yahoo.com/quote/INTC/key-statistics?p=INTC',
 'https://finance.yahoo.com/quote/BAC/key-statistics?p=BAC',
 'https://finance.yahoo.com/quote/UNH/key-statistics?p=UNH',
 'https://finance.yahoo.com/quote/T/key-statistics?p=T',
 'https://finance.yahoo.com/quote/HD/key-statistics?p=HD',
 'https://finance.yahoo.com/quote/XOM/key-statistics?p=XOM',
 'https://finance.yahoo.com/quote/DIS/key-statistics?p=DIS',
 'https://finance.yahoo.com/quote/VZ/key-statistics?p=VZ',
 'https://finance.yahoo.com/quote/KO/key-statistics?p=KO',
 'https://finance.yahoo.com/quote/MRK/key-statistics?p=MRK',
 'https://finance.yahoo.com/quote/CVX/key-statistics?p=CVX',
 'https://finance.yahoo.com/quote/CMCSA/key-statistics?p=CMCSA',
 'https://finance.yahoo.com/quote/PEP/key-statistics?p=PEP',
 'https://finance.yahoo.com/quote/PFE/key-statistics?p=PFE',
 'https://finance.yahoo.com/quote/CSCO/key-statistics?p=CSCO',
 'https://finance.yahoo.com/quote/ADBE/key-statistics?p=ADBE',
 'https://finance.yahoo.com/quote/WFC/key-statistics?p=WFC',
 'https://finance.yahoo.com/quote/BA/key-statistics?p=BA',
 'https://finance.yahoo.com/quote/C/key-statistics?p=C',
 'https://finance.yahoo.com/quote/NVDA/key-statistics?p=NVDA',
 'https://finance.yahoo.com/quote/WMT/key-statistics?p=WMT',
 'https://finance.yahoo.com/quote/MCD/key-statistics?p=MCD',
 'https://finance.yahoo.com/quote/NFLX/key-statistics?p=NFLX',
 'https://finance.yahoo.com/quote/CRM/key-statistics?p=CRM',
 'https://finance.yahoo.com/quote/MDT/key-statistics?p=MDT',
 'https://finance.yahoo.com/quote/BMY/key-statistics?p=BMY',
 'https://finance.yahoo.com/quote/ABT/key-statistics?p=ABT',
 'https://finance.yahoo.com/quote/PYPL/key-statistics?p=PYPL',
 'https://finance.yahoo.com/quote/COST/key-statistics?p=COST',
 'https://finance.yahoo.com/quote/ABBV/key-statistics?p=ABBV',
 'https://finance.yahoo.com/quote/PM/key-statistics?p=PM',
 'https://finance.yahoo.com/quote/NEE/key-statistics?p=NEE',
 'https://finance.yahoo.com/quote/ACN/key-statistics?p=ACN',
 'https://finance.yahoo.com/quote/TMO/key-statistics?p=TMO',
 'https://finance.yahoo.com/quote/AMGN/key-statistics?p=AMGN',
 'https://finance.yahoo.com/quote/IBM/key-statistics?p=IBM',
 'https://finance.yahoo.com/quote/HON/key-statistics?p=HON',
 'https://finance.yahoo.com/quote/UNP/key-statistics?p=UNP',
 'https://finance.yahoo.com/quote/NKE/key-statistics?p=NKE',
 'https://finance.yahoo.com/quote/UTX/key-statistics?p=UTX',
 'https://finance.yahoo.com/quote/TXN/key-statistics?p=TXN',
 'https://finance.yahoo.com/quote/AVGO/key-statistics?p=AVGO',
 'https://finance.yahoo.com/quote/LLY/key-statistics?p=LLY',
 'https://finance.yahoo.com/quote/LIN/key-statistics?p=LIN',
 'https://finance.yahoo.com/quote/ORCL/key-statistics?p=ORCL',
 'https://finance.yahoo.com/quote/TSLA/key-statistics?p=TSLA',
 'https://finance.yahoo.com/quote/AMT/key-statistics?p=AMT',
 'https://finance.yahoo.com/quote/GE/key-statistics?p=GE',
 'https://finance.yahoo.com/quote/LMT/key-statistics?p=LMT',
 'https://finance.yahoo.com/quote/SBUX/key-statistics?p=SBUX',
 'https://finance.yahoo.com/quote/DHR/key-statistics?p=DHR',
 'https://finance.yahoo.com/quote/QCOM/key-statistics?p=QCOM',
 'https://finance.yahoo.com/quote/LOW/key-statistics?p=LOW',
 'https://finance.yahoo.com/quote/FIS/key-statistics?p=FIS',
 'https://finance.yahoo.com/quote/CVS/key-statistics?p=CVS',
 'https://finance.yahoo.com/quote/AXP/key-statistics?p=AXP',
 'https://finance.yahoo.com/quote/MMM/key-statistics?p=MMM',
 'https://finance.yahoo.com/quote/GILD/key-statistics?p=GILD',
 'https://finance.yahoo.com/quote/MDLZ/key-statistics?p=MDLZ',
 'https://finance.yahoo.com/quote/MO/key-statistics?p=MO',
 'https://finance.yahoo.com/quote/BKNG/key-statistics?p=BKNG',
 'https://finance.yahoo.com/quote/CHTR/key-statistics?p=CHTR',
 'https://finance.yahoo.com/quote/CI/key-statistics?p=CI',
 'https://finance.yahoo.com/quote/ADP/key-statistics?p=ADP',
 'https://finance.yahoo.com/quote/USB/key-statistics?p=USB',
 'https://finance.yahoo.com/quote/TJX/key-statistics?p=TJX',
 'https://finance.yahoo.com/quote/SYK/key-statistics?p=SYK',
 'https://finance.yahoo.com/quote/INTU/key-statistics?p=INTU',
 'https://finance.yahoo.com/quote/SPGI/key-statistics?p=SPGI',
 'https://finance.yahoo.com/quote/ANTM/key-statistics?p=ANTM',
 'https://finance.yahoo.com/quote/CME/key-statistics?p=CME',
 'https://finance.yahoo.com/quote/GS/key-statistics?p=GS',
 'https://finance.yahoo.com/quote/CB/key-statistics?p=CB',
 'https://finance.yahoo.com/quote/CAT/key-statistics?p=CAT',
 'https://finance.yahoo.com/quote/UPS/key-statistics?p=UPS',
 'https://finance.yahoo.com/quote/DUK/key-statistics?p=DUK',
 'https://finance.yahoo.com/quote/TFC/key-statistics?p=TFC',
 'https://finance.yahoo.com/quote/SO/key-statistics?p=SO',
 'https://finance.yahoo.com/quote/D/key-statistics?p=D',
 'https://finance.yahoo.com/quote/PLD/key-statistics?p=PLD',
 'https://finance.yahoo.com/quote/BDX/key-statistics?p=BDX',
 'https://finance.yahoo.com/quote/ISRG/key-statistics?p=ISRG',
 'https://finance.yahoo.com/quote/ZTS/key-statistics?p=ZTS',
 'https://finance.yahoo.com/quote/FISV/key-statistics?p=FISV',
 'https://finance.yahoo.com/quote/CCI/key-statistics?p=CCI',
 'https://finance.yahoo.com/quote/PNC/key-statistics?p=PNC',
 'https://finance.yahoo.com/quote/BLK/key-statistics?p=BLK',
 'https://finance.yahoo.com/quote/NOW/key-statistics?p=NOW',
 'https://finance.yahoo.com/quote/AGN/key-statistics?p=AGN',
 'https://finance.yahoo.com/quote/MS/key-statistics?p=MS',
 'https://finance.yahoo.com/quote/MU/key-statistics?p=MU',
 'https://finance.yahoo.com/quote/CL/key-statistics?p=CL',
 'https://finance.yahoo.com/quote/COP/key-statistics?p=COP',
 'https://finance.yahoo.com/quote/RTN/key-statistics?p=RTN',
 'https://finance.yahoo.com/quote/VRTX/key-statistics?p=VRTX',
 'https://finance.yahoo.com/quote/AMAT/key-statistics?p=AMAT',
 'https://finance.yahoo.com/quote/GPN/key-statistics?p=GPN',
 'https://finance.yahoo.com/quote/MMC/key-statistics?p=MMC',
 'https://finance.yahoo.com/quote/ITW/key-statistics?p=ITW',
 'https://finance.yahoo.com/quote/BIIB/key-statistics?p=BIIB',
 'https://finance.yahoo.com/quote/CSX/key-statistics?p=CSX',
 'https://finance.yahoo.com/quote/BSX/key-statistics?p=BSX',
 'https://finance.yahoo.com/quote/NOC/key-statistics?p=NOC',
 'https://finance.yahoo.com/quote/TGT/key-statistics?p=TGT',
 'https://finance.yahoo.com/quote/AMD/key-statistics?p=AMD',
 'https://finance.yahoo.com/quote/APD/key-statistics?p=APD',
 'https://finance.yahoo.com/quote/AON/key-statistics?p=AON',
 'https://finance.yahoo.com/quote/EQIX/key-statistics?p=EQIX',
 'https://finance.yahoo.com/quote/NSC/key-statistics?p=NSC',
 'https://finance.yahoo.com/quote/SCHW/key-statistics?p=SCHW',
 'https://finance.yahoo.com/quote/WM/key-statistics?p=WM',
 'https://finance.yahoo.com/quote/ICE/key-statistics?p=ICE',
 'https://finance.yahoo.com/quote/DE/key-statistics?p=DE',
 'https://finance.yahoo.com/quote/ECL/key-statistics?p=ECL',
 'https://finance.yahoo.com/quote/AEP/key-statistics?p=AEP',
 'https://finance.yahoo.com/quote/LHX/key-statistics?p=LHX',
 'https://finance.yahoo.com/quote/KMB/key-statistics?p=KMB',
 'https://finance.yahoo.com/quote/HUM/key-statistics?p=HUM',
 'https://finance.yahoo.com/quote/PGR/key-statistics?p=PGR',
 'https://finance.yahoo.com/quote/LRCX/key-statistics?p=LRCX',
 'https://finance.yahoo.com/quote/SHW/key-statistics?p=SHW']

# %%
url_list_2 = [ 'https://finance.yahoo.com/quote/EXC/key-statistics?p=EXC',
 'https://finance.yahoo.com/quote/ATVI/key-statistics?p=ATVI',
 'https://finance.yahoo.com/quote/GD/key-statistics?p=GD',
 'https://finance.yahoo.com/quote/COF/key-statistics?p=COF',
 'https://finance.yahoo.com/quote/EW/key-statistics?p=EW',
 'https://finance.yahoo.com/quote/SLB/key-statistics?p=SLB',
 'https://finance.yahoo.com/quote/EL/key-statistics?p=EL',
 'https://finance.yahoo.com/quote/ADSK/key-statistics?p=ADSK',
 'https://finance.yahoo.com/quote/MCO/key-statistics?p=MCO',
 'https://finance.yahoo.com/quote/SRE/key-statistics?p=SRE',
 'https://finance.yahoo.com/quote/BAX/key-statistics?p=BAX',
 'https://finance.yahoo.com/quote/EMR/key-statistics?p=EMR',
 'https://finance.yahoo.com/quote/ILMN/key-statistics?p=ILMN',
 'https://finance.yahoo.com/quote/EOG/key-statistics?p=EOG',
 'https://finance.yahoo.com/quote/GM/key-statistics?p=GM',
 'https://finance.yahoo.com/quote/ADI/key-statistics?p=ADI',
 'https://finance.yahoo.com/quote/ROST/key-statistics?p=ROST',
 'https://finance.yahoo.com/quote/KMI/key-statistics?p=KMI',
 'https://finance.yahoo.com/quote/SPG/key-statistics?p=SPG',
 'https://finance.yahoo.com/quote/ETN/key-statistics?p=ETN',
 'https://finance.yahoo.com/quote/AIG/key-statistics?p=AIG',
 'https://finance.yahoo.com/quote/DG/key-statistics?p=DG',
 'https://finance.yahoo.com/quote/MET/key-statistics?p=MET',
 'https://finance.yahoo.com/quote/ALL/key-statistics?p=ALL',
 'https://finance.yahoo.com/quote/HCA/key-statistics?p=HCA',
 'https://finance.yahoo.com/quote/ROP/key-statistics?p=ROP',
 'https://finance.yahoo.com/quote/PSX/key-statistics?p=PSX',
 'https://finance.yahoo.com/quote/WBA/key-statistics?p=WBA',
 'https://finance.yahoo.com/quote/MAR/key-statistics?p=MAR',
 'https://finance.yahoo.com/quote/DD/key-statistics?p=DD',
 'https://finance.yahoo.com/quote/AFL/key-statistics?p=AFL',
 'https://finance.yahoo.com/quote/PRU/key-statistics?p=PRU',
 'https://finance.yahoo.com/quote/FDX/key-statistics?p=FDX',
 'https://finance.yahoo.com/quote/CNC/key-statistics?p=CNC',
 'https://finance.yahoo.com/quote/UBER/key-statistics?p=UBER',
 'https://finance.yahoo.com/quote/BK/key-statistics?p=BK',
 'https://finance.yahoo.com/quote/CTSH/key-statistics?p=CTSH',
 'https://finance.yahoo.com/quote/MPC/key-statistics?p=MPC',
 'https://finance.yahoo.com/quote/OXY/key-statistics?p=OXY',
 'https://finance.yahoo.com/quote/SYY/key-statistics?p=SYY',
 'https://finance.yahoo.com/quote/XEL/key-statistics?p=XEL',
 'https://finance.yahoo.com/quote/DOW/key-statistics?p=DOW',
 'https://finance.yahoo.com/quote/NEM/key-statistics?p=NEM',
 'https://finance.yahoo.com/quote/WELL/key-statistics?p=WELL',
 'https://finance.yahoo.com/quote/TRV/key-statistics?p=TRV',
 'https://finance.yahoo.com/quote/IR/key-statistics?p=IR',
 'https://finance.yahoo.com/quote/PSA/key-statistics?p=PSA',
 'https://finance.yahoo.com/quote/DAL/key-statistics?p=DAL',
 'https://finance.yahoo.com/quote/VLO/key-statistics?p=VLO',
 'https://finance.yahoo.com/quote/SBAC/key-statistics?p=SBAC',
 'https://finance.yahoo.com/quote/HPQ/key-statistics?p=HPQ',
 'https://finance.yahoo.com/quote/ZBH/key-statistics?p=ZBH',
 'https://finance.yahoo.com/quote/REGN/key-statistics?p=REGN',
 'https://finance.yahoo.com/quote/JCI/key-statistics?p=JCI',
 'https://finance.yahoo.com/quote/WEC/key-statistics?p=WEC',
 'https://finance.yahoo.com/quote/STZ/key-statistics?p=STZ',
 'https://finance.yahoo.com/quote/WDAY/key-statistics?p=WDAY',
 'https://finance.yahoo.com/quote/INFO/key-statistics?p=INFO',
 'https://finance.yahoo.com/quote/TDG/key-statistics?p=TDG',
 'https://finance.yahoo.com/quote/GIS/key-statistics?p=GIS',
 'https://finance.yahoo.com/quote/AVB/key-statistics?p=AVB',
 'https://finance.yahoo.com/quote/EA/key-statistics?p=EA',
 'https://finance.yahoo.com/quote/OKE/key-statistics?p=OKE',
 'https://finance.yahoo.com/quote/EQR/key-statistics?p=EQR',
 'https://finance.yahoo.com/quote/F/key-statistics?p=F',
 'https://finance.yahoo.com/quote/YUM/key-statistics?p=YUM',
 'https://finance.yahoo.com/quote/MSI/key-statistics?p=MSI',
 'https://finance.yahoo.com/quote/HLT/key-statistics?p=HLT',
 'https://finance.yahoo.com/quote/ED/key-statistics?p=ED',
 'https://finance.yahoo.com/quote/TROW/key-statistics?p=TROW',
 'https://finance.yahoo.com/quote/APH/key-statistics?p=APH',
 'https://finance.yahoo.com/quote/ES/key-statistics?p=ES',
 'https://finance.yahoo.com/quote/TMUS/key-statistics?p=TMUS',
 'https://finance.yahoo.com/quote/MCK/key-statistics?p=MCK',
 'https://finance.yahoo.com/quote/LULU/key-statistics?p=LULU',
 'https://finance.yahoo.com/quote/PEG/key-statistics?p=PEG',
 'https://finance.yahoo.com/quote/EBAY/key-statistics?p=EBAY',
 'https://finance.yahoo.com/quote/ORLY/key-statistics?p=ORLY',
 'https://finance.yahoo.com/quote/IQV/key-statistics?p=IQV',
 'https://finance.yahoo.com/quote/PAYX/key-statistics?p=PAYX',
 'https://finance.yahoo.com/quote/PPG/key-statistics?p=PPG',
 'https://finance.yahoo.com/quote/STT/key-statistics?p=STT',
 'https://finance.yahoo.com/quote/FE/key-statistics?p=FE',
 'https://finance.yahoo.com/quote/SQ/key-statistics?p=SQ',
 'https://finance.yahoo.com/quote/TWTR/key-statistics?p=TWTR',
 'https://finance.yahoo.com/quote/KLAC/key-statistics?p=KLAC',
 'https://finance.yahoo.com/quote/VRSK/key-statistics?p=VRSK',
 'https://finance.yahoo.com/quote/DLR/key-statistics?p=DLR',
 'https://finance.yahoo.com/quote/LUV/key-statistics?p=LUV',
 'https://finance.yahoo.com/quote/WLTW/key-statistics?p=WLTW',
 'https://finance.yahoo.com/quote/FLT/key-statistics?p=FLT',
 'https://finance.yahoo.com/quote/PH/key-statistics?p=PH',
 'https://finance.yahoo.com/quote/EIX/key-statistics?p=EIX',
 'https://finance.yahoo.com/quote/MSCI/key-statistics?p=MSCI',
 'https://finance.yahoo.com/quote/ETR/key-statistics?p=ETR',
 'https://finance.yahoo.com/quote/A/key-statistics?p=A',
 'https://finance.yahoo.com/quote/SPLK/key-statistics?p=SPLK',
 'https://finance.yahoo.com/quote/MNST/key-statistics?p=MNST',
 'https://finance.yahoo.com/quote/CSGP/key-statistics?p=CSGP',
 'https://finance.yahoo.com/quote/O/key-statistics?p=O',
 'https://finance.yahoo.com/quote/WMB/key-statistics?p=WMB',
 'https://finance.yahoo.com/quote/DXCM/key-statistics?p=DXCM',
 'https://finance.yahoo.com/quote/VFC/key-statistics?p=VFC',
 'https://finance.yahoo.com/quote/PPL/key-statistics?p=PPL',
 'https://finance.yahoo.com/quote/SWK/key-statistics?p=SWK',
 'https://finance.yahoo.com/quote/MCHP/key-statistics?p=MCHP',
 'https://finance.yahoo.com/quote/AWK/key-statistics?p=AWK',
 'https://finance.yahoo.com/quote/PCAR/key-statistics?p=PCAR',
 'https://finance.yahoo.com/quote/CTAS/key-statistics?p=CTAS',
 'https://finance.yahoo.com/quote/RMD/key-statistics?p=RMD',
 'https://finance.yahoo.com/quote/ADM/key-statistics?p=ADM',
 'https://finance.yahoo.com/quote/BLL/key-statistics?p=BLL',
 'https://finance.yahoo.com/quote/AZO/key-statistics?p=AZO',
 'https://finance.yahoo.com/quote/CMI/key-statistics?p=CMI',
 'https://finance.yahoo.com/quote/DTE/key-statistics?p=DTE',
 'https://finance.yahoo.com/quote/IDXX/key-statistics?p=IDXX',
 'https://finance.yahoo.com/quote/ANSS/key-statistics?p=ANSS',
 'https://finance.yahoo.com/quote/SNPS/key-statistics?p=SNPS',
 'https://finance.yahoo.com/quote/CERN/key-statistics?p=CERN',
 'https://finance.yahoo.com/quote/DFS/key-statistics?p=DFS',
 'https://finance.yahoo.com/quote/CMG/key-statistics?p=CMG',
 'https://finance.yahoo.com/quote/PANW/key-statistics?p=PANW',
 'https://finance.yahoo.com/quote/LVS/key-statistics?p=LVS',
 'https://finance.yahoo.com/quote/HSY/key-statistics?p=HSY',
 'https://finance.yahoo.com/quote/TSN/key-statistics?p=TSN',
 'https://finance.yahoo.com/quote/AME/key-statistics?p=AME',
 'https://finance.yahoo.com/quote/CTVA/key-statistics?p=CTVA',
 'https://finance.yahoo.com/quote/XLNX/key-statistics?p=XLNX',
 'https://finance.yahoo.com/quote/WY/key-statistics?p=WY',
 'https://finance.yahoo.com/quote/FTV/key-statistics?p=FTV',
 'https://finance.yahoo.com/quote/ROK/key-statistics?p=ROK',
 'https://finance.yahoo.com/quote/PXD/key-statistics?p=PXD',
 'https://finance.yahoo.com/quote/APTV/key-statistics?p=APTV',
 'https://finance.yahoo.com/quote/BXP/key-statistics?p=BXP',
 'https://finance.yahoo.com/quote/AMP/key-statistics?p=AMP',
 'https://finance.yahoo.com/quote/KR/key-statistics?p=KR',
 'https://finance.yahoo.com/quote/MTB/key-statistics?p=MTB',
 'https://finance.yahoo.com/quote/VTR/key-statistics?p=VTR',
 'https://finance.yahoo.com/quote/FAST/key-statistics?p=FAST',
 'https://finance.yahoo.com/quote/LYB/key-statistics?p=LYB',
 'https://finance.yahoo.com/quote/CDNS/key-statistics?p=CDNS',
 'https://finance.yahoo.com/quote/SYF/key-statistics?p=SYF',
 'https://finance.yahoo.com/quote/ALXN/key-statistics?p=ALXN',
 'https://finance.yahoo.com/quote/GLW/key-statistics?p=GLW',
 'https://finance.yahoo.com/quote/RSG/key-statistics?p=RSG',
 'https://finance.yahoo.com/quote/CBRE/key-statistics?p=CBRE',
 'https://finance.yahoo.com/quote/AEE/key-statistics?p=AEE',
 'https://finance.yahoo.com/quote/VRSN/key-statistics?p=VRSN',
 'https://finance.yahoo.com/quote/ALGN/key-statistics?p=ALGN',
 'https://finance.yahoo.com/quote/ESS/key-statistics?p=ESS',
 'https://finance.yahoo.com/quote/HIG/key-statistics?p=HIG',
 'https://finance.yahoo.com/quote/VEEV/key-statistics?p=VEEV',
 'https://finance.yahoo.com/quote/DLTR/key-statistics?p=DLTR',
 'https://finance.yahoo.com/quote/FITB/key-statistics?p=FITB',
 'https://finance.yahoo.com/quote/DHI/key-statistics?p=DHI',
 'https://finance.yahoo.com/quote/CPRT/key-statistics?p=CPRT',
 'https://finance.yahoo.com/quote/CLX/key-statistics?p=CLX',
 'https://finance.yahoo.com/quote/WDC/key-statistics?p=WDC',
 'https://finance.yahoo.com/quote/MKC/key-statistics?p=MKC',
 'https://finance.yahoo.com/quote/BBY/key-statistics?p=BBY',
 'https://finance.yahoo.com/quote/AJG/key-statistics?p=AJG',
 'https://finance.yahoo.com/quote/SWKS/key-statistics?p=SWKS',
 'https://finance.yahoo.com/quote/EFX/key-statistics?p=EFX',
 'https://finance.yahoo.com/quote/ARE/key-statistics?p=ARE',
 'https://finance.yahoo.com/quote/CDW/key-statistics?p=CDW',
 'https://finance.yahoo.com/quote/FRC/key-statistics?p=FRC',
 'https://finance.yahoo.com/quote/CMS/key-statistics?p=CMS',
 'https://finance.yahoo.com/quote/VMC/key-statistics?p=VMC',
 'https://finance.yahoo.com/quote/NTRS/key-statistics?p=NTRS',
 'https://finance.yahoo.com/quote/RCL/key-statistics?p=RCL',
 'https://finance.yahoo.com/quote/KEY/key-statistics?p=KEY',
 'https://finance.yahoo.com/quote/LEN/key-statistics?p=LEN',
 'https://finance.yahoo.com/quote/HAL/key-statistics?p=HAL',
 'https://finance.yahoo.com/quote/VIAC/key-statistics?p=VIAC',
 'https://finance.yahoo.com/quote/HPE/key-statistics?p=HPE',
 'https://finance.yahoo.com/quote/CHD/key-statistics?p=CHD',
 'https://finance.yahoo.com/quote/LH/key-statistics?p=LH',
 'https://finance.yahoo.com/quote/PEAK/key-statistics?p=PEAK',
 'https://finance.yahoo.com/quote/KEYS/key-statistics?p=KEYS',
 'https://finance.yahoo.com/quote/TRU/key-statistics?p=TRU',
 'https://finance.yahoo.com/quote/ACGL/key-statistics?p=ACGL',
 'https://finance.yahoo.com/quote/UAL/key-statistics?p=UAL',
 'https://finance.yahoo.com/quote/MTD/key-statistics?p=MTD',
 'https://finance.yahoo.com/quote/TEAM/key-statistics?p=TEAM',
 'https://finance.yahoo.com/quote/MKL/key-statistics?p=MKL',
 'https://finance.yahoo.com/quote/RNG/key-statistics?p=RNG',
 'https://finance.yahoo.com/quote/FCX/key-statistics?p=FCX',
 'https://finance.yahoo.com/quote/IAC/key-statistics?p=IAC',
 'https://finance.yahoo.com/quote/INVH/key-statistics?p=INVH',
 'https://finance.yahoo.com/quote/TFX/key-statistics?p=TFX',
 'https://finance.yahoo.com/quote/COO/key-statistics?p=COO',
 'https://finance.yahoo.com/quote/MXIM/key-statistics?p=MXIM',
 'https://finance.yahoo.com/quote/CINF/key-statistics?p=CINF',
 'https://finance.yahoo.com/quote/FTNT/key-statistics?p=FTNT',
 'https://finance.yahoo.com/quote/CAH/key-statistics?p=CAH',
 'https://finance.yahoo.com/quote/EXPE/key-statistics?p=EXPE',
 'https://finance.yahoo.com/quote/CCL/key-statistics?p=CCL',
 'https://finance.yahoo.com/quote/DOV/key-statistics?p=DOV',
 'https://finance.yahoo.com/quote/KSU/key-statistics?p=KSU',
 'https://finance.yahoo.com/quote/K/key-statistics?p=K',
 'https://finance.yahoo.com/quote/KHC/key-statistics?p=KHC',
 'https://finance.yahoo.com/quote/ULTA/key-statistics?p=ULTA',
 'https://finance.yahoo.com/quote/CFG/key-statistics?p=CFG',
 'https://finance.yahoo.com/quote/SPOT/key-statistics?p=SPOT',
 'https://finance.yahoo.com/quote/IP/key-statistics?p=IP',
 'https://finance.yahoo.com/quote/MRVL/key-statistics?p=MRVL',
 'https://finance.yahoo.com/quote/MAA/key-statistics?p=MAA',]

# %%
 url_list_3 = ['https://finance.yahoo.com/quote/MLM/key-statistics?p=MLM',
 'https://finance.yahoo.com/quote/OMC/key-statistics?p=OMC',
 'https://finance.yahoo.com/quote/YUMC/key-statistics?p=YUMC',
 'https://finance.yahoo.com/quote/EVRG/key-statistics?p=EVRG',
 'https://finance.yahoo.com/quote/HES/key-statistics?p=HES',
 'https://finance.yahoo.com/quote/KMX/key-statistics?p=KMX',
 'https://finance.yahoo.com/quote/BMRN/key-statistics?p=BMRN',
 'https://finance.yahoo.com/quote/TIF/key-statistics?p=TIF',
 'https://finance.yahoo.com/quote/RF/key-statistics?p=RF',
 'https://finance.yahoo.com/quote/XYL/key-statistics?p=XYL',
 'https://finance.yahoo.com/quote/BURL/key-statistics?p=BURL',
 'https://finance.yahoo.com/quote/TWLO/key-statistics?p=TWLO',
 'https://finance.yahoo.com/quote/CXO/key-statistics?p=CXO',
 'https://finance.yahoo.com/quote/MGM/key-statistics?p=MGM',
 'https://finance.yahoo.com/quote/AKAM/key-statistics?p=AKAM',
 'https://finance.yahoo.com/quote/CAG/key-statistics?p=CAG',
 'https://finance.yahoo.com/quote/PAYC/key-statistics?p=PAYC',
 'https://finance.yahoo.com/quote/CTL/key-statistics?p=CTL',
 'https://finance.yahoo.com/quote/PFG/key-statistics?p=PFG',
 'https://finance.yahoo.com/quote/DGX/key-statistics?p=DGX',
 'https://finance.yahoo.com/quote/SUI/key-statistics?p=SUI',
 'https://finance.yahoo.com/quote/CTXS/key-statistics?p=CTXS',
 'https://finance.yahoo.com/quote/DRI/key-statistics?p=DRI',
 'https://finance.yahoo.com/quote/LDOS/key-statistics?p=LDOS',
 'https://finance.yahoo.com/quote/SSNC/key-statistics?p=SSNC',
 'https://finance.yahoo.com/quote/WPC/key-statistics?p=WPC',
 'https://finance.yahoo.com/quote/IFF/key-statistics?p=IFF',
 'https://finance.yahoo.com/quote/ODFL/key-statistics?p=ODFL',
 'https://finance.yahoo.com/quote/NLY/key-statistics?p=NLY',
 'https://finance.yahoo.com/quote/LBRDK/key-statistics?p=LBRDK',
 'https://finance.yahoo.com/quote/UDR/key-statistics?p=UDR',
 'https://finance.yahoo.com/quote/NUE/key-statistics?p=NUE',
 'https://finance.yahoo.com/quote/EXR/key-statistics?p=EXR',
 'https://finance.yahoo.com/quote/LNT/key-statistics?p=LNT',
 'https://finance.yahoo.com/quote/GRMN/key-statistics?p=GRMN',
 'https://finance.yahoo.com/quote/HBAN/key-statistics?p=HBAN',
 'https://finance.yahoo.com/quote/HOLX/key-statistics?p=HOLX',
 'https://finance.yahoo.com/quote/OKTA/key-statistics?p=OKTA',
 'https://finance.yahoo.com/quote/ABC/key-statistics?p=ABC',
 'https://finance.yahoo.com/quote/BKR/key-statistics?p=BKR',
 'https://finance.yahoo.com/quote/STE/key-statistics?p=STE',
 'https://finance.yahoo.com/quote/ATO/key-statistics?p=ATO',
 'https://finance.yahoo.com/quote/TDY/key-statistics?p=TDY',
 'https://finance.yahoo.com/quote/AES/key-statistics?p=AES',
 'https://finance.yahoo.com/quote/DRE/key-statistics?p=DRE',
 'https://finance.yahoo.com/quote/LW/key-statistics?p=LW',
 'https://finance.yahoo.com/quote/INCY/key-statistics?p=INCY',
 'https://finance.yahoo.com/quote/WAB/key-statistics?p=WAB',
 'https://finance.yahoo.com/quote/EXAS/key-statistics?p=EXAS',
 'https://finance.yahoo.com/quote/SIVB/key-statistics?p=SIVB',
 'https://finance.yahoo.com/quote/BR/key-statistics?p=BR',
 'https://finance.yahoo.com/quote/DOCU/key-statistics?p=DOCU',
 'https://finance.yahoo.com/quote/ALNY/key-statistics?p=ALNY',
 'https://finance.yahoo.com/quote/L/key-statistics?p=L',
 'https://finance.yahoo.com/quote/HRL/key-statistics?p=HRL',
 'https://finance.yahoo.com/quote/WAT/key-statistics?p=WAT',
 'https://finance.yahoo.com/quote/VAR/key-statistics?p=VAR',
 'https://finance.yahoo.com/quote/SGEN/key-statistics?p=SGEN',
 'https://finance.yahoo.com/quote/J/key-statistics?p=J',
 'https://finance.yahoo.com/quote/ANET/key-statistics?p=ANET',
 'https://finance.yahoo.com/quote/FMC/key-statistics?p=FMC',
 'https://finance.yahoo.com/quote/CNP/key-statistics?p=CNP',
 'https://finance.yahoo.com/quote/GPC/key-statistics?p=GPC',
 'https://finance.yahoo.com/quote/NDAQ/key-statistics?p=NDAQ',
 'https://finance.yahoo.com/quote/GDDY/key-statistics?p=GDDY',
 'https://finance.yahoo.com/quote/GWW/key-statistics?p=GWW',
 'https://finance.yahoo.com/quote/FOXA/key-statistics?p=FOXA',
 'https://finance.yahoo.com/quote/NVR/key-statistics?p=NVR',
 'https://finance.yahoo.com/quote/TYL/key-statistics?p=TYL',
 'https://finance.yahoo.com/quote/IEX/key-statistics?p=IEX',
 'https://finance.yahoo.com/quote/JKHY/key-statistics?p=JKHY',
 'https://finance.yahoo.com/quote/ALLE/key-statistics?p=ALLE',
 'https://finance.yahoo.com/quote/CE/key-statistics?p=CE',
 'https://finance.yahoo.com/quote/AMTD/key-statistics?p=AMTD',
 'https://finance.yahoo.com/quote/WYNN/key-statistics?p=WYNN',
 'https://finance.yahoo.com/quote/XRAY/key-statistics?p=XRAY',
 'https://finance.yahoo.com/quote/IT/key-statistics?p=IT',
 'https://finance.yahoo.com/quote/ELS/key-statistics?p=ELS',
 'https://finance.yahoo.com/quote/ZBRA/key-statistics?p=ZBRA',
 'https://finance.yahoo.com/quote/VICI/key-statistics?p=VICI',
 'https://finance.yahoo.com/quote/NTAP/key-statistics?p=NTAP',
 'https://finance.yahoo.com/quote/MAS/key-statistics?p=MAS',
 'https://finance.yahoo.com/quote/PODD/key-statistics?p=PODD',
 'https://finance.yahoo.com/quote/MKTX/key-statistics?p=MKTX',
 'https://finance.yahoo.com/quote/TTWO/key-statistics?p=TTWO',
 'https://finance.yahoo.com/quote/ARNC/key-statistics?p=ARNC',
 'https://finance.yahoo.com/quote/WST/key-statistics?p=WST',
 'https://finance.yahoo.com/quote/EXPD/key-statistics?p=EXPD',
 'https://finance.yahoo.com/quote/EPAM/key-statistics?p=EPAM',
 'https://finance.yahoo.com/quote/ALLY/key-statistics?p=ALLY',
 'https://finance.yahoo.com/quote/BFB/key-statistics?p=BFB',
 'https://finance.yahoo.com/quote/RJF/key-statistics?p=RJF',
 'https://finance.yahoo.com/quote/HAS/key-statistics?p=HAS', ##thisone
 'https://finance.yahoo.com/quote/MPW/key-statistics?p=MPW',
 'https://finance.yahoo.com/quote/SJM/key-statistics?p=SJM',
 'https://finance.yahoo.com/quote/ELAN/key-statistics?p=ELAN',
 'https://finance.yahoo.com/quote/QRVO/key-statistics?p=QRVO',
 'https://finance.yahoo.com/quote/NLOK/key-statistics?p=NLOK',
 'https://finance.yahoo.com/quote/VMW/key-statistics?p=VMW',
 'https://finance.yahoo.com/quote/TTD/key-statistics?p=TTD',
 'https://finance.yahoo.com/quote/FANG/key-statistics?p=FANG',
 'https://finance.yahoo.com/quote/VNO/key-statistics?p=VNO',
 'https://finance.yahoo.com/quote/LNC/key-statistics?p=LNC',
 'https://finance.yahoo.com/quote/WTRG/key-statistics?p=WTRG',
 'https://finance.yahoo.com/quote/HST/key-statistics?p=HST',
 'https://finance.yahoo.com/quote/FICO/key-statistics?p=FICO',
 'https://finance.yahoo.com/quote/DPZ/key-statistics?p=DPZ',
 'https://finance.yahoo.com/quote/FNF/key-statistics?p=FNF',
 'https://finance.yahoo.com/quote/URI/key-statistics?p=URI',
 'https://finance.yahoo.com/quote/GL/key-statistics?p=GL',
 'https://finance.yahoo.com/quote/TRMB/key-statistics?p=TRMB',
 'https://finance.yahoo.com/quote/TER/key-statistics?p=TER',
 'https://finance.yahoo.com/quote/PNW/key-statistics?p=PNW',
 'https://finance.yahoo.com/quote/MYL/key-statistics?p=MYL',
 'https://finance.yahoo.com/quote/NI/key-statistics?p=NI',
 'https://finance.yahoo.com/quote/PHM/key-statistics?p=PHM',
 'https://finance.yahoo.com/quote/Y/key-statistics?p=Y',
 'https://finance.yahoo.com/quote/FDS/key-statistics?p=FDS',
 'https://finance.yahoo.com/quote/RE/key-statistics?p=RE',
 'https://finance.yahoo.com/quote/AVY/key-statistics?p=AVY',
 'https://finance.yahoo.com/quote/TSCO/key-statistics?p=TSCO',
 'https://finance.yahoo.com/quote/AAL/key-statistics?p=AAL',
 'https://finance.yahoo.com/quote/EQH/key-statistics?p=EQH',
 'https://finance.yahoo.com/quote/WRB/key-statistics?p=WRB',
 'https://finance.yahoo.com/quote/ROKU/key-statistics?p=ROKU',
 'https://finance.yahoo.com/quote/TXT/key-statistics?p=TXT',
 'https://finance.yahoo.com/quote/BRO/key-statistics?p=BRO',
 'https://finance.yahoo.com/quote/CPT/key-statistics?p=CPT',
 'https://finance.yahoo.com/quote/UHS/key-statistics?p=UHS',
 'https://finance.yahoo.com/quote/WU/key-statistics?p=WU',
 'https://finance.yahoo.com/quote/BKI/key-statistics?p=BKI',
 'https://finance.yahoo.com/quote/NCLH/key-statistics?p=NCLH',
 'https://finance.yahoo.com/quote/VER/key-statistics?p=VER',
 'https://finance.yahoo.com/quote/REG/key-statistics?p=REG',
 'https://finance.yahoo.com/quote/COUP/key-statistics?p=COUP',
 'https://finance.yahoo.com/quote/HSIC/key-statistics?p=HSIC',
 'https://finance.yahoo.com/quote/BAH/key-statistics?p=BAH',
 'https://finance.yahoo.com/quote/FBHS/key-statistics?p=FBHS',
 'https://finance.yahoo.com/quote/CCK/key-statistics?p=CCK',
 'https://finance.yahoo.com/quote/LKQ/key-statistics?p=LKQ',
 'https://finance.yahoo.com/quote/NDSN/key-statistics?p=NDSN',
 'https://finance.yahoo.com/quote/PKI/key-statistics?p=PKI',
 'https://finance.yahoo.com/quote/GWRE/key-statistics?p=GWRE',
 'https://finance.yahoo.com/quote/APA/key-statistics?p=APA',
 'https://finance.yahoo.com/quote/DISH/key-statistics?p=DISH',
 'https://finance.yahoo.com/quote/AGNC/key-statistics?p=AGNC',
 'https://finance.yahoo.com/quote/WEX/key-statistics?p=WEX',
 'https://finance.yahoo.com/quote/ARMK/key-statistics?p=ARMK',
 'https://finance.yahoo.com/quote/ZEN/key-statistics?p=ZEN']

# %%
url_list_4 = ['https://finance.yahoo.com/quote/SIRI/key-statistics?p=SIRI',
 'https://finance.yahoo.com/quote/NRG/key-statistics?p=NRG',
 'https://finance.yahoo.com/quote/WRK/key-statistics?p=WRK',
 'https://finance.yahoo.com/quote/EMN/key-statistics?p=EMN',
 'https://finance.yahoo.com/quote/ETFC/key-statistics?p=ETFC',
 'https://finance.yahoo.com/quote/VST/key-statistics?p=VST',
 'https://finance.yahoo.com/quote/LYV/key-statistics?p=LYV',
 'https://finance.yahoo.com/quote/MTN/key-statistics?p=MTN',
 'https://finance.yahoo.com/quote/GLPI/key-statistics?p=GLPI',
 'https://finance.yahoo.com/quote/NNN/key-statistics?p=NNN',
 'https://finance.yahoo.com/quote/FRT/key-statistics?p=FRT',
 'https://finance.yahoo.com/quote/DOX/key-statistics?p=DOX',
 'https://finance.yahoo.com/quote/OHI/key-statistics?p=OHI',
 'https://finance.yahoo.com/quote/DISCK/key-statistics?p=DISCK',
 'https://finance.yahoo.com/quote/IPG/key-statistics?p=IPG',
 'https://finance.yahoo.com/quote/HII/key-statistics?p=HII',
 'https://finance.yahoo.com/quote/TAP/key-statistics?p=TAP',
 'https://finance.yahoo.com/quote/BFAM/key-statistics?p=BFAM',
 'https://finance.yahoo.com/quote/NBIX/key-statistics?p=NBIX',
 'https://finance.yahoo.com/quote/CHRW/key-statistics?p=CHRW',
 'https://finance.yahoo.com/quote/RPM/key-statistics?p=RPM',
 'https://finance.yahoo.com/quote/ALB/key-statistics?p=ALB',
 'https://finance.yahoo.com/quote/RGA/key-statistics?p=RGA',
 'https://finance.yahoo.com/quote/OGE/key-statistics?p=OGE',
 'https://finance.yahoo.com/quote/CSL/key-statistics?p=CSL',
 'https://finance.yahoo.com/quote/PTC/key-statistics?p=PTC',
 'https://finance.yahoo.com/quote/POOL/key-statistics?p=POOL',
 'https://finance.yahoo.com/quote/CTLT/key-statistics?p=CTLT',
 'https://finance.yahoo.com/quote/GGG/key-statistics?p=GGG',
 'https://finance.yahoo.com/quote/NBL/key-statistics?p=NBL',
 'https://finance.yahoo.com/quote/IRM/key-statistics?p=IRM',
 'https://finance.yahoo.com/quote/KRC/key-statistics?p=KRC',
 'https://finance.yahoo.com/quote/JBHT/key-statistics?p=JBHT',
 'https://finance.yahoo.com/quote/WHR/key-statistics?p=WHR',
 'https://finance.yahoo.com/quote/PKG/key-statistics?p=PKG',
 'https://finance.yahoo.com/quote/SRPT/key-statistics?p=SRPT',
 'https://finance.yahoo.com/quote/FWONK/key-statistics?p=FWONK',
 'https://finance.yahoo.com/quote/MOH/key-statistics?p=MOH',
 'https://finance.yahoo.com/quote/SCI/key-statistics?p=SCI',
 'https://finance.yahoo.com/quote/CMA/key-statistics?p=CMA',
 'https://finance.yahoo.com/quote/JLL/key-statistics?p=JLL',
 'https://finance.yahoo.com/quote/XPO/key-statistics?p=XPO',
 'https://finance.yahoo.com/quote/AZPN/key-statistics?p=AZPN',
 'https://finance.yahoo.com/quote/UGI/key-statistics?p=UGI',
 'https://finance.yahoo.com/quote/MASI/key-statistics?p=MASI',
 'https://finance.yahoo.com/quote/AAP/key-statistics?p=AAP',
 'https://finance.yahoo.com/quote/CY/key-statistics?p=CY',
 'https://finance.yahoo.com/quote/LII/key-statistics?p=LII',
 'https://finance.yahoo.com/quote/ON/key-statistics?p=ON',
 'https://finance.yahoo.com/quote/DVN/key-statistics?p=DVN',
 'https://finance.yahoo.com/quote/BIO/key-statistics?p=BIO',
 'https://finance.yahoo.com/quote/CRL/key-statistics?p=CRL',
 'https://finance.yahoo.com/quote/ATUS/key-statistics?p=ATUS',
 'https://finance.yahoo.com/quote/CGNX/key-statistics?p=CGNX',
 'https://finance.yahoo.com/quote/NOV/key-statistics?p=NOV',
 'https://finance.yahoo.com/quote/PCG/key-statistics?p=PCG',
 'https://finance.yahoo.com/quote/TRGP/key-statistics?p=TRGP',
 'https://finance.yahoo.com/quote/USFD/key-statistics?p=USFD',
 'https://finance.yahoo.com/quote/STOR/key-statistics?p=STOR',
 'https://finance.yahoo.com/quote/RNR/key-statistics?p=RNR',
 'https://finance.yahoo.com/quote/SEIC/key-statistics?p=SEIC',
 'https://finance.yahoo.com/quote/LYFT/key-statistics?p=LYFT',
 'https://finance.yahoo.com/quote/DVA/key-statistics?p=DVA',
 'https://finance.yahoo.com/quote/TTC/key-statistics?p=TTC',
 'https://finance.yahoo.com/quote/G/key-statistics?p=G',
 'https://finance.yahoo.com/quote/AIZ/key-statistics?p=AIZ',
 'https://finance.yahoo.com/quote/CZR/key-statistics?p=CZR',
 'https://finance.yahoo.com/quote/SNA/key-statistics?p=SNA',
 'https://finance.yahoo.com/quote/MRO/key-statistics?p=MRO',
 'https://finance.yahoo.com/quote/CPB/key-statistics?p=CPB',
 'https://finance.yahoo.com/quote/VOYA/key-statistics?p=VOYA',
 'https://finance.yahoo.com/quote/EHC/key-statistics?p=EHC',
 'https://finance.yahoo.com/quote/HUBS/key-statistics?p=HUBS',
 'https://finance.yahoo.com/quote/CF/key-statistics?p=CF',
 'https://finance.yahoo.com/quote/LAMR/key-statistics?p=LAMR',
 'https://finance.yahoo.com/quote/ZAYO/key-statistics?p=ZAYO',
 'https://finance.yahoo.com/quote/AFG/key-statistics?p=AFG',
 'https://finance.yahoo.com/quote/HEIA/key-statistics?p=HEIA',
 'https://finance.yahoo.com/quote/ENTG/key-statistics?p=ENTG',
 'https://finance.yahoo.com/quote/AIV/key-statistics?p=AIV',
 'https://finance.yahoo.com/quote/JAZZ/key-statistics?p=JAZZ',
 'https://finance.yahoo.com/quote/KIM/key-statistics?p=KIM',
 'https://finance.yahoo.com/quote/MPWR/key-statistics?p=MPWR',
 'https://finance.yahoo.com/quote/TPR/key-statistics?p=TPR',
 'https://finance.yahoo.com/quote/QGEN/key-statistics?p=QGEN',
 'https://finance.yahoo.com/quote/TECH/key-statistics?p=TECH',
 'https://finance.yahoo.com/quote/JNPR/key-statistics?p=JNPR',
 'https://finance.yahoo.com/quote/NWL/key-statistics?p=NWL',
 'https://finance.yahoo.com/quote/NLSN/key-statistics?p=NLSN',
 'https://finance.yahoo.com/quote/MHK/key-statistics?p=MHK',
 'https://finance.yahoo.com/quote/HUBB/key-statistics?p=HUBB',
 'https://finance.yahoo.com/quote/CONE/key-statistics?p=CONE',
 'https://finance.yahoo.com/quote/DELL/key-statistics?p=DELL',
 'https://finance.yahoo.com/quote/AMH/key-statistics?p=AMH',
 'https://finance.yahoo.com/quote/ALK/key-statistics?p=ALK',
 'https://finance.yahoo.com/quote/ZION/key-statistics?p=ZION',
 'https://finance.yahoo.com/quote/FFIV/key-statistics?p=FFIV',
 'https://finance.yahoo.com/quote/CABO/key-statistics?p=CABO',
 'https://finance.yahoo.com/quote/RS/key-statistics?p=RS',
 'https://finance.yahoo.com/quote/DXC/key-statistics?p=DXC',
 'https://finance.yahoo.com/quote/IONS/key-statistics?p=IONS',
 'https://finance.yahoo.com/quote/LSXMK/key-statistics?p=LSXMK',
 'https://finance.yahoo.com/quote/GNTX/key-statistics?p=GNTX',
 'https://finance.yahoo.com/quote/BG/key-statistics?p=BG',
 'https://finance.yahoo.com/quote/ABMD/key-statistics?p=ABMD',
 'https://finance.yahoo.com/quote/ACM/key-statistics?p=ACM',
 'https://finance.yahoo.com/quote/LPLA/key-statistics?p=LPLA',
 'https://finance.yahoo.com/quote/OLED/key-statistics?p=OLED',
 'https://finance.yahoo.com/quote/COLD/key-statistics?p=COLD',
 'https://finance.yahoo.com/quote/FLIR/key-statistics?p=FLIR',
 'https://finance.yahoo.com/quote/DEI/key-statistics?p=DEI',
 'https://finance.yahoo.com/quote/EEFT/key-statistics?p=EEFT',
 'https://finance.yahoo.com/quote/HRC/key-statistics?p=HRC',
 'https://finance.yahoo.com/quote/ST/key-statistics?p=ST',
 'https://finance.yahoo.com/quote/GLIBA/key-statistics?p=GLIBA',
 'https://finance.yahoo.com/quote/SBNY/key-statistics?p=SBNY',
 'https://finance.yahoo.com/quote/SLG/key-statistics?p=SLG',
 'https://finance.yahoo.com/quote/CHE/key-statistics?p=CHE',
 'https://finance.yahoo.com/quote/LEA/key-statistics?p=LEA',
 'https://finance.yahoo.com/quote/PRGO/key-statistics?p=PRGO',
 'https://finance.yahoo.com/quote/PFPT/key-statistics?p=PFPT',
 'https://finance.yahoo.com/quote/STWD/key-statistics?p=STWD',
 'https://finance.yahoo.com/quote/PNR/key-statistics?p=PNR',
 'https://finance.yahoo.com/quote/BWA/key-statistics?p=BWA',
 'https://finance.yahoo.com/quote/ATR/key-statistics?p=ATR',
 'https://finance.yahoo.com/quote/AYX/key-statistics?p=AYX',
 'https://finance.yahoo.com/quote/PRAH/key-statistics?p=PRAH',
 'https://finance.yahoo.com/quote/MDB/key-statistics?p=MDB',
 'https://finance.yahoo.com/quote/PBCT/key-statistics?p=PBCT',
 'https://finance.yahoo.com/quote/WBC/key-statistics?p=WBC',
 'https://finance.yahoo.com/quote/POST/key-statistics?p=POST',
 'https://finance.yahoo.com/quote/EWBC/key-statistics?p=EWBC',
 'https://finance.yahoo.com/quote/CBSH/key-statistics?p=CBSH',
 'https://finance.yahoo.com/quote/CACI/key-statistics?p=CACI',
 'https://finance.yahoo.com/quote/NRZ/key-statistics?p=NRZ',
 'https://finance.yahoo.com/quote/CDAY/key-statistics?p=CDAY',
 'https://finance.yahoo.com/quote/CIEN/key-statistics?p=CIEN',
 'https://finance.yahoo.com/quote/KSS/key-statistics?p=KSS',
 'https://finance.yahoo.com/quote/FAF/key-statistics?p=FAF',
 'https://finance.yahoo.com/quote/PLNT/key-statistics?p=PLNT',
 'https://finance.yahoo.com/quote/DCI/key-statistics?p=DCI',
 'https://finance.yahoo.com/quote/OC/key-statistics?p=OC',
 'https://finance.yahoo.com/quote/HZNP/key-statistics?p=HZNP',
 'https://finance.yahoo.com/quote/ORI/key-statistics?p=ORI',
 'https://finance.yahoo.com/quote/SPR/key-statistics?p=SPR',
 'https://finance.yahoo.com/quote/NUAN/key-statistics?p=NUAN',
 'https://finance.yahoo.com/quote/IVZ/key-statistics?p=IVZ',
 'https://finance.yahoo.com/quote/ATH/key-statistics?p=ATH',
 'https://finance.yahoo.com/quote/PB/key-statistics?p=PB',
 'https://finance.yahoo.com/quote/HDS/key-statistics?p=HDS',
 'https://finance.yahoo.com/quote/WWD/key-statistics?p=WWD',
 'https://finance.yahoo.com/quote/INGR/key-statistics?p=INGR',
 'https://finance.yahoo.com/quote/RGLD/key-statistics?p=RGLD',
 'https://finance.yahoo.com/quote/BWXT/key-statistics?p=BWXT',
 'https://finance.yahoo.com/quote/XRX/key-statistics?p=XRX',
 'https://finance.yahoo.com/quote/IAA/key-statistics?p=IAA',
 'https://finance.yahoo.com/quote/NYT/key-statistics?p=NYT',
 'https://finance.yahoo.com/quote/HTA/key-statistics?p=HTA',
 'https://finance.yahoo.com/quote/MKSI/key-statistics?p=MKSI']

# %%
url_list_5 = [ 'https://finance.yahoo.com/quote/FIVE/key-statistics?p=FIVE',
 'https://finance.yahoo.com/quote/RHI/key-statistics?p=RHI',
 'https://finance.yahoo.com/quote/ACC/key-statistics?p=ACC',
 'https://finance.yahoo.com/quote/MDU/key-statistics?p=MDU',
 'https://finance.yahoo.com/quote/BEN/key-statistics?p=BEN',
 'https://finance.yahoo.com/quote/MOS/key-statistics?p=MOS',
 'https://finance.yahoo.com/quote/MIDD/key-statistics?p=MIDD',
 'https://finance.yahoo.com/quote/DNKN/key-statistics?p=DNKN',
 'https://finance.yahoo.com/quote/PVH/key-statistics?p=PVH',
 'https://finance.yahoo.com/quote/AXTA/key-statistics?p=AXTA',
 'https://finance.yahoo.com/quote/EXEL/key-statistics?p=EXEL',
 'https://finance.yahoo.com/quote/ARW/key-statistics?p=ARW',
 'https://finance.yahoo.com/quote/CASY/key-statistics?p=CASY',
 'https://finance.yahoo.com/quote/HFC/key-statistics?p=HFC',
 'https://finance.yahoo.com/quote/TCF/key-statistics?p=TCF',
 'https://finance.yahoo.com/quote/HXL/key-statistics?p=HXL',
 'https://finance.yahoo.com/quote/FLS/key-statistics?p=FLS',
 'https://finance.yahoo.com/quote/ETSY/key-statistics?p=ETSY',
 'https://finance.yahoo.com/quote/ITT/key-statistics?p=ITT',  ##thisone
 'https://finance.yahoo.com/quote/SABR/key-statistics?p=SABR',
 'https://finance.yahoo.com/quote/CUZ/key-statistics?p=CUZ',
 'https://finance.yahoo.com/quote/NTNX/key-statistics?p=NTNX',
 'https://finance.yahoo.com/quote/Z/key-statistics?p=Z',
 'https://finance.yahoo.com/quote/AOS/key-statistics?p=AOS',
 'https://finance.yahoo.com/quote/ZNGA/key-statistics?p=ZNGA',
 'https://finance.yahoo.com/quote/KDP/key-statistics?p=KDP',
 'https://finance.yahoo.com/quote/CDK/key-statistics?p=CDK',
 'https://finance.yahoo.com/quote/NATI/key-statistics?p=NATI',
 'https://finance.yahoo.com/quote/CUBE/key-statistics?p=CUBE',
 'https://finance.yahoo.com/quote/UNM/key-statistics?p=UNM',
 'https://finance.yahoo.com/quote/JEF/key-statistics?p=JEF',
 'https://finance.yahoo.com/quote/CW/key-statistics?p=CW',
 'https://finance.yahoo.com/quote/TOL/key-statistics?p=TOL',
 'https://finance.yahoo.com/quote/JBLU/key-statistics?p=JBLU',
 'https://finance.yahoo.com/quote/WSM/key-statistics?p=WSM',
 'https://finance.yahoo.com/quote/NXST/key-statistics?p=NXST',
 'https://finance.yahoo.com/quote/JBL/key-statistics?p=JBL',
 'https://finance.yahoo.com/quote/PWR/key-statistics?p=PWR',
 'https://finance.yahoo.com/quote/MSG/key-statistics?p=MSG',
 'https://finance.yahoo.com/quote/RL/key-statistics?p=RL',
 'https://finance.yahoo.com/quote/IDA/key-statistics?p=IDA',
 'https://finance.yahoo.com/quote/BRX/key-statistics?p=BRX',
 'https://finance.yahoo.com/quote/PK/key-statistics?p=PK',
 'https://finance.yahoo.com/quote/SNX/key-statistics?p=SNX',
 'https://finance.yahoo.com/quote/HPP/key-statistics?p=HPP',
 'https://finance.yahoo.com/quote/FOX/key-statistics?p=FOX',
 'https://finance.yahoo.com/quote/NWSA/key-statistics?p=NWSA',
 'https://finance.yahoo.com/quote/LEG/key-statistics?p=LEG',
 'https://finance.yahoo.com/quote/SRCL/key-statistics?p=SRCL',
 'https://finance.yahoo.com/quote/STLD/key-statistics?p=STLD',
 'https://finance.yahoo.com/quote/COG/key-statistics?p=COG',
 'https://finance.yahoo.com/quote/BERY/key-statistics?p=BERY',
 'https://finance.yahoo.com/quote/PEN/key-statistics?p=PEN',
 'https://finance.yahoo.com/quote/PII/key-statistics?p=PII',
 'https://finance.yahoo.com/quote/AVTR/key-statistics?p=AVTR',
 'https://finance.yahoo.com/quote/EPR/key-statistics?p=EPR',
 'https://finance.yahoo.com/quote/LB/key-statistics?p=LB',
 'https://finance.yahoo.com/quote/OSK/key-statistics?p=OSK',
 'https://finance.yahoo.com/quote/CFR/key-statistics?p=CFR',
 'https://finance.yahoo.com/quote/PLAN/key-statistics?p=PLAN',
 'https://finance.yahoo.com/quote/BPOP/key-statistics?p=BPOP',
 'https://finance.yahoo.com/quote/WH/key-statistics?p=WH',
 'https://finance.yahoo.com/quote/SON/key-statistics?p=SON',
 'https://finance.yahoo.com/quote/JBGS/key-statistics?p=JBGS',
 'https://finance.yahoo.com/quote/PRI/key-statistics?p=PRI',
 'https://finance.yahoo.com/quote/WAL/key-statistics?p=WAL',
 'https://finance.yahoo.com/quote/ROL/key-statistics?p=ROL',
 'https://finance.yahoo.com/quote/WSO/key-statistics?p=WSO',
 'https://finance.yahoo.com/quote/BYND/key-statistics?p=BYND',
 'https://finance.yahoo.com/quote/M/key-statistics?p=M',
 'https://finance.yahoo.com/quote/AWI/key-statistics?p=AWI',
 'https://finance.yahoo.com/quote/CREE/key-statistics?p=CREE',
 'https://finance.yahoo.com/quote/MAN/key-statistics?p=MAN',
 'https://finance.yahoo.com/quote/SERV/key-statistics?p=SERV',
 'https://finance.yahoo.com/quote/BRKR/key-statistics?p=BRKR',
 'https://finance.yahoo.com/quote/EV/key-statistics?p=EV',
 'https://finance.yahoo.com/quote/HBI/key-statistics?p=HBI',
 'https://finance.yahoo.com/quote/AXS/key-statistics?p=AXS',
 'https://finance.yahoo.com/quote/THG/key-statistics?p=THG',
 'https://finance.yahoo.com/quote/SRC/key-statistics?p=SRC',
 'https://finance.yahoo.com/quote/SEE/key-statistics?p=SEE',
 'https://finance.yahoo.com/quote/W/key-statistics?p=W',
 'https://finance.yahoo.com/quote/HE/key-statistics?p=HE',
 'https://finance.yahoo.com/quote/RP/key-statistics?p=RP',
 'https://finance.yahoo.com/quote/LECO/key-statistics?p=LECO',
 'https://finance.yahoo.com/quote/LSI/key-statistics?p=LSI',
 'https://finance.yahoo.com/quote/HOG/key-statistics?p=HOG',
 'https://finance.yahoo.com/quote/SNV/key-statistics?p=SNV',
 'https://finance.yahoo.com/quote/BLUE/key-statistics?p=BLUE',
 'https://finance.yahoo.com/quote/PCTY/key-statistics?p=PCTY',
 'https://finance.yahoo.com/quote/ASH/key-statistics?p=ASH',
 'https://finance.yahoo.com/quote/HIW/key-statistics?p=HIW',
 'https://finance.yahoo.com/quote/IPGP/key-statistics?p=IPGP',
 'https://finance.yahoo.com/quote/MANH/key-statistics?p=MANH',
 'https://finance.yahoo.com/quote/BC/key-statistics?p=BC',
 'https://finance.yahoo.com/quote/AL/key-statistics?p=AL',
 'https://finance.yahoo.com/quote/PE/key-statistics?p=PE',
 'https://finance.yahoo.com/quote/GPK/key-statistics?p=GPK',
 'https://finance.yahoo.com/quote/DISCA/key-statistics?p=DISCA',
 'https://finance.yahoo.com/quote/S/key-statistics?p=S',
 'https://finance.yahoo.com/quote/PNFP/key-statistics?p=PNFP',
 'https://finance.yahoo.com/quote/SLM/key-statistics?p=SLM',
 'https://finance.yahoo.com/quote/NYCB/key-statistics?p=NYCB',
 'https://finance.yahoo.com/quote/FHN/key-statistics?p=FHN',
 'https://finance.yahoo.com/quote/KMPR/key-statistics?p=KMPR',
 'https://finance.yahoo.com/quote/ALSN/key-statistics?p=ALSN',
 'https://finance.yahoo.com/quote/HEI/key-statistics?p=HEI',
 'https://finance.yahoo.com/quote/BHF/key-statistics?p=BHF',
 'https://finance.yahoo.com/quote/GRUB/key-statistics?p=GRUB',
 'https://finance.yahoo.com/quote/CACC/key-statistics?p=CACC',
 'https://finance.yahoo.com/quote/MAT/key-statistics?p=MAT',
 'https://finance.yahoo.com/quote/HUN/key-statistics?p=HUN',
 'https://finance.yahoo.com/quote/THO/key-statistics?p=THO',   ##thisone
 'https://finance.yahoo.com/quote/SKX/key-statistics?p=SKX',
 'https://finance.yahoo.com/quote/HHC/key-statistics?p=HHC',
 'https://finance.yahoo.com/quote/UTHR/key-statistics?p=UTHR',
 'https://finance.yahoo.com/quote/WPX/key-statistics?p=WPX',
 'https://finance.yahoo.com/quote/DLB/key-statistics?p=DLB',
 'https://finance.yahoo.com/quote/CIT/key-statistics?p=CIT',
 'https://finance.yahoo.com/quote/CLH/key-statistics?p=CLH',
 'https://finance.yahoo.com/quote/FLO/key-statistics?p=FLO',
 'https://finance.yahoo.com/quote/CRI/key-statistics?p=CRI',
 'https://finance.yahoo.com/quote/AVLR/key-statistics?p=AVLR',
 'https://finance.yahoo.com/quote/KNX/key-statistics?p=KNX',
 'https://finance.yahoo.com/quote/JWN/key-statistics?p=JWN',
 'https://finance.yahoo.com/quote/PSTG/key-statistics?p=PSTG',
 'https://finance.yahoo.com/quote/CR/key-statistics?p=CR',
 'https://finance.yahoo.com/quote/GDI/key-statistics?p=GDI',
 'https://finance.yahoo.com/quote/TPX/key-statistics?p=TPX',
 'https://finance.yahoo.com/quote/SMAR/key-statistics?p=SMAR',
 'https://finance.yahoo.com/quote/KEX/key-statistics?p=KEX',
 'https://finance.yahoo.com/quote/HP/key-statistics?p=HP',
 'https://finance.yahoo.com/quote/SMG/key-statistics?p=SMG',
 'https://finance.yahoo.com/quote/MTG/key-statistics?p=MTG',
 'https://finance.yahoo.com/quote/AYI/key-statistics?p=AYI',
 'https://finance.yahoo.com/quote/TWO/key-statistics?p=TWO',
 'https://finance.yahoo.com/quote/ICUI/key-statistics?p=ICUI',
 'https://finance.yahoo.com/quote/OUT/key-statistics?p=OUT',
 'https://finance.yahoo.com/quote/COR/key-statistics?p=COR',
 'https://finance.yahoo.com/quote/CIM/key-statistics?p=CIM',
 'https://finance.yahoo.com/quote/VVV/key-statistics?p=VVV',
 'https://finance.yahoo.com/quote/FSLR/key-statistics?p=FSLR',
 'https://finance.yahoo.com/quote/HRB/key-statistics?p=HRB',
 'https://finance.yahoo.com/quote/LOPE/key-statistics?p=LOPE',
 'https://finance.yahoo.com/quote/MRNA/key-statistics?p=MRNA',
 'https://finance.yahoo.com/quote/CVNA/key-statistics?p=CVNA',
 'https://finance.yahoo.com/quote/NCR/key-statistics?p=NCR',
 'https://finance.yahoo.com/quote/NVST/key-statistics?p=NVST',
 'https://finance.yahoo.com/quote/ERIE/key-statistics?p=ERIE',
 'https://finance.yahoo.com/quote/AGO/key-statistics?p=AGO',
 'https://finance.yahoo.com/quote/CPRI/key-statistics?p=CPRI',
 'https://finance.yahoo.com/quote/PACW/key-statistics?p=PACW',
 'https://finance.yahoo.com/quote/EQC/key-statistics?p=EQC',
 'https://finance.yahoo.com/quote/GPS/key-statistics?p=GPS',
 'https://finance.yahoo.com/quote/IART/key-statistics?p=IART',
 'https://finance.yahoo.com/quote/FL/key-statistics?p=FL',
 'https://finance.yahoo.com/quote/WYND/key-statistics?p=WYND',
 'https://finance.yahoo.com/quote/NVT/key-statistics?p=NVT',
 'https://finance.yahoo.com/quote/ZS/key-statistics?p=ZS',
 'https://finance.yahoo.com/quote/LAZ/key-statistics?p=LAZ',
 'https://finance.yahoo.com/quote/ADS/key-statistics?p=ADS',
 'https://finance.yahoo.com/quote/UMPQ/key-statistics?p=UMPQ',
 'https://finance.yahoo.com/quote/MTCH/key-statistics?p=MTCH',
 'https://finance.yahoo.com/quote/IBKR/key-statistics?p=IBKR']

# %%
url_list_6 = [ 'https://finance.yahoo.com/quote/WBS/key-statistics?p=WBS',
 'https://finance.yahoo.com/quote/XEC/key-statistics?p=XEC',
 'https://finance.yahoo.com/quote/WEN/key-statistics?p=WEN',
 'https://finance.yahoo.com/quote/LFUS/key-statistics?p=LFUS',
 'https://finance.yahoo.com/quote/LSTR/key-statistics?p=LSTR',
 'https://finance.yahoo.com/quote/PEGA/key-statistics?p=PEGA',
 'https://finance.yahoo.com/quote/LSXMA/key-statistics?p=LSXMA',
 'https://finance.yahoo.com/quote/AGCO/key-statistics?p=AGCO',
 'https://finance.yahoo.com/quote/LOGM/key-statistics?p=LOGM',
 'https://finance.yahoo.com/quote/RYN/key-statistics?p=RYN',
 'https://finance.yahoo.com/quote/EXP/key-statistics?p=EXP',
 'https://finance.yahoo.com/quote/WRI/key-statistics?p=WRI',
 'https://finance.yahoo.com/quote/CLGX/key-statistics?p=CLGX',
 'https://finance.yahoo.com/quote/DBX/key-statistics?p=DBX',
 'https://finance.yahoo.com/quote/NKTR/key-statistics?p=NKTR',
 'https://finance.yahoo.com/quote/FTDR/key-statistics?p=FTDR',
 'https://finance.yahoo.com/quote/FHB/key-statistics?p=FHB',
 'https://finance.yahoo.com/quote/SVC/key-statistics?p=SVC',
 'https://finance.yahoo.com/quote/WTFC/key-statistics?p=WTFC',
 'https://finance.yahoo.com/quote/AMG/key-statistics?p=AMG',
 'https://finance.yahoo.com/quote/GRA/key-statistics?p=GRA',
 'https://finance.yahoo.com/quote/FND/key-statistics?p=FND',
 'https://finance.yahoo.com/quote/STL/key-statistics?p=STL',
 'https://finance.yahoo.com/quote/UNVR/key-statistics?p=UNVR',
 'https://finance.yahoo.com/quote/JHG/key-statistics?p=JHG',
 'https://finance.yahoo.com/quote/MFA/key-statistics?p=MFA',
 'https://finance.yahoo.com/quote/WTM/key-statistics?p=WTM',
 'https://finance.yahoo.com/quote/HLF/key-statistics?p=HLF',
 'https://finance.yahoo.com/quote/FNB/key-statistics?p=FNB',
 'https://finance.yahoo.com/quote/SAGE/key-statistics?p=SAGE',
 'https://finance.yahoo.com/quote/COHR/key-statistics?p=COHR',
 'https://finance.yahoo.com/quote/PBF/key-statistics?p=PBF',
 'https://finance.yahoo.com/quote/VSAT/key-statistics?p=VSAT',
 'https://finance.yahoo.com/quote/QRTEA/key-statistics?p=QRTEA',
 'https://finance.yahoo.com/quote/ESTC/key-statistics?p=ESTC',
 'https://finance.yahoo.com/quote/FCNCA/key-statistics?p=FCNCA',
 'https://finance.yahoo.com/quote/RBC/key-statistics?p=RBC',
 'https://finance.yahoo.com/quote/MIC/key-statistics?p=MIC',
 'https://finance.yahoo.com/quote/LM/key-statistics?p=LM',
 'https://finance.yahoo.com/quote/AVT/key-statistics?p=AVT',
 'https://finance.yahoo.com/quote/BOH/key-statistics?p=BOH',
 'https://finance.yahoo.com/quote/SCCO/key-statistics?p=SCCO',
 'https://finance.yahoo.com/quote/OFC/key-statistics?p=OFC',
 'https://finance.yahoo.com/quote/MAC/key-statistics?p=MAC',
 'https://finance.yahoo.com/quote/SIX/key-statistics?p=SIX',
 'https://finance.yahoo.com/quote/CHH/key-statistics?p=CHH',
 'https://finance.yahoo.com/quote/TKR/key-statistics?p=TKR',
 'https://finance.yahoo.com/quote/UHAL/key-statistics?p=UHAL',
 'https://finance.yahoo.com/quote/NFG/key-statistics?p=NFG',
 'https://finance.yahoo.com/quote/COTY/key-statistics?p=COTY',
 'https://finance.yahoo.com/quote/CPA/key-statistics?p=CPA',
 'https://finance.yahoo.com/quote/FEYE/key-statistics?p=FEYE',
 'https://finance.yahoo.com/quote/UAA/key-statistics?p=UAA',
 'https://finance.yahoo.com/quote/CFX/key-statistics?p=CFX',
 'https://finance.yahoo.com/quote/OLLI/key-statistics?p=OLLI',
 'https://finance.yahoo.com/quote/OZK/key-statistics?p=OZK',
 'https://finance.yahoo.com/quote/ZG/key-statistics?p=ZG',
 'https://finance.yahoo.com/quote/ACHC/key-statistics?p=ACHC',
 'https://finance.yahoo.com/quote/MUR/key-statistics?p=MUR',
 'https://finance.yahoo.com/quote/MORN/key-statistics?p=MORN',
 'https://finance.yahoo.com/quote/OMF/key-statistics?p=OMF',
 'https://finance.yahoo.com/quote/AGIO/key-statistics?p=AGIO',
 'https://finance.yahoo.com/quote/ASB/key-statistics?p=ASB',
 'https://finance.yahoo.com/quote/LBRDA/key-statistics?p=LBRDA',
 'https://finance.yahoo.com/quote/TCO/key-statistics?p=TCO',
 'https://finance.yahoo.com/quote/H/key-statistics?p=H',
 'https://finance.yahoo.com/quote/NEU/key-statistics?p=NEU',
 'https://finance.yahoo.com/quote/CNK/key-statistics?p=CNK',
 'https://finance.yahoo.com/quote/BFA/key-statistics?p=BFA',
 'https://finance.yahoo.com/quote/ENR/key-statistics?p=ENR',
 'https://finance.yahoo.com/quote/TCBI/key-statistics?p=TCBI',
 'https://finance.yahoo.com/quote/APLE/key-statistics?p=APLE',
 'https://finance.yahoo.com/quote/DKS/key-statistics?p=DKS',
 'https://finance.yahoo.com/quote/COMM/key-statistics?p=COMM',
 'https://finance.yahoo.com/quote/MSM/key-statistics?p=MSM',
 'https://finance.yahoo.com/quote/UA/key-statistics?p=UA',
 'https://finance.yahoo.com/quote/ALKS/key-statistics?p=ALKS',
 'https://finance.yahoo.com/quote/ESI/key-statistics?p=ESI',
 'https://finance.yahoo.com/quote/VMI/key-statistics?p=VMI',
 'https://finance.yahoo.com/quote/CC/key-statistics?p=CC',
 'https://finance.yahoo.com/quote/TRIP/key-statistics?p=TRIP',
 'https://finance.yahoo.com/quote/AA/key-statistics?p=AA',
 'https://finance.yahoo.com/quote/RPAI/key-statistics?p=RPAI',
 'https://finance.yahoo.com/quote/GH/key-statistics?p=GH',
 'https://finance.yahoo.com/quote/BKU/key-statistics?p=BKU',
 'https://finance.yahoo.com/quote/NEWR/key-statistics?p=NEWR',
 'https://finance.yahoo.com/quote/EVR/key-statistics?p=EVR',
 'https://finance.yahoo.com/quote/HGV/key-statistics?p=HGV',
 'https://finance.yahoo.com/quote/BOKF/key-statistics?p=BOKF',
 'https://finance.yahoo.com/quote/PGRE/key-statistics?p=PGRE',
 'https://finance.yahoo.com/quote/AGR/key-statistics?p=AGR',
 'https://finance.yahoo.com/quote/SC/key-statistics?p=SC',
 'https://finance.yahoo.com/quote/NAVI/key-statistics?p=NAVI',
 'https://finance.yahoo.com/quote/OLN/key-statistics?p=OLN',
 'https://finance.yahoo.com/quote/CMD/key-statistics?p=CMD',
 'https://finance.yahoo.com/quote/FLR/key-statistics?p=FLR',
 'https://finance.yahoo.com/quote/AN/key-statistics?p=AN',
 'https://finance.yahoo.com/quote/KAR/key-statistics?p=KAR',
 'https://finance.yahoo.com/quote/RIG/key-statistics?p=RIG',
 'https://finance.yahoo.com/quote/BDN/key-statistics?p=BDN',
 'https://finance.yahoo.com/quote/SPB/key-statistics?p=SPB',
 'https://finance.yahoo.com/quote/TREE/key-statistics?p=TREE',
 'https://finance.yahoo.com/quote/COLM/key-statistics?p=COLM',
 'https://finance.yahoo.com/quote/TDC/key-statistics?p=TDC',
 'https://finance.yahoo.com/quote/GT/key-statistics?p=GT',
 'https://finance.yahoo.com/quote/TDS/key-statistics?p=TDS',
 'https://finance.yahoo.com/quote/THS/key-statistics?p=THS',
 'https://finance.yahoo.com/quote/CLNY/key-statistics?p=CLNY',
 'https://finance.yahoo.com/quote/MD/key-statistics?p=MD',
 'https://finance.yahoo.com/quote/CXP/key-statistics?p=CXP',
 'https://finance.yahoo.com/quote/DT/key-statistics?p=DT',
 'https://finance.yahoo.com/quote/R/key-statistics?p=R',
 'https://finance.yahoo.com/quote/CBT/key-statistics?p=CBT',
 'https://finance.yahoo.com/quote/GHC/key-statistics?p=GHC',
 'https://finance.yahoo.com/quote/ESRT/key-statistics?p=ESRT',
 'https://finance.yahoo.com/quote/SLGN/key-statistics?p=SLGN',
 'https://finance.yahoo.com/quote/WCC/key-statistics?p=WCC',
 'https://finance.yahoo.com/quote/SATS/key-statistics?p=SATS',
 'https://finance.yahoo.com/quote/STAY/key-statistics?p=STAY',
 'https://finance.yahoo.com/quote/APY/key-statistics?p=APY',
 'https://finance.yahoo.com/quote/WWE/key-statistics?p=WWE',
 'https://finance.yahoo.com/quote/WLK/key-statistics?p=WLK',
 'https://finance.yahoo.com/quote/CLR/key-statistics?p=CLR',
 'https://finance.yahoo.com/quote/SITC/key-statistics?p=SITC',
 'https://finance.yahoo.com/quote/JWA/key-statistics?p=JWA',
 'https://finance.yahoo.com/quote/OI/key-statistics?p=OI',
 'https://finance.yahoo.com/quote/SBGI/key-statistics?p=SBGI',
 'https://finance.yahoo.com/quote/HAIN/key-statistics?p=HAIN',
 'https://finance.yahoo.com/quote/NWS/key-statistics?p=NWS',   ####thisone
 'https://finance.yahoo.com/quote/TRN/key-statistics?p=TRN',
 'https://finance.yahoo.com/quote/KOS/key-statistics?p=KOS',
 'https://finance.yahoo.com/quote/UFS/key-statistics?p=UFS',
 'https://finance.yahoo.com/quote/PINC/key-statistics?p=PINC',
 'https://finance.yahoo.com/quote/URBN/key-statistics?p=URBN',
 'https://finance.yahoo.com/quote/SFM/key-statistics?p=SFM',
 'https://finance.yahoo.com/quote/NUS/key-statistics?p=NUS',
 'https://finance.yahoo.com/quote/CNA/key-statistics?p=CNA',
 'https://finance.yahoo.com/quote/MCY/key-statistics?p=MCY',
 'https://finance.yahoo.com/quote/IGT/key-statistics?p=IGT',
 'https://finance.yahoo.com/quote/TWOU/key-statistics?p=TWOU',
 'https://finance.yahoo.com/quote/ETRN/key-statistics?p=ETRN',
 'https://finance.yahoo.com/quote/PTEN/key-statistics?p=PTEN',
 'https://finance.yahoo.com/quote/PAG/key-statistics?p=PAG',
 'https://finance.yahoo.com/quote/GO/key-statistics?p=GO',
 'https://finance.yahoo.com/quote/BGCP/key-statistics?p=BGCP',
 'https://finance.yahoo.com/quote/FWONA/key-statistics?p=FWONA']

# %%
url_list_7 = ['https://finance.yahoo.com/quote/LGFB/key-statistics?p=LGFB',
 'https://finance.yahoo.com/quote/X/key-statistics?p=X',
 'https://finance.yahoo.com/quote/AMCX/key-statistics?p=AMCX',
 'https://finance.yahoo.com/quote/PPC/key-statistics?p=PPC',
 'https://finance.yahoo.com/quote/CVET/key-statistics?p=CVET',
 'https://finance.yahoo.com/quote/EQT/key-statistics?p=EQT',
 'https://finance.yahoo.com/quote/AM/key-statistics?p=AM',
 'https://finance.yahoo.com/quote/UI/key-statistics?p=UI',
 'https://finance.yahoo.com/quote/PS/key-statistics?p=PS',
 'https://finance.yahoo.com/quote/BPR/key-statistics?p=BPR',
 'https://finance.yahoo.com/quote/SNDR/key-statistics?p=SNDR',
 'https://finance.yahoo.com/quote/SWI/key-statistics?p=SWI',
 'https://finance.yahoo.com/quote/SWCH/key-statistics?p=SWCH',
 'https://finance.yahoo.com/quote/ADT/key-statistics?p=ADT',
 'https://finance.yahoo.com/quote/REZI/key-statistics?p=REZI',
 'https://finance.yahoo.com/quote/TFSL/key-statistics?p=TFSL',
 'https://finance.yahoo.com/quote/PD/key-statistics?p=PD',
 'https://finance.yahoo.com/quote/VIRT/key-statistics?p=VIRT',
 'https://finance.yahoo.com/quote/CRNC/key-statistics?p=CRNC',
 'https://finance.yahoo.com/quote/LENB/key-statistics?p=LENB',
 'https://finance.yahoo.com/quote/LGFA/key-statistics?p=LGFA',
 'https://finance.yahoo.com/quote/ANAT/key-statistics?p=ANAT',
 'https://finance.yahoo.com/quote/CHNG/key-statistics?p=CHNG',
 'https://finance.yahoo.com/quote/USM/key-statistics?p=USM',
 'https://finance.yahoo.com/quote/CDEV/key-statistics?p=CDEV',
 'https://finance.yahoo.com/quote/MDLA/key-statistics?p=MDLA',
 'https://finance.yahoo.com/quote/RRC/key-statistics?p=RRC',
 'https://finance.yahoo.com/quote/EAF/key-statistics?p=EAF',
 'https://finance.yahoo.com/quote/CHK/key-statistics?p=CHK',
 'https://finance.yahoo.com/quote/GTES/key-statistics?p=GTES',
 'https://finance.yahoo.com/quote/AR/key-statistics?p=AR',
 'https://finance.yahoo.com/quote/ADPT/key-statistics?p=ADPT',
 'https://finance.yahoo.com/quote/ARD/key-statistics?p=ARD',
 'https://finance.yahoo.com/quote/VIACA/key-statistics?p=VIACA'
]

# %%
list_of_pages = []
for thing in url_list_1:
    a = requests.get(thing)
    list_of_pages.append(a)

# %%
list_of_pages
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
for thing in url_list_2:
    a = requests.get(thing)
    list_of_pages.append(a)

# %%
list_of_pages
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_of_pages_3 = []
for thing in url_list_3:
    a = requests.get(thing)
    list_of_pages_3.append(a)

# %%
list_of_pages_3
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_of_pages_3.pop(92)
# Out:
# <Response [503]>

# %%
len(list_of_pages_3)
# Out:
# 148

# %%
list_of_pages_4 = []
for thing in url_list_4:
    a = requests.get(thing)
    list_of_pages_4.append(a)

# %%
list_of_pages_4
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_of_pages_5 = []
for thing in url_list_5:
    a = requests.get(thing)
    list_of_pages_5.append(a)

# %%
list_of_pages_5
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [503]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_of_pages_5.pop(112)
# Out:
# <Response [503]>

# %%
list_of_pages_5.pop(18)
# Out:
# <Response [503]>

# %%
list_of_pages_6 = []
for thing in url_list_6:
    a = requests.get(thing)
    list_of_pages_6.append(a)

# %%
list_of_pages_6
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
list_of_pages_6.pop(128)
# Out:
# <Response [503]>

# %%
list_of_pages_7 = []
for thing in url_list_7:
    a = requests.get(thing)
    list_of_pages_7.append(a)

# %%
list_of_pages_7
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
len(list_of_pages)
# Out:
# 340

# %%
list_of_pages.extend(list_of_pages_3)

# %%
len(list_of_pages)
# Out:
# 488

# %%
list_of_pages.extend(list_of_pages_4)

# %%
list_of_pages.extend(list_of_pages_5)

# %%
list_of_pages.extend(list_of_pages_6)

# %%
list_of_pages.extend(list_of_pages_7)

# %%
list_of_pages
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
# ...

# %%
len(list_of_pages)
# Out:
# 988

# %%
freq = list(range(0,800))

# %%
new_list_of_datas = []
empty_df = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[0].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df.append(adf)
    new_list_of_datas.append(adf)

# %%
new_list_of_datas[5]
# Out:
# 0 Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                 952.83B            816.74B        28.20         22.19
#
# 0 PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# 1                        5.17              5.89             4.74
#
# 0 Enterprise Value/Revenue 3 Enterprise Value/EBITDA 6
# 1                       5.05                     16.97

# %%
zfreq = list(range(0,86))
#             len(new_list_of_datas)

# %%
len(zfreq)
# Out:
# 86

# %%
new_list_of_datas_1 = []
empty_df_1 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[1].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_1.append(adf)
    new_list_of_datas_1.append(adf)

# %%
new_list_of_datas_1[5]
# Out:
# 0 Beta (5Y Monthly) 52-Week Change 3 S&P500 52-Week Change 3 52 Week High 3  \
# 1              1.04           16.11%                   5.78%        1530.74
#
# 0 52 Week Low 3 50-Day Moving Average 3 200-Day Moving Average 3
# 1       1027.03                 1459.90                  1317.02

# %%
new_list_of_datas_2 = []
empty_df_2 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[2].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_2.append(adf)
    new_list_of_datas_2.append(adf)

# %%
new_list_of_datas_2[5]
# Out:
# 0 Avg Vol (3 month) 3 Avg Vol (10 day) 3 Shares Outstanding 5   Float  \
# 1               1.69M               2.8M              299.83M  617.9M
#
# 0 % Held by Insiders 1 % Held by Institutions 1 Shares Short (Feb 13, 2020) 4  \
# 1                0.14%                   81.67%                         2.99M
#
# 0 Short Ratio (Feb 13, 2020) 4 Short % of Float (Feb 13, 2020) 4  \
# 1                         1.64                             1.00%
#
# 0 Short % of Shares Outstanding (Feb 13, 2020) 4  \
# 1                                          0.43%
#
# 0 Shares Short (prior month Jan 14, 2020) 4
# 1                                     3.13M

# %%
new_list_of_datas_3 = []
empty_df_3 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[3].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_3.append(adf)
    new_list_of_datas_3.append(adf)

# %%
new_list_of_datas_3[5]
# Out:
# 0 Forward Annual Dividend Rate 4 Forward Annual Dividend Yield 4  \
# 1                            NaN                             NaN
#
# 0 Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3  \
# 1                             NaN                              NaN
#
# 0 5 Year Average Dividend Yield 4 Payout Ratio 4 Dividend Date 3  \
# 1                             NaN          0.00%             NaN
#
# 0 Ex-Dividend Date 4 Last Split Factor 2 Last Split Date 3
# 1                NaN           1998:1000      Apr 02, 2014

# %%
new_list_of_datas_4 = []
empty_df_4 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[4].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_4.append(adf)
    new_list_of_datas_4.append(adf)

# %%
new_list_of_datas_4[5]
# Out:
# 0 Fiscal Year Ends Most Recent Quarter (mrq)
# 1     Dec 30, 2019              Dec 30, 2019

# %%
new_list_of_datas_5 = []
empty_df_5 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[5].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_5.append(adf)
    new_list_of_datas_5.append(adf)

# %%
new_list_of_datas_5[5]
# Out:
# 0 Profit Margin Operating Margin (ttm)
# 1        21.22%                 22.54%

# %%
new_list_of_datas_6 = []
empty_df_6 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[6].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_6.append(adf)
    new_list_of_datas_6.append(adf)

# %%
new_list_of_datas_6[5]
# Out:
# 0 Return on Assets (ttm) Return on Equity (ttm)
# 1                  8.96%                 18.12%

# %%
new_list_of_datas_7 = []
empty_df_7 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[7].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_7.append(adf)
    new_list_of_datas_7.append(adf)

# %%
new_list_of_datas_7[5]
# Out:
# 0 Revenue (ttm) Revenue Per Share (ttm) Quarterly Revenue Growth (yoy)  \
# 1       161.86B                  233.70                         17.30%
#
# 0 Gross Profit (ttm)  EBITDA Net Income Avi to Common (ttm) Diluted EPS (ttm)  \
# 1             89.96B  48.13B                         34.34B             49.16
#
# 0 Quarterly Earnings Growth (yoy)
# 1                          19.30%

# %%
new_list_of_datas_8 = []
empty_df_8 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[8].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_8.append(adf)
    new_list_of_datas_8.append(adf)

# %%
new_list_of_datas_8[5]
# Out:
# 0 Total Cash (mrq) Total Cash Per Share (mrq) Total Debt (mrq)  \
# 1          119.68B                     174.13           15.97B
#
# 0 Total Debt/Equity (mrq) Current Ratio (mrq) Book Value Per Share (mrq)
# 1                    7.93                3.37                     292.65

# %%
new_list_of_datas_9 = []
empty_df_9 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(list_of_pages[thing].content)[9].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_9.append(adf)
    new_list_of_datas_9.append(adf)

# %%
new_list_of_datas_9[5]
# Out:
# 0 Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                    54.52B                       25.58B

# %%
empty_df_9
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(freq)
# Out:
# 800

# %%
nine lists of 800 dataframes
need to do .apply to append each row in tables 1-10 to a dataframe
then need to concat the 10 tables

# %%
testing_df = new_list_of_datas_9[0]

# %%
testing_df_2 = new_list_of_datas_9[1]

# %%
testing_df_2

# %%
testing_df.append(testing_df_2)

# %%
testing_df

# %%
empty_df = pd.DataFrame()
for thing in new_list_of_datas:
    a = thing
    empty_df = empty_df.append(a)

# %%
empty_df
# Out:
# 0  Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                    1.31T              1.21T        23.72         19.06
# 1                    1.31T              1.19T        30.10         27.38
# 1                   972.7B            960.26B        84.92         48.63
# 1                  559.94B            504.85B        30.55         18.01
# 1                  954.69B            816.79B        28.26         22.16
# ..                     ...                ...          ...           ...
# 1                    3.83B              7.89B        11.18          5.18
# 1                    3.88B              5.37B         8.40          9.49
# 1                    3.92B              1.19B         8.24         61.81
# 1                    5.24B              12.1B         6.55          8.25
# 1                    4.44B               5.7B        90.62         15.69
#
# 0  PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
empty_df_1 = pd.DataFrame()
for thing in new_list_of_datas_1:
    a = thing
    empty_df_1 = empty_df_1.append(a)

# %%
empty_df_1
# Out:
# 0  Beta (5Y Monthly) 52-Week Change 3 S&P500 52-Week Change 3 52 Week High 3  \
# 1               1.28           55.45%                   5.78%         327.85
# 1               1.15           44.32%                   5.78%         190.70
# 1               1.62           11.06%                   5.78%        2185.95
# 1               1.08           15.00%                   5.78%         224.20
# 1               1.04           16.69%                   5.78%        1532.11
# ..               ...              ...                     ...            ...
# 1               0.96          -42.71%                   5.78%          50.00
# 1               1.48          -22.98%                   5.78%          41.47
# 1               0.35           -4.64%                   5.78%          34.95
# 1               0.75          -48.34%                   5.78%          29.59
# 1               1.11           -7.01%                   5.78%          65.09
#
# ...

# %%
empty_df_2 = pd.DataFrame()
for thing in new_list_of_datas_2:
    a = thing
    empty_df_2 = empty_df_2.append(a)
    
empty_df_2
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#    % Held by Insiders 1 % Held by Institutions 1 Avg Vol (10 day) 3  \
# 1                 0.07%                   61.84%             63.65M
# 1                 1.42%                   74.39%             71.89M
# 1                15.16%                   57.59%              6.71M
# 1                 0.99%                   78.94%             21.56M
# 1                 5.66%                   69.87%              2.67M
# ..                  ...                      ...                ...
# 1                 5.38%                   98.08%              4.16M
# 1                 1.30%                   87.57%              1.18M
# ...

# %%
empty_df_3 = pd.DataFrame()
for thing in new_list_of_datas_3:
    a = thing
    empty_df_3 = empty_df_3.append(a)
    
empty_df_3
# Out:
# 0  Forward Annual Dividend Rate 4 Forward Annual Dividend Yield 4  \
# 1                            3.08                           1.13%
# 1                            2.04                           1.29%
# 1                             NaN                             NaN
# 1                             NaN                             NaN
# 1                             NaN                             NaN
# ..                            ...                             ...
# 1                             NaN                             NaN
# 1                             2.4                           7.59%
# 1                             NaN                             NaN
# 1                            0.97                           6.77%
# 1                             NaN                             NaN
#
# 0  Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3  \
# 1                             3.04                            1.11%
# ...

# %%
empty_df_4 = pd.DataFrame()
for thing in new_list_of_datas_4:
    a = thing
    empty_df_4 = empty_df_4.append(a)
    
empty_df_4
# Out:
# 0  Fiscal Year Ends Most Recent Quarter (mrq)
# 1      Sep 27, 2019              Dec 27, 2019
# 1      Jun 29, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# ..              ...                       ...
# 1      Mar 29, 2019              Dec 27, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Feb 01, 2019              Nov 01, 2019
# 1      Dec 30, 2019              Dec 30, 2019
#
# [800 rows x 2 columns]

# %%
empty_df_5 = pd.DataFrame()
for thing in new_list_of_datas_5:
    a = thing
    empty_df_5 = empty_df_5.append(a)
    
empty_df_5
# Out:
# 0  Profit Margin Operating Margin (ttm)
# 1         21.49%                 24.71%
# 1         33.02%                 36.74%
# 1          4.13%                  5.14%
# 1         26.15%                 33.93%
# 1         21.22%                 22.54%
# ..           ...                    ...
# 1          6.09%                 12.62%
# 1         41.28%                 58.57%
# 1        385.36%                 14.29%
# 1          4.97%                  8.19%
# 1          3.31%                 17.20%
#
# [800 rows x 2 columns]

# %%
empty_df_6 = pd.DataFrame()
for thing in new_list_of_datas_6:
    a = thing
    empty_df_6 = empty_df_6.append(a)
    
empty_df_6
# Out:
# 0  Return on Assets (ttm) Return on Equity (ttm)
# 1                  11.58%                 55.47%
# 1                  11.38%                 43.83%
# 1                   4.64%                 21.94%
# 1                  13.00%                 19.96%
# 1                   8.96%                 18.12%
# ..                    ...                    ...
# 1                   6.27%                 14.19%
# 1                   1.79%                  9.58%
# 1                   0.33%                 15.33%
# 1                   7.50%                 22.93%
# 1                   5.09%                  3.60%
#
# [800 rows x 2 columns]

# %%
empty_df_7 = pd.DataFrame()
for thing in new_list_of_datas_7:
    a = thing
    empty_df_7 = empty_df_7.append(a)
    
empty_df_7
# Out:
# 0  Revenue (ttm) Revenue Per Share (ttm) Quarterly Revenue Growth (yoy)  \
# 1        267.68B                   58.99                          8.90%
# 1        134.25B                   17.56                         13.70%
# 1        280.52B                  567.86                         20.80%
# 1          70.7B                   24.77                         24.60%
# 1        161.86B                  233.70                         17.30%
# ..           ...                     ...                            ...
# 1           5.7B                   37.75                          9.20%
# 1          1.14B                    9.54                         -4.40%
# 1        127.85M                    1.05                        -39.40%
# 1         16.33B                   43.26                         -2.20%
# 1          1.52B                   17.72                          3.10%
#
# 0  Gross Profit (ttm)   EBITDA Net Income Avi to Common (ttm)  \
# ...

# %%
empty_df_8 = pd.DataFrame()
for thing in new_list_of_datas_8:
    a = thing
    empty_df_8 = empty_df_8.append(a)
    
empty_df_8
# Out:
# 0  Total Cash (mrq) Total Cash Per Share (mrq) Total Debt (mrq)  \
# 1           107.16B                      24.49          116.75B
# 1           134.23B                      17.65           87.15B
# 1            55.02B                     110.53           77.54B
# 1            54.86B                      19.24           11.07B
# 1           119.68B                     174.13           15.97B
# ..              ...                        ...              ...
# 1              237M                       1.59            4.27B
# 1           637.86M                       5.53            2.36B
# 1              2.8B                      22.91           26.57M
# 1             1.08B                        2.9            7.83B
# 1           198.92M                       2.36             1.5B
#
# 0  Total Debt/Equity (mrq) Current Ratio (mrq) Book Value Per Share (mrq)
# 1                   130.40                1.60                      20.42
# ...

# %%
empty_df_9 = pd.DataFrame()
for thing in new_list_of_datas_9:
    a = thing
    empty_df_9 = empty_df_9.append(a)
    
empty_df_9
# Out:
# 0  Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                     73.22B                       45.59B
# 1                     54.13B                       35.08B
# 1                     38.51B                       18.79B
# 1                     36.31B                       15.85B
# 1                     54.52B                       25.58B
# ..                       ...                          ...
# 1                       670M                        2.25B
# 1                    582.66M                          NaN
# 1                     98.94M                       60.43M
# 1                      1.34B                      146.12M
# 1                    231.43M                      130.68M
#
# [800 rows x 2 columns]

# %%
master_df = pd.DataFrame()

# %%
master_df = pd.concat([master_df, empty_df], axis = 1)

# %%
master_df
# Out:
# 0  Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                    1.31T              1.21T        23.72         19.06
# 1                    1.31T              1.19T        30.10         27.38
# 1                   972.7B            960.26B        84.92         48.63
# 1                  559.94B            504.85B        30.55         18.01
# 1                  954.69B            816.79B        28.26         22.16
# ..                     ...                ...          ...           ...
# 1                    3.83B              7.89B        11.18          5.18
# 1                    3.88B              5.37B         8.40          9.49
# 1                    3.92B              1.19B         8.24         61.81
# 1                    5.24B              12.1B         6.55          8.25
# 1                    4.44B               5.7B        90.62         15.69
#
# 0  PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
master_df = pd.concat([master_df, empty_df_1], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_2], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_3], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_4], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_5], axis = 1)

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                    1.31T              1.21T        23.72         19.06
# 1                    1.31T              1.19T        30.10         27.38
# 1                   972.7B            960.26B        84.92         48.63
# 1                  559.94B            504.85B        30.55         18.01
# 1                  954.69B            816.79B        28.26         22.16
# ..                     ...                ...          ...           ...
# 1                    3.83B              7.89B        11.18          5.18
# 1                    3.88B              5.37B         8.40          9.49
# 1                    3.92B              1.19B         8.24         61.81
# 1                    5.24B              12.1B         6.55          8.25
# 1                    4.44B               5.7B        90.62         15.69
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
master_df = pd.concat([master_df, empty_df_6], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_7], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_8], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_9], axis = 1)

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                    1.31T              1.21T        23.72         19.06
# 1                    1.31T              1.19T        30.10         27.38
# 1                   972.7B            960.26B        84.92         48.63
# 1                  559.94B            504.85B        30.55         18.01
# 1                  954.69B            816.79B        28.26         22.16
# ..                     ...                ...          ...           ...
# 1                    3.83B              7.89B        11.18          5.18
# 1                    3.88B              5.37B         8.40          9.49
# 1                    3.92B              1.19B         8.24         61.81
# 1                    5.24B              12.1B         6.55          8.25
# 1                    4.44B               5.7B        90.62         15.69
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
tickers = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/CSV_Files/full_ticker.csv')

# %%
list(tickers["Ticker"])
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'FB',
#  'GOOG',
#  'GOOGL',
#  'BRKB',
#  'JPM',
#  'JNJ',
#  'V',
#  'PG',
#  'MA',
#  'INTC',
#  'BAC',
#  'UNH',
#  'T',
#  'HD',
#  'XOM',
#  'DIS',
#  'VZ',
#  'KO',
#  'MRK',
#  'CVX',
#  'CMCSA',
#  'PEP',
#  'PFE',
#  'CSCO',
#  'ADBE',
#  'WFC',
#  'BA',
#  'C',
#  'NVDA',
#  'WMT',
#  'MCD',
#  'NFLX',
#  'CRM',
#  'MDT',
#  'BMY',
#  'ABT',
#  'PYPL',
#  'COST',
#  'ABBV',
#  'PM',
#  'NEE',
#  'ACN',
#  'TMO',
#  'AMGN',
#  'IBM',
#  'HON',
#  'UNP',
#  'NKE',
#  'UTX',
#  'TXN',
#  'AVGO',
#  'LLY',
#  'LIN',
#  'ORCL',
#  'TSLA',
#  'AMT',
#  'GE',
#  'LMT',
#  'SBUX',
#  'DHR',
#  'QCOM',
#  'LOW',
#  'FIS',
#  'CVS',
#  'AXP',
#  'MMM',
#  'GILD',
#  'MDLZ',
#  'MO',
#  'BKNG',
#  'CHTR',
#  'CI',
#  'ADP',
#  'USB',
#  'TJX',
#  'SYK',
#  'INTU',
#  'SPGI',
#  'ANTM',
#  'CME',
#  'GS',
#  'CB',
#  'CAT',
#  'UPS',
#  'DUK',
#  'TFC',
#  'SO',
#  'D',
#  'PLD',
#  'BDX',
#  'ISRG',
#  'ZTS',
#  'FISV',
#  'CCI',
#  'PNC',
#  'BLK',
# ...

# %%
tickers = ['AAPL',
 'MSFT',
 'AMZN',
 'FB',
 'GOOG',
 'GOOGL',
 'BRKB',
 'JPM',
 'JNJ',
 'V',
 'PG',
 'MA',
 'INTC',
 'BAC',
 'UNH',
 'T',
 'HD',
 'XOM',
 'DIS',
 'VZ',
 'KO',
 'MRK',
 'CVX',
 'CMCSA',
 'PEP',
 'PFE',
 'CSCO',
 'ADBE',
 'WFC',
 'BA',
 'C',
 'NVDA',
 'WMT',
 'MCD',
 'NFLX',
 'CRM',
 'MDT',
 'BMY',
 'ABT',
 'PYPL',
 'COST',
 'ABBV',
 'PM',
 'NEE',
 'ACN',
 'TMO',
 'AMGN',
 'IBM',
 'HON',
 'UNP',
 'NKE',
 'UTX',
 'TXN',
 'AVGO',
 'LLY',
 'LIN',
 'ORCL',
 'TSLA',
 'AMT',
 'GE',
 'LMT',
 'SBUX',
 'DHR',
 'QCOM',
 'LOW',
 'FIS',
 'CVS',
 'AXP',
 'MMM',
 'GILD',
 'MDLZ',
 'MO',
 'BKNG',
 'CHTR',
 'CI',
 'ADP',
 'USB',
 'TJX',
 'SYK',
 'INTU',
 'SPGI',
 'ANTM',
 'CME',
 'GS',
 'CB',
 'CAT',
 'UPS',
 'DUK',
 'TFC',
 'SO',
 'D',
 'PLD',
 'BDX',
 'ISRG',
 'ZTS',
 'FISV',
 'CCI',
 'PNC',
 'BLK',
 'NOW',
 'AGN',
 'MS',
 'MU',
 'CL',
 'COP',
 'RTN',
 'VRTX',
 'AMAT',
 'GPN',
 'MMC',
 'ITW',
 'BIIB',
 'CSX',
 'BSX',
 'NOC',
 'TGT',
 'AMD',
 'APD',
 'AON',
 'EQIX',
 'NSC',
 'SCHW',
 'WM',
 'ICE',
 'DE',
 'ECL',
 'AEP',
 'LHX',
 'KMB',
 'HUM',
 'PGR',
 'LRCX',
 'SHW',
 'EXC',
 'ATVI',
 'GD',
 'COF',
 'EW',
 'SLB',
 'EL',
 'ADSK',
 'MCO',
 'SRE',
 'BAX',
 'EMR',
 'ILMN',
 'EOG',
 'GM',
 'ADI',
 'ROST',
 'KMI',
 'SPG',
 'ETN',
 'AIG',
 'DG',
 'MET',
 'ALL',
 'HCA',
 'ROP',
 'PSX',
 'WBA',
 'MAR',
 'DD',
 'AFL',
 'PRU',
 'FDX',
 'CNC',
 'UBER',
 'BK',
 'CTSH',
 'MPC',
 'OXY',
 'SYY',
 'XEL',
 'DOW',
 'NEM',
 'WELL',
 'TRV',
 'IR',
 'PSA',
 'DAL',
 'VLO',
 'SBAC',
 'HPQ',
 'ZBH',
 'REGN',
 'JCI',
 'WEC',
 'STZ',
 'WDAY',
 'INFO',
 'TDG',
 'GIS',
 'AVB',
 'EA',
 'OKE',
 'EQR',
 'F',
 'YUM',
 'MSI',
 'HLT',
 'ED',
 'TROW',
 'APH',
 'ES',
 'TMUS',
 'MCK',
 'LULU',
 'PEG',
 'EBAY',
 'ORLY',
 'IQV',
 'PAYX',
 'PPG',
 'STT',
 'FE',
 'SQ',
 'TWTR',
 'KLAC',
 'VRSK',
 'DLR',
 'LUV',
 'WLTW',
 'FLT',
 'PH',
 'EIX',
 'MSCI',
 'ETR',
 'A',
 'SPLK',
 'MNST',
 'CSGP',
 'O',
 'WMB',
 'DXCM',
 'VFC',
 'PPL',
 'SWK',
 'MCHP',
 'AWK',
 'PCAR',
 'CTAS',
 'RMD',
 'ADM',
 'BLL',
 'AZO',
 'CMI',
 'DTE',
 'IDXX',
 'ANSS',
 'SNPS',
 'CERN',
 'DFS',
 'CMG',
 'PANW',
 'LVS',
 'HSY',
 'TSN',
 'AME',
 'CTVA',
 'XLNX',
 'WY',
 'FTV',
 'ROK',
 'PXD',
 'APTV',
 'BXP',
 'AMP',
 'KR',
 'MTB',
 'VTR',
 'FAST',
 'LYB',
 'CDNS',
 'SYF',
 'ALXN',
 'GLW',
 'RSG',
 'CBRE',
 'AEE',
 'VRSN',
 'ALGN',
 'ESS',
 'HIG',
 'VEEV',
 'DLTR',
 'FITB',
 'DHI',
 'CPRT',
 'CLX',
 'WDC',
 'MKC',
 'BBY',
 'AJG',
 'SWKS',
 'EFX',
 'ARE',
 'CDW',
 'FRC',
 'CMS',
 'VMC',
 'NTRS',
 'RCL',
 'KEY',
 'LEN',
 'HAL',
 'VIAC',
 'HPE',
 'CHD',
 'LH',
 'PEAK',
 'KEYS',
 'TRU',
 'ACGL',
 'UAL',
 'MTD',
 'TEAM',
 'MKL',
 'RNG',
 'FCX',
 'IAC',
 'INVH',
 'TFX',
 'COO',
 'MXIM',
 'CINF',
 'FTNT',
 'CAH',
 'EXPE',
 'CCL',
 'DOV',
 'KSU',
 'K',
 'KHC',
 'ULTA',
 'CFG',
 'SPOT',
 'IP',
 'MRVL',
 'MAA',
 'MLM',
 'OMC',
 'YUMC',
 'EVRG',
 'HES',
 'KMX',
 'BMRN',
 'TIF',
 'RF',
 'XYL',
 'BURL',
 'TWLO',
 'CXO',
 'MGM',
 'AKAM',
 'CAG',
 'PAYC',
 'CTL',
 'PFG',
 'DGX',
 'SUI',
 'CTXS',
 'DRI',
 'LDOS',
 'SSNC',
 'WPC',
 'IFF',
 'ODFL',
 'NLY',
 'LBRDK',
 'UDR',
 'NUE',
 'EXR',
 'LNT',
 'GRMN',
 'HBAN',
 'HOLX',
 'OKTA',
 'ABC',
 'BKR',
 'STE',
 'ATO',
 'TDY',
 'AES',
 'DRE',
 'LW',
 'INCY',
 'WAB',
 'EXAS',
 'SIVB',
 'BR',
 'DOCU',
 'ALNY',
 'L',
 'HRL',
 'WAT',
 'VAR',
 'SGEN',
 'J',
 'ANET',
 'FMC',
 'CNP',
 'GPC',
 'NDAQ',
 'GDDY',
 'GWW',
 'FOXA',
 'NVR',
 'TYL',
 'IEX',
 'JKHY',
 'ALLE',
 'CE',
 'AMTD',
 'WYNN',
 'XRAY',
 'IT',
 'ELS',
 'ZBRA',
 'VICI',
 'NTAP',
 'MAS',
 'PODD',
 'MKTX',
 'TTWO',
 'ARNC',
 'WST',
 'EXPD',
 'EPAM',
 'ALLY',
 'BFB',
 'RJF',
 'MPW',
 'SJM',
 'ELAN',
 'QRVO',
 'NLOK',
 'VMW',
 'TTD',
 'FANG',
 'VNO',
 'LNC',
 'WTRG',
 'HST',
 'FICO',
 'DPZ',
 'FNF',
 'URI',
 'GL',
 'TRMB',
 'TER',
 'PNW',
 'MYL',
 'NI',
 'PHM',
 'Y',
 'FDS',
 'RE',
 'AVY',
 'TSCO',
 'AAL',
 'EQH',
 'WRB',
 'ROKU',
 'TXT',
 'BRO',
 'CPT',
 'UHS',
 'WU',
 'BKI',
 'NCLH',
 'VER',
 'REG',
 'COUP',
 'HSIC',
 'BAH',
 'FBHS',
 'CCK',
 'LKQ',
 'NDSN',
 'PKI',
 'GWRE',
 'APA',
 'DISH',
 'AGNC',
 'WEX',
 'ARMK',
 'ZEN',
 'SIRI',
 'NRG',
 'WRK',
 'EMN',
 'ETFC',
 'VST',
 'LYV',
 'MTN',
 'GLPI',
 'NNN',
 'FRT',
 'DOX',
 'OHI',
 'DISCK',
 'IPG',
 'HII',
 'TAP',
 'BFAM',
 'NBIX',
 'CHRW',
 'RPM',
 'ALB',
 'RGA',
 'OGE',
 'CSL',
 'PTC',
 'POOL',
 'CTLT',
 'GGG',
 'NBL',
 'IRM',
 'KRC',
 'JBHT',
 'WHR',
 'PKG',
 'SRPT',
 'FWONK',
 'MOH',
 'SCI',
 'CMA',
 'JLL',
 'XPO',
 'AZPN',
 'UGI',
 'MASI',
 'AAP',
 'CY',
 'LII',
 'ON',
 'DVN',
 'BIO',
 'CRL',
 'ATUS',
 'CGNX',
 'NOV',
 'PCG',
 'TRGP',
 'USFD',
 'STOR',
 'RNR',
 'SEIC',
 'LYFT',
 'DVA',
 'TTC',
 'G',
 'AIZ',
 'CZR',
 'SNA',
 'MRO',
 'CPB',
 'VOYA',
 'EHC',
 'HUBS',
 'CF',
 'LAMR',
 'ZAYO',
 'AFG',
 'HEIA',
 'ENTG',
 'AIV',
 'JAZZ',
 'KIM',
 'MPWR',
 'TPR',
 'QGEN',
 'TECH',
 'JNPR',
 'NWL',
 'NLSN',
 'MHK',
 'HUBB',
 'CONE',
 'DELL',
 'AMH',
 'ALK',
 'ZION',
 'FFIV',
 'CABO',
 'RS',
 'DXC',
 'IONS',
 'LSXMK',
 'GNTX',
 'BG',
 'ABMD',
 'ACM',
 'LPLA',
 'OLED',
 'COLD',
 'FLIR',
 'DEI',
 'EEFT',
 'HRC',
 'ST',
 'GLIBA',
 'SBNY',
 'SLG',
 'CHE',
 'LEA',
 'PRGO',
 'PFPT',
 'STWD',
 'PNR',
 'BWA',
 'ATR',
 'AYX',
 'PRAH',
 'MDB',
 'PBCT',
 'WBC',
 'POST',
 'EWBC',
 'CBSH',
 'CACI',
 'NRZ',
 'CDAY',
 'CIEN',
 'KSS',
 'FAF',
 'PLNT',
 'DCI',
 'OC',
 'HZNP',
 'ORI',
 'SPR',
 'NUAN',
 'IVZ',
 'ATH',
 'PB',
 'HDS',
 'WWD',
 'INGR',
 'RGLD',
 'BWXT',
 'XRX',
 'IAA',
 'NYT',
 'HTA',
 'MKSI',
 'FIVE',
 'RHI',
 'ACC',
 'MDU',
 'BEN',
 'MOS',
 'MIDD',
 'DNKN',
 'PVH',
 'AXTA',
 'EXEL',
 'ARW',
 'CASY',
 'HFC',
 'TCF',
 'HXL',
 'FLS',
 'ETSY',
 'SABR',
 'CUZ',
 'NTNX',
 'Z',
 'AOS',
 'ZNGA',
 'KDP',
 'CDK',
 'NATI',
 'CUBE',
 'UNM',
 'JEF',
 'CW',
 'TOL',
 'JBLU',
 'WSM',
 'NXST',
 'JBL',
 'PWR',
 'MSG',
 'RL',
 'IDA',
 'BRX',
 'PK',
 'SNX',
 'HPP',
 'FOX',
 'NWSA',
 'LEG',
 'SRCL',
 'STLD',
 'COG',
 'BERY',
 'PEN',
 'PII',
 'AVTR',
 'EPR',
 'LB',
 'OSK',
 'CFR',
 'PLAN',
 'BPOP',
 'WH',
 'SON',
 'JBGS',
 'PRI',
 'WAL',
 'ROL',
 'WSO',
 'BYND',
 'M',
 'AWI',
 'CREE',
 'MAN',
 'SERV',
 'BRKR',
 'EV',
 'HBI',
 'AXS',
 'THG',
 'SRC',
 'SEE',
 'W',
 'HE',
 'RP',
 'LECO',
 'LSI',
 'HOG',
 'SNV',
 'BLUE',
 'PCTY',
 'ASH',
 'HIW',
 'IPGP',
 'MANH',
 'BC',
 'AL',
 'PE',
 'GPK',
 'DISCA',
 'S',
 'PNFP',
 'SLM',
 'NYCB',
 'FHN',
 'KMPR',
 'ALSN',
 'HEI',
 'BHF',
 'GRUB',
 'CACC',
 'MAT',
 'HUN',
 'SKX',
 'HHC',
 'UTHR',
 'WPX',
 'DLB',
 'CIT',
 'CLH',
 'FLO',
 'CRI',
 'AVLR',
 'KNX',
 'JWN',
 'PSTG',
 'CR',
 'GDI',
 'TPX',
 'SMAR',
 'KEX',
 'HP',
 'SMG',
 'MTG',
 'AYI',
 'TWO',
 'ICUI',
 'OUT',
 'COR',
 'CIM',
 'VVV',
 'FSLR',
 'HRB',
 'LOPE',
 'MRNA',
 'CVNA',
 'NCR',
 'NVST',
 'ERIE',
 'AGO',
 'CPRI',
 'PACW',
 'EQC',
 'GPS',
 'IART']

# %%
dropped = ['FL',
 'WYND',
 'NVT',
 'ZS',
 'LAZ',
 'ADS',
 'UMPQ',
 'MTCH',
 'IBKR',
 'WBS',
 'XEC',
 'WEN',
 'LFUS',
 'LSTR',
 'PEGA',
 'LSXMA',
 'AGCO',
 'LOGM',
 'RYN',
 'EXP',
 'WRI',
 'CLGX',
 'DBX',
 'NKTR',
 'FTDR',
 'FHB',
 'SVC',
 'WTFC',
 'AMG',
 'GRA',
 'FND',
 'STL',
 'UNVR',
 'JHG',
 'MFA',
 'WTM',
 'HLF',
 'FNB',
 'SAGE',
 'COHR',
 'PBF',
 'VSAT',
 'QRTEA',
 'ESTC',
 'FCNCA',
 'RBC',
 'MIC',
 'LM',
 'AVT',
 'BOH',
 'SCCO',
 'OFC',
 'MAC',
 'SIX',
 'CHH',
 'TKR',
 'UHAL',
 'NFG',
 'COTY',
 'CPA',
 'FEYE',
 'UAA',
 'CFX',
 'OLLI',
 'OZK',
 'ZG',
 'ACHC',
 'MUR',
 'MORN',
 'OMF',
 'AGIO',
 'ASB',
 'LBRDA',
 'TCO',
 'H',
 'NEU',
 'CNK',
 'BFA',
 'ENR',
 'TCBI',
 'APLE',
 'DKS',
 'COMM',
 'MSM',
 'UA',
 'ALKS',
 'ESI',
 'VMI',
 'CC',
 'TRIP',
 'AA',
 'RPAI',
 'GH',
 'BKU',
 'NEWR',
 'EVR',
 'HGV',
 'BOKF',
 'PGRE',
 'AGR',
 'SC',
 'NAVI',
 'OLN',
 'CMD',
 'FLR',
 'AN',
 'KAR',
 'RIG',
 'BDN',
 'SPB',
 'TREE',
 'COLM',
 'TDC',
 'GT',
 'TDS',
 'THS',
 'CLNY',
 'MD',
 'CXP',
 'DT',
 'R',
 'CBT',
 'GHC',
 'ESRT',
 'SLGN',
 'WCC',
 'SATS',
 'STAY',
 'APY',
 'WWE',
 'WLK',
 'CLR',
 'SITC',
 'JWA',
 'OI',
 'SBGI',
 'HAIN',
 'TRN',
 'KOS',
 'UFS',
 'PINC',
 'URBN',
 'SFM',
 'NUS',
 'CNA',
 'MCY',
 'IGT',
 'TWOU',
 'ETRN',
 'PTEN',
 'PAG',
 'GO',
 'BGCP',
 'FWONA',
 'LGFB',
 'X',
 'AMCX',
 'PPC',
 'CVET',
 'EQT',
 'AM',
 'UI',
 'PS',
 'BPR',
 'SNDR',
 'SWI',
 'SWCH',
 'ADT',
 'REZI',
 'TFSL',
 'PD',
 'VIRT',
 'CRNC',
 'LENB',
 'LGFA',
 'ANAT',
 'CHNG',
 'USM',
 'CDEV',
 'MDLA',
 'RRC',
 'EAF',
 'CHK',
 'GTES',
 'AR',
 'ADPT',
 'ARD',
 'VIACA']

# %%
tickers
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'FB',
#  'GOOG',
#  'GOOGL',
#  'BRKB',
#  'JPM',
#  'JNJ',
#  'V',
#  'PG',
#  'MA',
#  'INTC',
#  'BAC',
#  'UNH',
#  'T',
#  'HD',
#  'XOM',
#  'DIS',
#  'VZ',
#  'KO',
#  'MRK',
#  'CVX',
#  'CMCSA',
#  'PEP',
#  'PFE',
#  'CSCO',
#  'ADBE',
#  'WFC',
#  'BA',
#  'C',
#  'NVDA',
#  'WMT',
#  'MCD',
#  'NFLX',
#  'CRM',
#  'MDT',
#  'BMY',
#  'ABT',
#  'PYPL',
#  'COST',
#  'ABBV',
#  'PM',
#  'NEE',
#  'ACN',
#  'TMO',
#  'AMGN',
#  'IBM',
#  'HON',
#  'UNP',
#  'NKE',
#  'UTX',
#  'TXN',
#  'AVGO',
#  'LLY',
#  'LIN',
#  'ORCL',
#  'TSLA',
#  'AMT',
#  'GE',
#  'LMT',
#  'SBUX',
#  'DHR',
#  'QCOM',
#  'LOW',
#  'FIS',
#  'CVS',
#  'AXP',
#  'MMM',
#  'GILD',
#  'MDLZ',
#  'MO',
#  'BKNG',
#  'CHTR',
#  'CI',
#  'ADP',
#  'USB',
#  'TJX',
#  'SYK',
#  'INTU',
#  'SPGI',
#  'ANTM',
#  'CME',
#  'GS',
#  'CB',
#  'CAT',
#  'UPS',
#  'DUK',
#  'TFC',
#  'SO',
#  'D',
#  'PLD',
#  'BDX',
#  'ISRG',
#  'ZTS',
#  'FISV',
#  'CCI',
#  'PNC',
#  'BLK',
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 1
# Data columns (total 75 columns):
# Market Cap (intraday) 5                           798 non-null object
# Enterprise Value 3                                798 non-null object
# Trailing P/E                                      699 non-null object
# Forward P/E 1                                     794 non-null object
# PEG Ratio (5 yr expected) 1                       786 non-null object
# Price/Sales (ttm)                                 797 non-null object
# Price/Book (mrq)                                  752 non-null object
# Enterprise Value/Revenue 3                        797 non-null object
# Enterprise Value/EBITDA 6                         740 non-null object
# Beta (5Y Monthly)                                 774 non-null object
# 52-Week Change 3                                  796 non-null object
# S&P500 52-Week Change 3                           798 non-null object
# ...

# %%
master_df["Tickers"] = tickers

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                    1.31T              1.21T        23.72         19.06
# 1                    1.31T              1.19T        30.10         27.38
# 1                   972.7B            960.26B        84.92         48.63
# 1                  559.94B            504.85B        30.55         18.01
# 1                  954.69B            816.79B        28.26         22.16
# ..                     ...                ...          ...           ...
# 1                    3.83B              7.89B        11.18          5.18
# 1                    3.88B              5.37B         8.40          9.49
# 1                    3.92B              1.19B         8.24         61.81
# 1                    5.24B              12.1B         6.55          8.25
# 1                    4.44B               5.7B        90.62         15.69
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
# master_df.to_csv('scraped_df.csv')
