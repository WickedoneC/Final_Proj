# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/Data_Redo/Models copy/cleaned_df2.csv')

# %%
df
# Out:
#       Unnamed: 0  Coupon     Yield Moody's Rating  Weight (%)   Price  \
# 0              0   5.125  4.210000            Ba3        0.02   47.79
# 1              1   5.875  3.540000            Ba3        0.02   47.79
# 2              2   3.250  3.580000             A3        0.12   52.81
# 3              3   4.000  3.440000             A3        0.12   52.81
# 4              4   6.450  2.498236             A3        0.12   52.81
# ...          ...     ...       ...            ...         ...     ...
# 6125        6125   4.000  4.160000           Baa1        0.09   38.14
# 6126        6126   2.875  2.060000           Baa1        0.09   38.14
# 6127        6127   2.600  2.270000           Baa1        0.09   38.14
# 6128        6128   3.700  2.390000             A3        0.50  189.95
# 6129        6129   3.250  1.980000             A3        0.50  189.95
#
#         Shares  Market Value  Notional Value  Market Cap (intraday) 5  ...  \
# ...

# %%
cols_drop = ['Unnamed: 0']
df.drop(columns=cols_drop, inplace=True)

# %%
pd.set_option('display.max_columns', 45)

# %%
df
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000            Ba3        0.02   47.79  119151.0
# 1      5.875  3.540000            Ba3        0.02   47.79  119151.0
# 2      3.250  3.580000             A3        0.12   52.81  543134.0
# 3      4.000  3.440000             A3        0.12   52.81  543134.0
# 4      6.450  2.498236             A3        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000           Baa1        0.09   38.14  575844.0
# 6126   2.875  2.060000           Baa1        0.09   38.14  575844.0
# 6127   2.600  2.270000           Baa1        0.09   38.14  575844.0
# 6128   3.700  2.390000             A3        0.50  189.95  621307.0
# 6129   3.250  1.980000             A3        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
# sector_drop = ['Sector', 'Exchange']
# df.drop(columns=sector_drop, inplace=True)

# %%
mdf = df[["Moody's Rating"]]

# %%
ndf = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/Data_Redo/Models copy/ntr.csv')
ndf.drop(columns=cols_drop, inplace=True)

# %%
ndf.head()
# Out:
#   Moody's Rating   Names Ticker       Name
# 0            Ba3   aecom    ACM      AECOM
# 1            Ba3   aecom    ACM      AECOM
# 2             A3  aflaci    AFL  AFLAC INC
# 3             A3  aflaci    AFL  AFLAC INC
# 4             A3  aflaci    AFL  AFLAC INC

# %%
# nmdf = pd.concat([mdf, ndf], axis=1)

# %%
# nmdf.head()

# %%
# name_drop = ['Names', 'Ticker']
# df.drop(columns=name_drop, inplace=True)

# %%
df
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000            Ba3        0.02   47.79  119151.0
# 1      5.875  3.540000            Ba3        0.02   47.79  119151.0
# 2      3.250  3.580000             A3        0.12   52.81  543134.0
# 3      4.000  3.440000             A3        0.12   52.81  543134.0
# 4      6.450  2.498236             A3        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000           Baa1        0.09   38.14  575844.0
# 6126   2.875  2.060000           Baa1        0.09   38.14  575844.0
# 6127   2.600  2.270000           Baa1        0.09   38.14  575844.0
# 6128   3.700  2.390000             A3        0.50  189.95  621307.0
# 6129   3.250  1.980000             A3        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
o = df[["Moody's Rating"]]

# %%
dfw = df.drop("Moody's Rating", axis=1)

# %%
dfc = df

# %%
dfc
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000            Ba3        0.02   47.79  119151.0
# 1      5.875  3.540000            Ba3        0.02   47.79  119151.0
# 2      3.250  3.580000             A3        0.12   52.81  543134.0
# 3      4.000  3.440000             A3        0.12   52.81  543134.0
# 4      6.450  2.498236             A3        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000           Baa1        0.09   38.14  575844.0
# 6126   2.875  2.060000           Baa1        0.09   38.14  575844.0
# 6127   2.600  2.270000           Baa1        0.09   38.14  575844.0
# 6128   3.700  2.390000             A3        0.50  189.95  621307.0
# 6129   3.250  1.980000             A3        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
data_rankings = {'Aaa':0,
'Aa1':1,
'Aa2':2,
'Aa3':3,
'A1':4,
'A2':5,
'A3':6,
'Baa1':7,
'Baa2':8,
'Baa3':9,
'Ba1':10,
'Ba2':11,
'Ba3':12,
'B1': 13,
'B2':14,
'B3':15,
'WR':16
                }

# %%
dfc["Moody's Rating"] = dfc["Moody's Rating"].replace(data_rankings)

# %%
dfw
dfc
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000             12        0.02   47.79  119151.0
# 1      5.875  3.540000             12        0.02   47.79  119151.0
# 2      3.250  3.580000              6        0.12   52.81  543134.0
# 3      4.000  3.440000              6        0.12   52.81  543134.0
# 4      6.450  2.498236              6        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000              7        0.09   38.14  575844.0
# 6126   2.875  2.060000              7        0.09   38.14  575844.0
# 6127   2.600  2.270000              7        0.09   38.14  575844.0
# 6128   3.700  2.390000              6        0.50  189.95  621307.0
# 6129   3.250  1.980000              6        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
dfc
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000             12        0.02   47.79  119151.0
# 1      5.875  3.540000             12        0.02   47.79  119151.0
# 2      3.250  3.580000              6        0.12   52.81  543134.0
# 3      4.000  3.440000              6        0.12   52.81  543134.0
# 4      6.450  2.498236              6        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000              7        0.09   38.14  575844.0
# 6126   2.875  2.060000              7        0.09   38.14  575844.0
# 6127   2.600  2.270000              7        0.09   38.14  575844.0
# 6128   3.700  2.390000              6        0.50  189.95  621307.0
# 6129   3.250  1.980000              6        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
len(df["Moody's Rating"].unique())
# Out:
# 16

# %%
y = df["Moody's Rating"]
X = df.drop("Moody's Rating", axis=1)

# %%
y
# Out:
# 0       12
# 1       12
# 2        6
# 3        6
# 4        6
#         ..
# 6125     7
# 6126     7
# 6127     7
# 6128     6
# 6129     6
# Name: Moody's Rating, Length: 6130, dtype: object

# %%
X
# Out:
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 0      5.125  4.210000        0.02   47.79  119151.0  5.694226e+06
# 1      5.875  3.540000        0.02   47.79  119151.0  5.694226e+06
# 2      3.250  3.580000        0.12   52.81  543134.0  2.868291e+07
# 3      4.000  3.440000        0.12   52.81  543134.0  2.868291e+07
# 4      6.450  2.498236        0.12   52.81  543134.0  2.868291e+07
# ...      ...       ...         ...     ...       ...           ...
# 6125   4.000  4.160000        0.09   38.14  575844.0  2.196269e+07
# 6126   2.875  2.060000        0.09   38.14  575844.0  2.196269e+07
# 6127   2.600  2.270000        0.09   38.14  575844.0  2.196269e+07
# 6128   3.700  2.390000        0.50  189.95  621307.0  1.180173e+08
# 6129   3.250  1.980000        0.50  189.95  621307.0  1.180173e+08
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# 0       5.694226e+06                     7.24          0.00          15.74
# ...

# %%
from sklearn.cluster import KMeans

# Set number of clusters at initialization time
k_means = KMeans(n_clusters=16) 


# Run the clustering algorithm
k_means.fit(X) 


# Generate cluster index values for each row
cluster_assignments = k_means.predict(X) 

# Cluster predictions for each point are also stored in k_means.labels_

# %%
pd.DataFrame(cluster_assignments)
# Out:
#       0
# 0     4
# 1     4
# 2     9
# 3     9
# 4     9
# ...  ..
# 6125  9
# 6126  9
# 6127  9
# 6128  7
# 6129  7
#
# [6130 rows x 1 columns]

# %%
r = pd.DataFrame(cluster_assignments)

# %%
r
# Out:
#       0
# 0     4
# 1     4
# 2     9
# 3     9
# 4     9
# ...  ..
# 6125  9
# 6126  9
# 6127  9
# 6128  7
# 6129  7
#
# [6130 rows x 1 columns]

# %%
k_means.labels_
# Out:
# array([4, 4, 9, ..., 9, 7, 7], dtype=int32)

# %%
# This code builds on the previous example
from sklearn.metrics import calinski_harabasz_score

# Note that we could also pass in k_means.labels_ instead of cluster_assignments
print(calinski_harabasz_score(dfc, cluster_assignments))
# Out:
# 545183.7215411083

# %%
y.size
# Out:
# 6130

# %%
from matplotlib import pyplot as plt

# %%
# Plot the data
plt.figure(figsize=(6, 6))
plt.scatter(r, y)
plt.xlabel('Predicted Ratings')
plt.ylabel('Actual Ratings')
plt.title('Visualization of raw data');

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Generate synthetic dataset with 8 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# from sklearn.cluster import KMeans
# from sklearn.datasets import make_blobs

# from yellowbrick.cluster import KElbowVisualizer

# # Generate synthetic dataset with 8 random clusters
# # X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# # Instantiate the clustering model and visualizer
# model = KMeans()
# visualizer = KElbowVisualizer(
#     model, k=(4,12), metric='calinski_harabasz', timings=False
# )

# visualizer.fit(o)        # Fit the data to the visualizer
# visualizer.show()        # Finalize and render the figure

# %%
# from sklearn.cluster import KMeans
# from sklearn.datasets import make_blobs

# from yellowbrick.cluster import KElbowVisualizer

# # Generate synthetic dataset with 8 random clusters
# # X, y = make_blobs(n_samples=1000, n_features=12, centers=8, random_state=42)

# # Instantiate the clustering model and visualizer
# model = KMeans()
# visualizer = KElbowVisualizer(
#     model, k=(4,12), metric='calinski_harabasz', timings=False, locate_elbow=False
# )

# visualizer.fit(r)        # Fit the data to the visualizer
# visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster.elbow import kelbow_visualizer
from yellowbrick.datasets.loaders import load_nfl

# X, y = load_nfl()

# Use the quick method and immediately show the figure
kelbow_visualizer(KMeans(random_state=4), X, k=(2,10))
# Out:
# KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12eb03d50>,
#                  k=None, locate_elbow=True, metric='distortion', model=None,
#                  timings=True)

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl

# Load a clustering dataset
# X, y = load_nfl()

# Specify the features to use for clustering
# features = ['Rec', 'Yds', 'TD', 'Fmb', 'Ctch_Rate']
# X = X.query('Tgt >= 20')[features]

# Instantiate the clustering model and visualizer
model = KMeans(10, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import silhouette_visualizer
from yellowbrick.datasets import load_credit

# Load a clustering dataset
# X, y = load_credit()

# Specify rows to cluster: under 40 y/o and have either graduate or university education
# X = X[(X['age'] <= 40) & (X['edu'].isin([1,2]))]

# Use the quick method and immediately show the figure
silhouette_visualizer(KMeans(12, random_state=42), X, colors='yellowbrick')
# Out:
# SilhouetteVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12ea21450>,
#                      colors='yellowbrick', is_fitted='auto', model=None)

# %%
o.head()
# Out:
#   Moody's Rating
# 0            Ba3
# 1            Ba3
# 2             A3
# 3             A3
# 4             A3

# %%
r.head()
# Out:
#    0
# 0  4
# 1  4
# 2  9
# 3  9
# 4  9

# %%
inv_map = {v: k for k, v in data_rankings.items()}

# %%
inv_map
# Out:
# {0: 'Aaa',
#  1: 'Aa1',
#  2: 'Aa2',
#  3: 'Aa3',
#  4: 'A1',
#  5: 'A2',
#  6: 'A3',
#  7: 'Baa1',
#  8: 'Baa2',
#  9: 'Baa3',
#  10: 'Ba1',
#  11: 'Ba2',
#  12: 'Ba3',
#  13: 'B1',
#  14: 'B2',
#  15: 'B3',
#  16: 'WR'}

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=12, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=15)
visualizer = InterclusterDistance(model)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Run the clustering algorithm
model.fit(X) 

# Generate cluster index values for each row
clusterings = model.predict(X) 

# Cluster predictions for each point are also stored in k_means.labels_

# %%
pd.DataFrame(clusterings)
# Out:
#       0
# 0     4
# 1     4
# 2     8
# 3     8
# 4     8
# ...  ..
# 6125  8
# 6126  8
# 6127  8
# 6128  3
# 6129  3
#
# [6130 rows x 1 columns]

# %%
km = KMeans(
    n_clusters=15, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, 
)
y_km = km.fit_predict(X)

# %%
pd.DataFrame(y_km)
# Out:
#        0
# 0     10
# 1     10
# 2      5
# 3      5
# 4      5
# ...   ..
# 6125  13
# 6126  13
# 6127  13
# 6128   2
# 6129   2
#
# [6130 rows x 1 columns]

# %%
visualizer = InterclusterDistance(km)

visualizer.fit(km)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=12, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans(15)
visualizer = InterclusterDistance(model)

visualizer.fit(r)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=12, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans(15)
visualizer = InterclusterDistance(model)

visualizer.fit(r)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import intercluster_distance


# X, _ = load_nfl()
intercluster_distance(MiniBatchKMeans(15, random_state=777), r)
# Out:
# InterclusterDistance(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12e621910>,
#                      embedding='mds', is_fitted='auto', legend=True,
#                      legend_loc='lower left', legend_size=1.5, max_size=25000,
#                      min_size=400, model=None, random_state=None,
#                      scoring='membership')

# %%
from yellowbrick.datasets import load_nfl
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import intercluster_distance


# X, _ = load_nfl()
intercluster_distance(MiniBatchKMeans(15, random_state=7), r)
# Out:
# InterclusterDistance(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12f776d90>,
#                      embedding='mds', is_fitted='auto', legend=True,
#                      legend_loc='lower left', legend_size=1.5, max_size=25000,
#                      min_size=400, model=None, random_state=None,
#                      scoring='membership')

# %%
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import intercluster_distance


# X, _ = load_nfl()
intercluster_distance(MiniBatchKMeans(15, random_state=60), X)
# Out:
# InterclusterDistance(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12ec4dd90>,
#                      embedding='mds', is_fitted='auto', legend=True,
#                      legend_loc='lower left', legend_size=1.5, max_size=25000,
#                      min_size=400, model=None, random_state=None,
#                      scoring='membership')

# %%
o
# Out:
#      Moody's Rating
# 0               Ba3
# 1               Ba3
# 2                A3
# 3                A3
# 4                A3
# ...             ...
# 6125           Baa1
# 6126           Baa1
# 6127           Baa1
# 6128             A3
# 6129             A3
#
# [6130 rows x 1 columns]

# %%
r["Moody's Rating"] = r[0]

# %%
r.drop(0, axis=1, inplace=True)

# %%
r
# Out:
#       Moody's Rating
# 0                  4
# 1                  4
# 2                  9
# 3                  9
# 4                  9
# ...              ...
# 6125               9
# 6126               9
# 6127               9
# 6128               7
# 6129               7
#
# [6130 rows x 1 columns]

# %%
X
# Out:
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 0      5.125  4.210000        0.02   47.79  119151.0  5.694226e+06
# 1      5.875  3.540000        0.02   47.79  119151.0  5.694226e+06
# 2      3.250  3.580000        0.12   52.81  543134.0  2.868291e+07
# 3      4.000  3.440000        0.12   52.81  543134.0  2.868291e+07
# 4      6.450  2.498236        0.12   52.81  543134.0  2.868291e+07
# ...      ...       ...         ...     ...       ...           ...
# 6125   4.000  4.160000        0.09   38.14  575844.0  2.196269e+07
# 6126   2.875  2.060000        0.09   38.14  575844.0  2.196269e+07
# 6127   2.600  2.270000        0.09   38.14  575844.0  2.196269e+07
# 6128   3.700  2.390000        0.50  189.95  621307.0  1.180173e+08
# 6129   3.250  1.980000        0.50  189.95  621307.0  1.180173e+08
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# 0       5.694226e+06                     7.24          0.00          15.74
# ...

# %%
from sklearn.cluster import KMeans

# Set number of clusters at initialization time
k_means = KMeans(n_clusters=15) 

# Run the clustering algorithm
k_means.fit(X) 

# Generate cluster index values for each row
cluster_assignments = k_means.predict(X) 

# Cluster predictions for each point are also stored in k_means.labels_

# %%
from yellowbrick.datasets import load_nfl
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import intercluster_distance


# X, _ = load_nfl()
intercluster_distance(MiniBatchKMeans(15, random_state=63), X)
# Out:
# InterclusterDistance(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x12fa25cd0>,
#                      embedding='mds', is_fitted='auto', legend=True,
#                      legend_loc='lower left', legend_size=1.5, max_size=25000,
#                      min_size=400, model=None, random_state=None,
#                      scoring='membership')

# %%
r = pd.DataFrame(cluster_assignments)

# %%
r
r["Moody's Rating"] = r[0]
r.drop(0, axis=1, inplace=True)
r
# Out:
#       Moody's Rating
# 0                 13
# 1                 13
# 2                  8
# 3                  8
# 4                  8
# ...              ...
# 6125              12
# 6126              12
# 6127              12
# 6128               5
# 6129               5
#
# [6130 rows x 1 columns]

# %%
(o["Moody's Rating"] == r["Moody's Rating"]).value_counts()
# Out:
# False    6130
# Name: Moody's Rating, dtype: int64

# %%
p = o.replace(data_rankings)

# %%
p
# Out:
#      Moody's Rating
# 0                12
# 1                12
# 2                 6
# 3                 6
# 4                 6
# ...             ...
# 6125              7
# 6126              7
# 6127              7
# 6128              6
# 6129              6
#
# [6130 rows x 1 columns]

# %%
r
# Out:
#       Moody's Rating
# 0                 13
# 1                 13
# 2                  8
# 3                  8
# 4                  8
# ...              ...
# 6125              12
# 6126              12
# 6127              12
# 6128               5
# 6129               5
#
# [6130 rows x 1 columns]

# %%
p
# Out:
#      Moody's Rating
# 0                12
# 1                12
# 2                 6
# 3                 6
# 4                 6
# ...             ...
# 6125              7
# 6126              7
# 6127              7
# 6128              6
# 6129              6
#
# [6130 rows x 1 columns]

# %%
test_val = p["Moody's Rating"] - r["Moody's Rating"]

# %%
test_val.mean()
# Out:
# -1.3172920065252856

# %%
mean_diff_rating = test_val.mean()
mean_diff_rating
# Out:
# -1.3172920065252856

# %%
inv_map
# Out:
# {0: 'Aaa',
#  1: 'Aa1',
#  2: 'Aa2',
#  3: 'Aa3',
#  4: 'A1',
#  5: 'A2',
#  6: 'A3',
#  7: 'Baa1',
#  8: 'Baa2',
#  9: 'Baa3',
#  10: 'Ba1',
#  11: 'Ba2',
#  12: 'Ba3',
#  13: 'B1',
#  14: 'B2',
#  15: 'B3',
#  16: 'WR'}

# %%
r.head()
# Out:
#    Moody's Rating
# 0              13
# 1              13
# 2               8
# 3               8
# 4               8

# %%
r["Moody's Rating"] = r["Moody's Rating"].replace(inv_map)

# %%
r.head()
# Out:
#   Moody's Rating
# 0             B1
# 1             B1
# 2           Baa2
# 3           Baa2
# 4           Baa2

# %%
r["Predicted Rating"] = r["Moody's Rating"]

# %%
r.head()
# Out:
#   Moody's Rating Predicted Rating
# 0             B1               B1
# 1             B1               B1
# 2           Baa2             Baa2
# 3           Baa2             Baa2
# 4           Baa2             Baa2

# %%
r.drop("Moody's Rating", axis=1, inplace=True)

# %%
r.head()
# Out:
#   Predicted Rating
# 0               B1
# 1               B1
# 2             Baa2
# 3             Baa2
# 4             Baa2

# %%
o.head()
# Out:
#   Moody's Rating
# 0            Ba3
# 1            Ba3
# 2             A3
# 3             A3
# 4             A3

# %%
o["Moody's Rating"] = o["Moody's Rating"].replace(inv_map)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
o.head()
# Out:
#   Moody's Rating
# 0            Ba3
# 1            Ba3
# 2             A3
# 3             A3
# 4             A3

# %%
X.head()
# Out:
#    Coupon     Yield  Weight (%)  Price    Shares  Market Value  \
# 0   5.125  4.210000        0.02  47.79  119151.0    5694226.29
# 1   5.875  3.540000        0.02  47.79  119151.0    5694226.29
# 2   3.250  3.580000        0.12  52.81  543134.0   28682906.54
# 3   4.000  3.440000        0.12  52.81  543134.0   28682906.54
# 4   6.450  2.498236        0.12  52.81  543134.0   28682906.54
#
#    Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# 0      5694226.29                     7.24          0.00          15.74
# 1      5694226.29                     7.24          0.00          15.74
# 2     28682906.54                    32.72         10.22           9.76
# 3     28682906.54                    32.72         10.22           9.76
# 4     28682906.54                    32.72         10.22           9.76
#
#    PEG Ratio (5 yr expected) 1  Price/Sales (ttm)  Price/Book (mrq)  \
# 0                         1.58               0.36              1.97
# ...

# %%
ndf
# Out:
#      Moody's Rating   Names Ticker                Name
# 0               Ba3   aecom    ACM               AECOM
# 1               Ba3   aecom    ACM               AECOM
# 2                A3  aflaci    AFL           AFLAC INC
# 3                A3  aflaci    AFL           AFLAC INC
# 4                A3  aflaci    AFL           AFLAC INC
# ...             ...     ...    ...                 ...
# 6125           Baa1  ebayin   EBAY            EBAY INC
# 6126           Baa1  ebayin   EBAY            EBAY INC
# 6127           Baa1  ebayin   EBAY            EBAY INC
# 6128             A3  salesf    CRM  SALESFORCE.COM INC
# 6129             A3  salesf    CRM  SALESFORCE.COM INC
#
# [6130 rows x 4 columns]

# %%
names_x = pd.concat([ndf, X], axis=1)

# %%
names_x.head()
# Out:
#   Moody's Rating   Names Ticker       Name  Coupon     Yield  Weight (%)  \
# 0            Ba3   aecom    ACM      AECOM   5.125  4.210000        0.02
# 1            Ba3   aecom    ACM      AECOM   5.875  3.540000        0.02
# 2             A3  aflaci    AFL  AFLAC INC   3.250  3.580000        0.12
# 3             A3  aflaci    AFL  AFLAC INC   4.000  3.440000        0.12
# 4             A3  aflaci    AFL  AFLAC INC   6.450  2.498236        0.12
#
#    Price    Shares  Market Value  Notional Value  Market Cap (intraday) 5  \
# 0  47.79  119151.0    5694226.29      5694226.29                     7.24
# 1  47.79  119151.0    5694226.29      5694226.29                     7.24
# 2  52.81  543134.0   28682906.54     28682906.54                    32.72
# 3  52.81  543134.0   28682906.54     28682906.54                    32.72
# 4  52.81  543134.0   28682906.54     28682906.54                    32.72
#
#    Trailing P/E  Forward P/E 1  PEG Ratio (5 yr expected) 1  \
# ...

# %%
rx = pd.concat([r, names_x], axis=1)

# %%
rx.head()
# Out:
#   Predicted Rating Moody's Rating   Names Ticker       Name  Coupon     Yield  \
# 0               B1            Ba3   aecom    ACM      AECOM   5.125  4.210000
# 1               B1            Ba3   aecom    ACM      AECOM   5.875  3.540000
# 2             Baa2             A3  aflaci    AFL  AFLAC INC   3.250  3.580000
# 3             Baa2             A3  aflaci    AFL  AFLAC INC   4.000  3.440000
# 4             Baa2             A3  aflaci    AFL  AFLAC INC   6.450  2.498236
#
#    Weight (%)  Price    Shares  Market Value  Notional Value  \
# 0        0.02  47.79  119151.0    5694226.29      5694226.29
# 1        0.02  47.79  119151.0    5694226.29      5694226.29
# 2        0.12  52.81  543134.0   28682906.54     28682906.54
# 3        0.12  52.81  543134.0   28682906.54     28682906.54
# 4        0.12  52.81  543134.0   28682906.54     28682906.54
#
#    Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# 0                     7.24          0.00          15.74
# ...

# %%
rx["Predicted Rating"].value_counts()
# Out:
# B1      1472
# Baa2     951
# Ba3      710
# Aa3      701
# Aaa      576
# Baa1     301
# Ba1      293
# Aa2      285
# A2       247
# B2       215
# Baa3     140
# A3        92
# Aa1       71
# Ba2       64
# A1        12
# Name: Predicted Rating, dtype: int64

# %%
r
# Out:
#      Predicted Rating
# 0                  B1
# 1                  B1
# 2                Baa2
# 3                Baa2
# 4                Baa2
# ...               ...
# 6125              Ba3
# 6126              Ba3
# 6127              Ba3
# 6128               A2
# 6129               A2
#
# [6130 rows x 1 columns]

# %%
rx
# Out:
#      Predicted Rating Moody's Rating   Names Ticker                Name  \
# 0                  B1            Ba3   aecom    ACM               AECOM
# 1                  B1            Ba3   aecom    ACM               AECOM
# 2                Baa2             A3  aflaci    AFL           AFLAC INC
# 3                Baa2             A3  aflaci    AFL           AFLAC INC
# 4                Baa2             A3  aflaci    AFL           AFLAC INC
# ...               ...            ...     ...    ...                 ...
# 6125              Ba3           Baa1  ebayin   EBAY            EBAY INC
# 6126              Ba3           Baa1  ebayin   EBAY            EBAY INC
# 6127              Ba3           Baa1  ebayin   EBAY            EBAY INC
# 6128               A2             A3  salesf    CRM  SALESFORCE.COM INC
# 6129               A2             A3  salesf    CRM  SALESFORCE.COM INC
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# ...

# %%
cols = ["Predicted Rating", "Moody's Rating"]

# %%
t = rx[cols]

# %%
t.apply(pd.Series.value_counts)
# Out:
#       Predicted Rating  Moody's Rating
# A1                12.0             293
# A2               247.0             976
# A3                92.0            1050
# Aa1               71.0              37
# Aa2              285.0              94
# Aa3              701.0              95
# Aaa              576.0             104
# B1              1472.0              18
# B2               215.0              56
# B3                 NaN              30
# Ba1              293.0             170
# Ba2               64.0              53
# Ba3              710.0             109
# Baa1             301.0            1341
# Baa2             951.0             865
# Baa3             140.0             839

# %%
rx.loc[rx['Predicted Rating'] == "Baa3"]
# Out:
#      Predicted Rating Moody's Rating   Names Ticker          Name  Coupon  \
# 2126             Baa3            Aa2  chevro    CVX  CHEVRON CORP  3.3260
# 2127             Baa3            Aa2  chevro    CVX  CHEVRON CORP  3.3260
# 2128             Baa3            Aa2  chevro    CVX  CHEVRON CORP  2.6418
# 2129             Baa3            Aa2  chevro    CVX  CHEVRON CORP  2.4110
# 2130             Baa3            Aa2  chevro    CVX  CHEVRON CORP  2.3550
# ...               ...            ...     ...    ...           ...     ...
# 4558             Baa3             A1  pfizer    PFE    PFIZER INC  4.2000
# 4559             Baa3             A1  pfizer    PFE    PFIZER INC  2.9500
# 4560             Baa3             A1  pfizer    PFE    PFIZER INC  2.2236
# 4561             Baa3             A1  pfizer    PFE    PFIZER INC  6.6000
# 4562             Baa3             A1  pfizer    PFE    PFIZER INC  2.7500
#
#          Yield  Weight (%)   Price     Shares  Market Value  Notional Value  \
# ...

# %%
rx.loc[rx["Moody's Rating"] == "B3"]
# Out:
#      Predicted Rating Moody's Rating   Names Ticker  \
# 2360              Aa3             B3  cooper    COO
# 2426               B1             B3  diamon   FANG
# 2427               B1             B3  diamon   FANG
# 2428               B1             B3  diamon   FANG
# 4031               B1             B3  mattel    MAT
# 4953               B1             B3  sprint      S
# 4954               B1             B3  sprint      S
# 4955               B1             B3  sprint      S
# 4956               B1             B3  sprint      S
# 4957               B1             B3  sprint      S
# 4958               B1             B3  sprint      S
# 4959               B1             B3  sprint      S
# 4961               B1             B3  sprint      S
# 4964               B1             B3  sprint      S
# 5071              Ba3             B3  transd    TDG
# 5072              Ba3             B3  transd    TDG
# 5073              Ba3             B3  transd    TDG
# ...

# %%
cols = ["Predicted Rating", "Moody's Rating"]

# %%
rx.groupby(rx["Predicted Rating"]).count()
# Out:
#                   Moody's Rating  Names  Ticker  Name  Coupon  Yield  \
# Predicted Rating
# A1                            12     12      12    12      12     12
# A2                           247    247     247   247     247    247
# A3                            92     92      92    92      92     92
# Aa1                           71     71      71    71      71     71
# Aa2                          285    285     285   285     285    285
# Aa3                          701    701     701   701     701    701
# Aaa                          576    576     576   576     576    576
# B1                          1472   1472    1472  1472    1472   1472
# B2                           215    215     215   215     215    215
# Ba1                          293    293     293   293     293    293
# Ba2                           64     64      64    64      64     64
# Ba3                          710    710     710   710     710    710
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=12, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=15)
visualizer = InterclusterDistance(k_means)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# cluster_assignments
# k_means

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Generate synthetic dataset with 12 random clusters
# X, y = make_blobs(n_samples=1000, n_features=12, centers=12, random_state=42)

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=16)
visualizer = InterclusterDistance(model)

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# cluster_assignments
# k_means

# %%
z = model.predict(X)

# %%
k = pd.DataFrame(z, columns=['Predicted'])

# %%
k
# Out:
#       Predicted
# 0             8
# 1             8
# 2             2
# 3             2
# 4             2
# ...         ...
# 6125          2
# 6126          2
# 6127          2
# 6128          0
# 6129          0
#
# [6130 rows x 1 columns]

# %%
k['Predicted']
# Out:
# 0       8
# 1       8
# 2       2
# 3       2
# 4       2
#        ..
# 6125    2
# 6126    2
# 6127    2
# 6128    0
# 6129    0
# Name: Predicted, Length: 6130, dtype: int32

# %%
p
# Out:
#      Moody's Rating
# 0                12
# 1                12
# 2                 6
# 3                 6
# 4                 6
# ...             ...
# 6125              7
# 6126              7
# 6127              7
# 6128              6
# 6129              6
#
# [6130 rows x 1 columns]

# %%
test_val = p["Moody's Rating"] - k['Predicted']

# %%
test_val
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 6125    5
# 6126    5
# 6127    5
# 6128    6
# 6129    6
# Length: 6130, dtype: object

# %%
test_val.mean()
# Out:
# -1.3546492659053833

# %%
(p["Moody's Rating"] == k['Predicted']).value_counts()
# Out:
# False    5610
# True      520
# dtype: int64

# %%
q = r.replace(data_rankings)

# %%
p
# Out:
#      Moody's Rating
# 0                12
# 1                12
# 2                 6
# 3                 6
# 4                 6
# ...             ...
# 6125              7
# 6126              7
# 6127              7
# 6128              6
# 6129              6
#
# [6130 rows x 1 columns]

# %%
k
# Out:
#       Predicted
# 0             8
# 1             8
# 2             2
# 3             2
# 4             2
# ...         ...
# 6125          2
# 6126          2
# 6127          2
# 6128          0
# 6129          0
#
# [6130 rows x 1 columns]

# %%
df
# Out:
#       Coupon     Yield Moody's Rating  Weight (%)   Price    Shares  \
# 0      5.125  4.210000             12        0.02   47.79  119151.0
# 1      5.875  3.540000             12        0.02   47.79  119151.0
# 2      3.250  3.580000              6        0.12   52.81  543134.0
# 3      4.000  3.440000              6        0.12   52.81  543134.0
# 4      6.450  2.498236              6        0.12   52.81  543134.0
# ...      ...       ...            ...         ...     ...       ...
# 6125   4.000  4.160000              7        0.09   38.14  575844.0
# 6126   2.875  2.060000              7        0.09   38.14  575844.0
# 6127   2.600  2.270000              7        0.09   38.14  575844.0
# 6128   3.700  2.390000              6        0.50  189.95  621307.0
# 6129   3.250  1.980000              6        0.50  189.95  621307.0
#
#       Market Value  Notional Value  Market Cap (intraday) 5  Trailing P/E  \
# 0     5.694226e+06    5.694226e+06                     7.24          0.00
# ...

# %%
ndf
# Out:
#      Moody's Rating   Names Ticker                Name
# 0               Ba3   aecom    ACM               AECOM
# 1               Ba3   aecom    ACM               AECOM
# 2                A3  aflaci    AFL           AFLAC INC
# 3                A3  aflaci    AFL           AFLAC INC
# 4                A3  aflaci    AFL           AFLAC INC
# ...             ...     ...    ...                 ...
# 6125           Baa1  ebayin   EBAY            EBAY INC
# 6126           Baa1  ebayin   EBAY            EBAY INC
# 6127           Baa1  ebayin   EBAY            EBAY INC
# 6128             A3  salesf    CRM  SALESFORCE.COM INC
# 6129             A3  salesf    CRM  SALESFORCE.COM INC
#
# [6130 rows x 4 columns]

# %%
ndf = ndf.drop(columns="Names")
ndf
# Out:
#      Moody's Rating Ticker                Name
# 0               Ba3    ACM               AECOM
# 1               Ba3    ACM               AECOM
# 2                A3    AFL           AFLAC INC
# 3                A3    AFL           AFLAC INC
# 4                A3    AFL           AFLAC INC
# ...             ...    ...                 ...
# 6125           Baa1   EBAY            EBAY INC
# 6126           Baa1   EBAY            EBAY INC
# 6127           Baa1   EBAY            EBAY INC
# 6128             A3    CRM  SALESFORCE.COM INC
# 6129             A3    CRM  SALESFORCE.COM INC
#
# [6130 rows x 3 columns]

# %%
display_df = pd.concat([ndf, df], axis=1)

# %%
display_df
# Out:
#      Moody's Rating Ticker                Name  Coupon     Yield  \
# 0               Ba3    ACM               AECOM   5.125  4.210000
# 1               Ba3    ACM               AECOM   5.875  3.540000
# 2                A3    AFL           AFLAC INC   3.250  3.580000
# 3                A3    AFL           AFLAC INC   4.000  3.440000
# 4                A3    AFL           AFLAC INC   6.450  2.498236
# ...             ...    ...                 ...     ...       ...
# 6125           Baa1   EBAY            EBAY INC   4.000  4.160000
# 6126           Baa1   EBAY            EBAY INC   2.875  2.060000
# 6127           Baa1   EBAY            EBAY INC   2.600  2.270000
# 6128             A3    CRM  SALESFORCE.COM INC   3.700  2.390000
# 6129             A3    CRM  SALESFORCE.COM INC   3.250  1.980000
#
#      Moody's Rating  Weight (%)   Price    Shares  Market Value  \
# 0                12        0.02   47.79  119151.0  5.694226e+06
# ...

# %%
finished_df = pd.concat([k, display_df], axis=1)
finished_df
# Out:
#       Predicted Moody's Rating Ticker                Name  Coupon     Yield  \
# 0             8            Ba3    ACM               AECOM   5.125  4.210000
# 1             8            Ba3    ACM               AECOM   5.875  3.540000
# 2             2             A3    AFL           AFLAC INC   3.250  3.580000
# 3             2             A3    AFL           AFLAC INC   4.000  3.440000
# 4             2             A3    AFL           AFLAC INC   6.450  2.498236
# ...         ...            ...    ...                 ...     ...       ...
# 6125          2           Baa1   EBAY            EBAY INC   4.000  4.160000
# 6126          2           Baa1   EBAY            EBAY INC   2.875  2.060000
# 6127          2           Baa1   EBAY            EBAY INC   2.600  2.270000
# 6128          0             A3    CRM  SALESFORCE.COM INC   3.700  2.390000
# 6129          0             A3    CRM  SALESFORCE.COM INC   3.250  1.980000
#
# ...

# %%
k
# Out:
#       Predicted
# 0             8
# 1             8
# 2             2
# 3             2
# 4             2
# ...         ...
# 6125          2
# 6126          2
# 6127          2
# 6128          0
# 6129          0
#
# [6130 rows x 1 columns]

# %%
z = k.replace(inv_map)

# %%
finished_df["Predicted"] = z

# %%
finished_df
# Out:
#      Predicted Moody's Rating Ticker                Name  Coupon     Yield  \
# 0         Baa2            Ba3    ACM               AECOM   5.125  4.210000
# 1         Baa2            Ba3    ACM               AECOM   5.875  3.540000
# 2          Aa2             A3    AFL           AFLAC INC   3.250  3.580000
# 3          Aa2             A3    AFL           AFLAC INC   4.000  3.440000
# 4          Aa2             A3    AFL           AFLAC INC   6.450  2.498236
# ...        ...            ...    ...                 ...     ...       ...
# 6125       Aa2           Baa1   EBAY            EBAY INC   4.000  4.160000
# 6126       Aa2           Baa1   EBAY            EBAY INC   2.875  2.060000
# 6127       Aa2           Baa1   EBAY            EBAY INC   2.600  2.270000
# 6128       Aaa             A3    CRM  SALESFORCE.COM INC   3.700  2.390000
# 6129       Aaa             A3    CRM  SALESFORCE.COM INC   3.250  1.980000
#
#      Moody's Rating  Weight (%)   Price    Shares  Market Value  \
# ...

# %%
finished_df = finished_df.drop([finished_df.columns[6]] ,  axis='columns')
finished_df
# Out:
#      Predicted Ticker                Name  Coupon     Yield  Weight (%)  \
# 0         Baa2    ACM               AECOM   5.125  4.210000        0.02
# 1         Baa2    ACM               AECOM   5.875  3.540000        0.02
# 2          Aa2    AFL           AFLAC INC   3.250  3.580000        0.12
# 3          Aa2    AFL           AFLAC INC   4.000  3.440000        0.12
# 4          Aa2    AFL           AFLAC INC   6.450  2.498236        0.12
# ...        ...    ...                 ...     ...       ...         ...
# 6125       Aa2   EBAY            EBAY INC   4.000  4.160000        0.09
# 6126       Aa2   EBAY            EBAY INC   2.875  2.060000        0.09
# 6127       Aa2   EBAY            EBAY INC   2.600  2.270000        0.09
# 6128       Aaa    CRM  SALESFORCE.COM INC   3.700  2.390000        0.50
# 6129       Aaa    CRM  SALESFORCE.COM INC   3.250  1.980000        0.50
#
#        Price    Shares  Market Value  Notional Value  Market Cap (intraday) 5  \
# ...

# %%
finished_df = pd.concat([o, finished_df], axis=1)
finished_df
# Out:
#      Moody's Rating Predicted Ticker                Name  Coupon     Yield  \
# 0               Ba3      Baa2    ACM               AECOM   5.125  4.210000
# 1               Ba3      Baa2    ACM               AECOM   5.875  3.540000
# 2                A3       Aa2    AFL           AFLAC INC   3.250  3.580000
# 3                A3       Aa2    AFL           AFLAC INC   4.000  3.440000
# 4                A3       Aa2    AFL           AFLAC INC   6.450  2.498236
# ...             ...       ...    ...                 ...     ...       ...
# 6125           Baa1       Aa2   EBAY            EBAY INC   4.000  4.160000
# 6126           Baa1       Aa2   EBAY            EBAY INC   2.875  2.060000
# 6127           Baa1       Aa2   EBAY            EBAY INC   2.600  2.270000
# 6128             A3       Aaa    CRM  SALESFORCE.COM INC   3.700  2.390000
# 6129             A3       Aaa    CRM  SALESFORCE.COM INC   3.250  1.980000
#
#       Weight (%)   Price    Shares  Market Value  Notional Value  \
# ...

# %%
finished_df.loc[finished_df["Moody's Rating"] == "Ba3"].sample(6)
# Out:
#      Moody's Rating Predicted Ticker                      Name  Coupon  Yield  \
# 5289            Ba3      Baa2   UTHR  UNITED THERAPEUTICS CORP   4.875   4.29
# 5308            Ba3        A1    UNH    UNITEDHEALTH GROUP INC   6.500   4.88
# 5331            Ba3      Baa2   UTHR  UNITED THERAPEUTICS CORP   5.500   4.62
# 102             Ba3      Baa2    AAP    ADVANCE AUTO PARTS INC   7.500   2.35
# 4794            Ba3      Baa2    SLM                  SLM CORP   5.625   7.40
# 5174            Ba3      Baa2    URI        UNITED RENTALS INC   6.000   2.05
#
#       Weight (%)   Price    Shares  Market Value  Notional Value  \
# 5289        0.02  104.19   33848.0  3.526623e+06    3.526623e+06
# 5308        0.90  298.78  707073.0  2.112593e+08    2.112593e+08
# 5331        0.02  104.19   33848.0  3.526623e+06    3.526623e+06
# 102         0.03  133.59   49210.0  6.573964e+06    6.573964e+06
# 4794        0.02   12.06  300555.0  3.624693e+06    3.624693e+06
# ...

# %%
finished_df.loc[finished_df["Moody's Rating"] == "Baa1"].sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 2648           Baa1       Aa2     EA                 ELECTRONIC ARTS INC
# 3023           Baa1       Aa2    GIS                   GENERAL MILLS INC
# 874            Baa1      Baa2    ACC  AMERICAN CAMPUS COMMUNITIES REIT I
# 1371           Baa1        B1    ADI                  ANALOG DEVICES INC
# 1736           Baa1        A3   BIIB                          BIOGEN INC
# 1943           Baa1        B1    CSX                            CSX CORP
# 4163           Baa1       Ba2   MDLZ  MONDELEZ INTERNATIONAL INC CLASS A
# 3049           Baa1        B1     GD               GENERAL DYNAMICS CORP
# 1277           Baa1        B1    AEP         AMERICAN ELECTRIC POWER INC
# 5393           Baa1       Ba1    UTX            UNITED TECHNOLOGIES CORP
#
#       Coupon      Yield  Weight (%)   Price     Shares  Market Value  \
# 2648    3.70   1.770000        0.10  109.69   216860.0   23787373.40
# ...

# %%
finished_df.loc[finished_df["Moody's Rating"] == "A3"].sample(10)
# Out:
#      Moody's Rating Predicted Ticker                               Name  \
# 5730             A3        A3    UPS  UNITED PARCEL SERVICE INC CLASS B
# 5751             A3      Baa2   UTHR           UNITED THERAPEUTICS CORP
# 4591             A3       Aa2    PSX                           PHILLIPS
# 142              A3       Ba2     MO                   ALTRIA GROUP INC
# 2272             A3      Baa3  CMCSA               COMCAST CORP CLASS A
# 2242             A3      Baa3  CMCSA               COMCAST CORP CLASS A
# 363              A3      Baa2   COLD             AMERICOLD REALTY TRUST
# 445              A3        A2    AMT           AMERICAN TOWER REIT CORP
# 5660             A3      Baa2    URI                 UNITED RENTALS INC
# 3879             A3        B1   LRCX                  LAM RESEARCH CORP
#
#       Coupon  Yield  Weight (%)   Price     Shares  Market Value  \
# 5730  3.8750   3.53        0.24  105.95   521902.0  5.529552e+07
# ...

# %%
finished_df["Moody's Rating"].value_counts()
# Out:
# Baa1    1341
# A3      1050
# A2       976
# Baa2     865
# Baa3     839
# A1       293
# Ba1      170
# Ba3      109
# Aaa      104
# Aa3       95
# Aa2       94
# B2        56
# Ba2       53
# Aa1       37
# B3        30
# B1        18
# Name: Moody's Rating, dtype: int64

# %%
o
# Out:
#      Moody's Rating
# 0               Ba3
# 1               Ba3
# 2                A3
# 3                A3
# 4                A3
# ...             ...
# 6125           Baa1
# 6126           Baa1
# 6127           Baa1
# 6128             A3
# 6129             A3
#
# [6130 rows x 1 columns]

# %%
finished_df.loc[finished_df["Moody's Rating"] == "Ba3"]
# Out:
#      Moody's Rating Predicted Ticker                               Name  \
# 0               Ba3      Baa2    ACM                              AECOM
# 1               Ba3      Baa2    ACM                              AECOM
# 101             Ba3        B1    AMD         ADVANCED MICRO DEVICES INC
# 102             Ba3      Baa2    AAP             ADVANCE AUTO PARTS INC
# 2147            Ba3        B2   CINF          CINCINNATI FINANCIAL CORP
# ...             ...       ...    ...                                ...
# 5333            Ba3       Ba1    UTX           UNITED TECHNOLOGIES CORP
# 5334            Ba3        A3    UPS  UNITED PARCEL SERVICE INC CLASS B
# 5335            Ba3        B2    UAL       UNITED AIRLINES HOLDINGS INC
# 5336            Ba3      Baa2    URI                 UNITED RENTALS INC
# 5337            Ba3      Baa2   UTHR           UNITED THERAPEUTICS CORP
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# ...

# %%
finished_df
# Out:
#      Moody's Rating Predicted Ticker                Name  Coupon     Yield  \
# 0               Ba3      Baa2    ACM               AECOM   5.125  4.210000
# 1               Ba3      Baa2    ACM               AECOM   5.875  3.540000
# 2                A3       Aa2    AFL           AFLAC INC   3.250  3.580000
# 3                A3       Aa2    AFL           AFLAC INC   4.000  3.440000
# 4                A3       Aa2    AFL           AFLAC INC   6.450  2.498236
# ...             ...       ...    ...                 ...     ...       ...
# 6125           Baa1       Aa2   EBAY            EBAY INC   4.000  4.160000
# 6126           Baa1       Aa2   EBAY            EBAY INC   2.875  2.060000
# 6127           Baa1       Aa2   EBAY            EBAY INC   2.600  2.270000
# 6128             A3       Aaa    CRM  SALESFORCE.COM INC   3.700  2.390000
# 6129             A3       Aaa    CRM  SALESFORCE.COM INC   3.250  1.980000
#
#       Weight (%)   Price    Shares  Market Value  Notional Value  \
# ...

# %%
test_df = finished_df

# %%
test_df.set_index("Ticker")
# Out:
#        Moody's Rating Predicted                Name  Coupon     Yield  \
# Ticker
# ACM               Ba3      Baa2               AECOM   5.125  4.210000
# ACM               Ba3      Baa2               AECOM   5.875  3.540000
# AFL                A3       Aa2           AFLAC INC   3.250  3.580000
# AFL                A3       Aa2           AFLAC INC   4.000  3.440000
# AFL                A3       Aa2           AFLAC INC   6.450  2.498236
# ...               ...       ...                 ...     ...       ...
# EBAY             Baa1       Aa2            EBAY INC   4.000  4.160000
# EBAY             Baa1       Aa2            EBAY INC   2.875  2.060000
# EBAY             Baa1       Aa2            EBAY INC   2.600  2.270000
# CRM                A3       Aaa  SALESFORCE.COM INC   3.700  2.390000
# CRM                A3       Aaa  SALESFORCE.COM INC   3.250  1.980000
#
#         Weight (%)   Price    Shares  Market Value  Notional Value  \
# Ticker
# ...

# %%
test_df.loc[test_df["Ticker"] == "APPL"]
# Out:
# Empty DataFrame
# Columns: [Moody's Rating, Predicted, Ticker, Name, Coupon, Yield, Weight (%), Price, Shares, Market Value, Notional Value, Market Cap (intraday) 5, Trailing P/E, Forward P/E 1, PEG Ratio (5 yr expected) 1, Price/Sales (ttm), Price/Book (mrq), Beta (5Y Monthly), S&P500 52-Week Change 3, % Held by Insiders 1, % Held by Institutions 1, Avg Vol (10 day) 3, Avg Vol (3 month) 3, Shares Outstanding 5, Profit Margin, Operating Margin (ttm), Return on Assets (ttm), Revenue Per Share (ttm), Quarterly Revenue Growth (yoy), Total Cash Per Share (mrq), Total Debt (mrq), Book Value Per Share (mrq), Days_to_Maturity]
# Index: []

# %%
test_df.loc[test_df["Ticker"] == "VZ"]
# Out:
#      Moody's Rating Predicted Ticker                        Name  Coupon  \
# 5809           Baa2        B3     VZ  VERIZON COMMUNICATIONS INC  6.9400
# 5810           Baa2        B3     VZ  VERIZON COMMUNICATIONS INC  8.7500
# 5811           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  6.9000
# 5812           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  3.4500
# 5813           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  4.2720
# 5814           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  3.8750
# 5815           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  7.7500
# 5816           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  5.8500
# 5817           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  7.3500
# 5818           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  6.4000
# 5819           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  4.6000
# 5820           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC  5.1500
# ...

# %%
test_df.loc[test_df["Ticker"] == "MSFT"]
# Out:
#      Moody's Rating Predicted Ticker            Name  Coupon  Yield  \
# 4110            Aaa       Aa1   MSFT  MICROSOFT CORP   4.875   3.08
# 4111            Aaa       Aa1   MSFT  MICROSOFT CORP   4.500   3.16
# 4112            Aaa       Aa1   MSFT  MICROSOFT CORP   3.000   1.33
# 4113            Aaa       Aa1   MSFT  MICROSOFT CORP   2.700   1.98
# 4114            Aaa       Aa1   MSFT  MICROSOFT CORP   2.000   1.78
# 4115            Aaa       Aa1   MSFT  MICROSOFT CORP   4.000   1.38
# 4116            Aaa       Aa1   MSFT  MICROSOFT CORP   2.375   1.84
# 4117            Aaa       Aa1   MSFT  MICROSOFT CORP   2.400   2.09
# 4118            Aaa       Aa1   MSFT  MICROSOFT CORP   3.500   2.68
# 4119            Aaa       Aa1   MSFT  MICROSOFT CORP   4.200   2.78
# 4120            Aaa       Aa1   MSFT  MICROSOFT CORP   2.400   1.72
# 4121            Aaa       Aa1   MSFT  MICROSOFT CORP   4.000   3.13
# 4122            Aaa       Aa1   MSFT  MICROSOFT CORP   4.750   3.16
# ...

# %%
test_df.Ticker.unique()
# Out:
# array(['ACM', 'AFL', 'T', 'ABBV', 'ABT', 'ATVI', 'ADBE', 'AMD', 'AAP',
#        'A', 'APD', 'ALB', 'ARE', 'Y', 'ALLE', 'AGN', 'ALLY', 'GOOG',
#        'GOOGL', 'MO', 'AMZN', 'AEE', 'AMT', 'AXP', 'AEP', 'AIG', 'AWK',
#        'AAL', 'AFG', 'AMH', 'COLD', 'ACC', 'AMP', 'ABC', 'AMGN', 'APH',
#        'ADI', 'ANTM', 'APA', 'AAPL', 'AMAT', 'ADM', 'ARNC', 'ARW', 'ASH',
#        'AIZ', 'AGO', 'ATO', 'AZO', 'ADSK', 'ADP', 'AVB', 'AVY', 'BKR',
#        'BLL', 'BAC', 'BK', 'BAX', 'BDX', 'BERY', 'BBY', 'BIO', 'BIIB',
#        'BLK', 'BA', 'BKNG', 'BWA', 'BSX', 'BXP', 'BMY', 'BRX', 'AVGO',
#        'BR', 'BRO', 'BC', 'BG', 'BURL', 'CHRW', 'CDK', 'CF', 'CIT', 'CME',
#        'CMS', 'CSX', 'CVS', 'CPT', 'CPB', 'COF', 'CAH', 'CSL', 'CAT',
#        'CE', 'CNC', 'CNP', 'CTL', 'SCHW', 'CRL', 'CHTR', 'CVX', 'CHD',
#        'CI', 'CINF', 'CSCO', 'C', 'CFG', 'CTXS', 'KO', 'CL', 'CMCSA',
#        'CMA', 'CBSH', 'CAG', 'CXO', 'COP', 'ED', 'STZ', 'COO', 'GLW',
# ...

# %%
# finished_df.to_csv("finished_df.csv")

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                            Name  Coupon  \
# 1571           Baa1       Aa2     BK    BANK OF NEW YORK MELLON CORP   4.200
# 4948            Ba2      Baa2    SRC  SPIRIT REALTY CAPITAL REIT INC   4.600
# 1653             A2       Aa2     BK    BANK OF NEW YORK MELLON CORP   3.124
# 4107           Baa3        A3     MU           MICRON TECHNOLOGY INC   5.327
# 4157           Baa1      Baa2    MHK           MOHAWK INDUSTRIES INC   3.850
#
#       Yield  Weight (%)   Price    Shares  Market Value  Notional Value  \
# 1571   2.46        0.12   45.90  613551.0   28161990.90     28161990.90
# 4948   3.36        0.02   53.77   72542.0    3900583.34      3900583.34
# 1653   3.15        0.12   45.90  613551.0   28161990.90     28161990.90
# 4107   3.69        0.21   58.50  827592.0   48414132.00     48414132.00
# 4157   5.05        0.03  137.98   42466.0    5859458.68      5859458.68
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 3866           Baa3        B1    LHX           L3HARRIS TECHNOLOGIES INC
# 5758             A3        A1    UNH              UNITEDHEALTH GROUP INC
# 362              A3      Baa2    AMH    AMERICAN HOMES RENT REIT CLASS A
# 911            Baa1      Baa2    AFG        AMERICAN FINANCIAL GROUP INC
# 3610           Baa2        B2    IFF  INTERNATIONAL FLAVORS & FRAGRANCES
#
#       Coupon  Yield  Weight (%)   Price    Shares  Market Value  \
# 3866   4.400   2.81        0.16  228.55  165209.0  3.775852e+07
# 5758   4.450   3.41        0.90  298.78  707073.0  2.112593e+08
# 362    3.375   1.86        0.02   29.52  197652.0  5.834687e+06
# 911    4.700   3.52        0.03  112.81   53703.0  6.058235e+06
# 3610   3.650   2.39        0.05  135.87   80738.0  1.096987e+07
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 1042           Baa1      Baa2    AMH    AMERICAN HOMES RENT REIT CLASS A
# 869            Baa1        B2    AWK            AMERICAN WATER WORKS INC
# 5726             A3      Baa2    URI                  UNITED RENTALS INC
# 4253           Baa3      Baa2    NNN  NATIONAL RETAIL PROPERTIES REIT IN
# 2116            Ba1       Ba2   CHTR  CHARTER COMMUNICATIONS INC CLASS A
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 1042   3.900  2.590000        0.02   29.52  197652.0    5834687.04
# 869    6.400  1.180000        0.08  139.32  136548.0   19023867.36
# 5726   2.375  2.210000        0.04  156.86   55465.0    8700239.90
# 4253   3.750  2.498236        0.03   57.04  127707.0    7284407.28
# 2116   3.579  2.498236        0.26  534.89  114632.0   61315510.48
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                        Name  Coupon  \
# 5570             A3      Baa2    URI          UNITED RENTALS INC   4.700
# 3297           Baa3        B1     GD       GENERAL DYNAMICS CORP   4.200
# 2704           Baa2        B2   EVRG                  EVERGY INC   5.292
# 3762           Baa2        B2      K                     KELLOGG   4.300
# 4326             B2      Baa2    NOV  NATIONAL OILWELL VARCO INC   6.500
#
#          Yield  Weight (%)   Price    Shares  Market Value  Notional Value  \
# 5570  2.498236        0.04  156.86   55465.0    8700239.90      8700239.90
# 3297  2.250000        0.15  188.06  190999.0   35919271.94     35919271.94
# 2704  2.498236        0.05   72.34  168914.0   12219238.76     12219238.76
# 3762  2.760000        0.05   67.71  186578.0   12633196.38     12633196.38
# 4326  2.498236        0.03   22.89  281121.0    6434859.69      6434859.69
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                         Name  Coupon  \
# 3274           Baa3        B1     GM               GENERAL MOTORS  2.2774
# 1223           Baa3      Baa2   COLD       AMERICOLD REALTY TRUST  3.9500
# 3026           Baa1        B1     GM               GENERAL MOTORS  2.3705
# 15             Baa2        A1      T                     AT&T INC  3.6000
# 757              A2        B1    AEP  AMERICAN ELECTRIC POWER INC  2.2384
#
#       Yield  Weight (%)   Price     Shares  Market Value  Notional Value  \
# 3274   2.46        0.14   34.76   931231.0  3.236959e+07    3.236959e+07
# 1223   3.02        0.02   38.06   148280.0  5.643537e+06    5.643537e+06
# 3026   8.91        0.14   34.76   931231.0  3.236959e+07    3.236959e+07
# 15     2.55        0.89   38.25  5463772.0  2.089893e+08    2.089893e+08
# 757    2.19        0.16  103.76   369888.0  3.837958e+07    3.837958e+07
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                        Name  Coupon  \
# 5168            Aa3      Baa2    URI          UNITED RENTALS INC   2.875
# 2928             A2        A2     GE            GENERAL ELECTRIC   3.875
# 6123           Baa1       Aa2   EBAY                    EBAY INC   3.450
# 2722           Baa2        B1    EXC                 EXELON CORP   4.450
# 5812           Baa1        B3     VZ  VERIZON COMMUNICATIONS INC   3.450
#
#       Yield  Weight (%)   Price     Shares  Market Value  Notional Value  \
# 5168   2.97        0.04  156.86    55465.0  8.700240e+06    8.700240e+06
# 2928   1.97        0.36   12.83  6475032.0  8.307466e+07    8.307466e+07
# 6123   2.46        0.09   38.14   575844.0  2.196269e+07    2.196269e+07
# 2722   3.70        0.15   49.76   726319.0  3.614163e+07    3.614163e+07
# 5812   1.62        0.77   58.51  3097266.0  1.812210e+08    1.812210e+08
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                              Name  \
# 2041             A3        A3    CAT                   CATERPILLAR INC
# 1370           Baa1        B1    ADI                ANALOG DEVICES INC
# 408              A3        B1    AIG  AMERICAN INTERNATIONAL GROUP INC
# 5139           Baa1       Ba1    UNP                UNION PACIFIC CORP
# 2724            Aa3        B1    EXC                       EXELON CORP
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 2041   3.650  1.990000        0.24  137.99  401021.0   55336887.79
# 1370   2.875  2.280000        0.14  117.65  275051.0   32359750.15
# 408    3.400  2.240000        0.14   48.48  652097.0   31613662.56
# 5139   3.250  2.630000        0.41  184.00  519631.0   95612104.00
# 2724   5.950  2.498236        0.15   49.76  726319.0   36141633.44
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                              Name  \
# 248            Baa1        B1    AIG  AMERICAN INTERNATIONAL GROUP INC
# 4004           Baa1        A3    MMC              MARSH & MCLENNAN INC
# 3313           Baa3        B1     GD             GENERAL DYNAMICS CORP
# 4641             A3       Aa2    PRU          PRUDENTIAL FINANCIAL INC
# 2727           Baa2        B1    EXC                       EXELON CORP
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 248   2.9500  2.498236        0.14   48.48  652097.0   31613662.56
# 4004  4.8000  2.050000        0.19  118.78  379234.0   45045414.52
# 3313  2.8374  2.750000        0.15  188.06  190999.0   35919271.94
# 4641  5.6250  2.498236        0.12   94.48  303377.0   28663058.96
# 2727  5.7500  2.498236        0.15   49.76  726319.0   36141633.44
#
#       Notional Value  Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                             Name  Coupon  \
# 1793           Baa1        B1    BSX           BOSTON SCIENTIFIC CORP  3.8000
# 493              A3      Baa2   COLD           AMERICOLD REALTY TRUST  8.1500
# 4569             A2       Ba1     PM  PHILIP MORRIS INTERNATIONAL INC  2.6250
# 4939            Ba3       Aa2    LUV               SOUTHWEST AIRLINES  7.5000
# 3312           Baa3        A2     GE                 GENERAL ELECTRIC  2.8374
#
#       Yield  Weight (%)  Price     Shares  Market Value  Notional Value  \
# 1793   2.29        0.19  42.31  1038728.0  4.394858e+07    4.394858e+07
# 493    3.65        0.02  38.06   148280.0  5.643537e+06    5.643537e+06
# 4569   2.06        0.44  88.50  1162225.0  1.028569e+08    1.028569e+08
# 4939  11.33        0.09  57.97   353575.0  2.049674e+07    2.049674e+07
# 3312   2.75        0.36  12.83  6475032.0  8.307466e+07    8.307466e+07
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(5)
# Out:
#      Moody's Rating Predicted Ticker                     Name  Coupon  \
# 5151           Baa1       Ba1    UNP       UNION PACIFIC CORP   4.375
# 3971           Baa2       Aa2    MPC  MARATHON PETROLEUM CORP   3.625
# 4995             A1       Aa2    STT        STATE STREET CORP   4.375
# 2527           Baa2        A3      D      DOMINION ENERGY INC   7.000
# 3522             A2        B2     IP      INTERNATIONAL PAPER   1.875
#
#          Yield  Weight (%)   Price    Shares  Market Value  Notional Value  \
# 5151  3.920000        0.41  184.00  519631.0   95612104.00     95612104.00
# 3971  2.610000        0.12   58.33  481237.0   28070554.21     28070554.21
# 4995  2.498236        0.09   77.85  271294.0   21120237.90     21120237.90
# 2527  2.498236        0.23   87.46  614140.0   53712684.40     53712684.40
# 3522  2.010000        0.05   43.19  289464.0   12501950.16     12501950.16
#
#       Market Cap (intraday) 5  Trailing P/E  Forward P/E 1  \
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 5783           Baa2      Baa2    VMW                  VMWARE CLASS A INC
# 4860             A2        B1    SPG       SIMON PROPERTY GROUP REIT INC
# 763              A2      Baa2   COLD              AMERICOLD REALTY TRUST
# 3463             A1        A1   INTC              INTEL CORPORATION CORP
# 4951           Baa3      Baa2    SPR      SPIRIT AEROSYSTEMS INC CLASS A
# 4483           Baa3      Baa2     OC                       OWENS CORNING
# 145              A3       Ba2     MO                    ALTRIA GROUP INC
# 4438           Baa3      Baa2    OHI  OMEGA HEALTHCARE INVESTORS REIT IN
# 690              A2      Baa2    AAL         AMERICAN AIRLINES GROUP INC
# 1250           Baa1      Baa2    AAL         AMERICAN AIRLINES GROUP INC
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 5783  2.3000  2.080000        0.04  161.82    56058.0  9.071306e+06
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 5179            Ba3        B2    UAL        UNITED AIRLINES HOLDINGS INC
# 4335            Ba3       Aaa   NFLX                         NETFLIX INC
# 77             Baa2       Ba1   ABBV                          ABBVIE INC
# 5526             A3        A3    UPS   UNITED PARCEL SERVICE INC CLASS B
# 949            Baa1        B2    AWK            AMERICAN WATER WORKS INC
# 4209           Baa3      Baa2    MOS                              MOSAIC
# 4250           Baa3      Baa2    NNN  NATIONAL RETAIL PROPERTIES REIT IN
# 2362           Baa1        B2    GLW                         CORNING INC
# 5358           Baa1        A3    UPS   UNITED PARCEL SERVICE INC CLASS B
# 307              A3        B1    AEP         AMERICAN ELECTRIC POWER INC
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 5179  5.0000  3.430000        0.06   79.55   172236.0  1.370137e+07
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 2783           Baa2       Aa2    FDX                          FEDEX CORP
# 5937            Aa2       Aaa    WMT                         WALMART INC
# 4567             A2       Ba1     PM     PHILIP MORRIS INTERNATIONAL INC
# 4524             A1      Baa3    PEP                         PEPSICO INC
# 915            Baa1        A2    AMT            AMERICAN TOWER REIT CORP
# 506              A3       Ba2    AXP                    AMERICAN EXPRESS
# 1356           Baa1       Ba1   AMGN                           AMGEN INC
# 2890             A2        B1     GM                      GENERAL MOTORS
# 4435           Baa3      Baa2    OHI  OMEGA HEALTHCARE INVESTORS REIT IN
# 798              A2        B1    AIG    AMERICAN INTERNATIONAL GROUP INC
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 2783   2.625  2.180000        0.12  158.62   180443.0  2.862187e+07
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                               Name  \
# 2874           Baa1        B2    FTV                       FORTIVE CORP
# 4666            Aa3       Aa2    PSA                PUBLIC STORAGE REIT
# 2348           Baa3       Aa2    STZ   CONSTELLATION BRANDS INC CLASS A
# 4821            Ba3      Baa2   SERV  SERVICEMASTER GLOBAL HOLDINGS INC
# 2627           Baa2      Baa2    EMN                   EASTMAN CHEMICAL
# 455              A3        A2    AMT           AMERICAN TOWER REIT CORP
# 5276             A2      Baa2    URI                 UNITED RENTALS INC
# 1502           Baa2        B1   ADSK                       AUTODESK INC
# 2667             A2        B2    ETR                       ENTERGY CORP
# 3522             A2        B2     IP                INTERNATIONAL PAPER
#
#       Coupon     Yield  Weight (%)   Price    Shares  Market Value  \
# 2874   3.150  2.498236        0.07   77.81  220500.0   17157105.00
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                               Name  \
# 935            Baa1        A2    AMT           AMERICAN TOWER REIT CORP
# 1468            Ba2      Baa2   ARNC                        ARCONIC INC
# 1877             A3        B2   BURL              BURLINGTON STORES INC
# 3947            Ba3        B2    MGM          MGM RESORTS INTERNATIONAL
# 1330           Baa1      Baa2    AAL        AMERICAN AIRLINES GROUP INC
# 2212             A3       Aaa      C                      CITIGROUP INC
# 5334            Ba3        A3    UPS  UNITED PARCEL SERVICE INC CLASS B
# 1901            Ba2      Baa2     CF         CF INDUSTRIES HOLDINGS INC
# 1332           Baa1      Baa2    AMH   AMERICAN HOMES RENT REIT CLASS A
# 681              A2      Baa2    AFG       AMERICAN FINANCIAL GROUP INC
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 935    3.750  2.460000        0.36  256.25   328668.0  8.422118e+07
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 4976           Baa1        A2   SBUX                      STARBUCKS CORP
# 3850           Baa3        B2    KHC                         KRAFT HEINZ
# 2475           Baa3      Baa2  DISCA              DISCOVERY INC SERIES A
# 3965           Baa2       Aa2    MPC             MARATHON PETROLEUM CORP
# 1334           Baa1      Baa2    ACC  AMERICAN CAMPUS COMMUNITIES REIT I
# 3988           Baa2       Aa2    MAR  MARRIOTT INTERNATIONAL INC CLASS A
# 1844             A2       Aaa    BMY                BRISTOL MYERS SQUIBB
# 4957             B3      Baa2      S                         SPRINT CORP
# 148              A3       Ba2     MO                    ALTRIA GROUP INC
# 546              A2       Ba2    AXP                    AMERICAN EXPRESS
#
#       Coupon  Yield  Weight (%)   Price     Shares  Market Value  \
# 4976  3.5000   2.48        0.34   89.28   883518.0  7.888049e+07
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                              Name  \
# 1472           Baa3      Baa2    ARW             ARROW ELECTRONICS INC
# 2981           Baa1        B1     GD             GENERAL DYNAMICS CORP
# 5423           Baa1       Ba1    UTX          UNITED TECHNOLOGIES CORP
# 5391           Baa1      Baa2   UTHR          UNITED THERAPEUTICS CORP
# 4924             A3       Aa2    LUV                SOUTHWEST AIRLINES
# 4090             A3       Aa2    MET                       METLIFE INC
# 4347           Baa2       Aa2    NEM                           NEWMONT
# 2134            Aa2      Baa3    CVX                      CHEVRON CORP
# 952            Baa1      Baa2    AMH  AMERICAN HOMES RENT REIT CLASS A
# 3504             A2        B2     IP               INTERNATIONAL PAPER
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 1472   3.875  3.560000        0.02   79.19    60193.0  4.766684e+06
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                                Name  \
# 5286            Ba3        A3    UPS   UNITED PARCEL SERVICE INC CLASS B
# 865            Baa1        A2    AMT            AMERICAN TOWER REIT CORP
# 5094             A3        A3    TFC               TRUIST FINANCIAL CORP
# 4439           Baa3      Baa2    OHI  OMEGA HEALTHCARE INVESTORS REIT IN
# 5718             A3        A3    UPS   UNITED PARCEL SERVICE INC CLASS B
# 278            Baa1        B1    AIG    AMERICAN INTERNATIONAL GROUP INC
# 1702             A1        A1    BAC                BANK OF AMERICA CORP
# 2253             A3      Baa3  CMCSA                COMCAST CORP CLASS A
# 4514             A1      Baa3    PEP                         PEPSICO INC
# 1670             A1        A1    BAC                BANK OF AMERICA CORP
#
#       Coupon     Yield  Weight (%)   Price     Shares  Market Value  \
# 5286   4.875  4.290000        0.24  105.95   521902.0  5.529552e+07
# ...

# %%
finished_df.sample(10)
# Out:
#      Moody's Rating Predicted Ticker                      Name  Coupon  \
# 3937             A3        A2    LMT      LOCKHEED MARTIN CORP   4.700
# 4878             A3        A3     SO                  SOUTHERN   5.350
# 5896           Baa1      Baa2    WRB           WR BERKLEY CORP   8.700
# 4062             A3       Aaa    MDT             MEDTRONIC PLC   2.750
# 1640             A2        A1    BAC      BANK OF AMERICA CORP   3.974
# 3767           Baa2        B2      K                   KELLOGG   3.250
# 2251             A3      Baa3  CMCSA      COMCAST CORP CLASS A   4.150
# 5495           Baa1       Ba1    UTX  UNITED TECHNOLOGIES CORP   4.125
# 2908             A2        A2     GE          GENERAL ELECTRIC   2.875
# 1941           Baa1        B1    CSX                  CSX CORP   4.750
#
#          Yield  Weight (%)   Price     Shares  Market Value  Notional Value  \
# 3937  3.280000        0.35  437.85   185034.0  8.101714e+07    8.101714e+07
# ...

# %%
# Plot the data
plt.figure(figsize=(6, 6))
plt.scatter(p, q)
plt.xlabel('Eruption time in mins')
plt.ylabel('Waiting time to next eruption')
plt.title('Visualization of raw data');
