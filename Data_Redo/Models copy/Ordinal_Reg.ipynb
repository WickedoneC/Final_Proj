# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/Data_Redo/cleaned_df.csv')

# %%
df
# Out:
#       Unnamed: 0  Coupon     Yield Moody's Rating   Names Ticker  \
# 0              0   5.125  4.210000            Ba3   aecom    ACM
# 1              1   5.875  3.540000            Ba3   aecom    ACM
# 2              2   3.250  3.580000             A3  aflaci    AFL
# 3              3   4.000  3.440000             A3  aflaci    AFL
# 4              4   6.450  2.498236             A3  aflaci    AFL
# ...          ...     ...       ...            ...     ...    ...
# 6707        6937   4.000  4.160000           Baa1  ebayin   EBAY
# 6708        6938   2.875  2.060000           Baa1  ebayin   EBAY
# 6709        6939   2.600  2.270000           Baa1  ebayin   EBAY
# 6710        6940   3.700  2.390000             A3  salesf    CRM
# 6711        6941   3.250  1.980000             A3  salesf    CRM
#
#                     Name  Weight (%)   Price    Shares  ...  \
# 0                  AECOM        0.02   47.79  119151.0  ...
# 1                  AECOM        0.02   47.79  119151.0  ...
# ...

# %%
df = df.loc[df["Moody's Rating"] != "Caa1"]

# %%
ntr = ["Moody's Rating", "Names", "Ticker", "Name"]

# %%
ntr = df[ntr]

# %%
# ntr.to_csv('ntr.csv')

# %%
ntr
# Out:
#      Moody's Rating   Names Ticker                Name
# 0               Ba3   aecom    ACM               AECOM
# 1               Ba3   aecom    ACM               AECOM
# 2                A3  aflaci    AFL           AFLAC INC
# 3                A3  aflaci    AFL           AFLAC INC
# 4                A3  aflaci    AFL           AFLAC INC
# ...             ...     ...    ...                 ...
# 6707           Baa1  ebayin   EBAY            EBAY INC
# 6708           Baa1  ebayin   EBAY            EBAY INC
# 6709           Baa1  ebayin   EBAY            EBAY INC
# 6710             A3  salesf    CRM  SALESFORCE.COM INC
# 6711             A3  salesf    CRM  SALESFORCE.COM INC
#
# [6711 rows x 4 columns]

# %%
cols_drop = ['Unnamed: 0']
df.drop(columns=cols_drop, inplace=True)
names_drop = ["Names", "Ticker", "Name"]
df.drop(columns=names_drop, inplace=True)
sectors = names_drop = ["Sector", "Exchange"]
df.drop(columns=sectors, inplace=True)

# %%
df.head()
# Out:
#    Coupon     Yield Moody's Rating  Weight (%)  Price    Shares  Market Value  \
# 0   5.125  4.210000            Ba3        0.02  47.79  119151.0    5694226.29
# 1   5.875  3.540000            Ba3        0.02  47.79  119151.0    5694226.29
# 2   3.250  3.580000             A3        0.12  52.81  543134.0   28682906.54
# 3   4.000  3.440000             A3        0.12  52.81  543134.0   28682906.54
# 4   6.450  2.498236             A3        0.12  52.81  543134.0   28682906.54
#
#    Notional Value  Market Cap (intraday) 5  Trailing P/E  ...  \
# 0      5694226.29                     7.24          0.00  ...
# 1      5694226.29                     7.24          0.00  ...
# 2     28682906.54                    32.72         10.22  ...
# 3     28682906.54                    32.72         10.22  ...
# 4     28682906.54                    32.72         10.22  ...
#
#    Shares Outstanding 5  Profit Margin  Operating Margin (ttm)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6711 entries, 0 to 6711
# Data columns (total 30 columns):
# Coupon                            6711 non-null float64
# Yield                             6711 non-null float64
# Moody's Rating                    6711 non-null object
# Weight (%)                        6711 non-null float64
# Price                             6711 non-null float64
# Shares                            6711 non-null float64
# Market Value                      6711 non-null float64
# Notional Value                    6711 non-null float64
# Market Cap (intraday) 5           6711 non-null float64
# Trailing P/E                      6711 non-null float64
# Forward P/E 1                     6711 non-null float64
# PEG Ratio (5 yr expected) 1       6711 non-null float64
# Price/Sales (ttm)                 6711 non-null float64
# Price/Book (mrq)                  6711 non-null float64
# Beta (5Y Monthly)                 6711 non-null float64
# ...

# %%
df.head()
# Out:
#    Coupon     Yield Moody's Rating  Weight (%)  Price    Shares  Market Value  \
# 0   5.125  4.210000            Ba3        0.02  47.79  119151.0    5694226.29
# 1   5.875  3.540000            Ba3        0.02  47.79  119151.0    5694226.29
# 2   3.250  3.580000             A3        0.12  52.81  543134.0   28682906.54
# 3   4.000  3.440000             A3        0.12  52.81  543134.0   28682906.54
# 4   6.450  2.498236             A3        0.12  52.81  543134.0   28682906.54
#
#    Notional Value  Market Cap (intraday) 5  Trailing P/E  ...  \
# 0      5694226.29                     7.24          0.00  ...
# 1      5694226.29                     7.24          0.00  ...
# 2     28682906.54                    32.72         10.22  ...
# 3     28682906.54                    32.72         10.22  ...
# 4     28682906.54                    32.72         10.22  ...
#
#    Shares Outstanding 5  Profit Margin  Operating Margin (ttm)  \
# ...

# %%
y = df["Moody's Rating"]
X = df.drop("Moody's Rating", axis=1)

# %%
newy = pd.DataFrame(y)

# %%
newy
# Out:
#      Moody's Rating
# 0               Ba3
# 1               Ba3
# 2                A3
# 3                A3
# 4                A3
# ...             ...
# 6707           Baa1
# 6708           Baa1
# 6709           Baa1
# 6710             A3
# 6711             A3
#
# [6711 rows x 1 columns]

# %%
newy["Moody's Rating"].value_counts()
# Out:
# Baa1    1341
# A3      1050
# A2       976
# Baa2     865
# Baa3     839
# WR       581
# A1       293
# Ba1      170
# Ba3      109
# Aaa      104
# Aa3       95
# Aa2       94
# B2        56
# Ba2       53
# Aa1       37
# B3        30
# B1        18
# Name: Moody's Rating, dtype: int64

# %%
len(newy["Moody's Rating"].value_counts())
# Out:
# 17

# %%
data_rankings = {'Aaa':0,
'Aa1':1,
'Aa2':2,
'Aa3':3,
'A1':4,
'A2':5,
'A3':6,
'Baa1':7,
'Baa2':8,
'Baa3':9,
'Ba1':10,
'Ba2':11,
'Ba3':12,
'B1': 13,
'B2':14,
'B3':15,
'WR':16
                }

# %%
newy["Moody's Rating"] = newy["Moody's Rating"].replace(data_rankings)

# %%
newy["Moody's Rating"].value_counts()
# Out:
# 7     1341
# 6     1050
# 5      976
# 8      865
# 9      839
# 16     581
# 4      293
# 10     170
# 12     109
# 0      104
# 3       95
# 2       94
# 14      56
# 11      53
# 1       37
# 15      30
# 13      18
# Name: Moody's Rating, dtype: int64

# %%
newy["Moody's Rating"] = newy["Moody's Rating"].astype(int)

# %%
newy["Moody's Rating"].value_counts()
# Out:
# 7     1341
# 6     1050
# 5      976
# 8      865
# 9      839
# 16     581
# 4      293
# 10     170
# 12     109
# 0      104
# 3       95
# 2       94
# 14      56
# 11      53
# 1       37
# 15      30
# 13      18
# Name: Moody's Rating, dtype: int64

# %%
newy = newy["Moody's Rating"]

# %%
len(newy.unique())
# Out:
# 17

# %%
y
# Out:
# 0        Ba3
# 1        Ba3
# 2         A3
# 3         A3
# 4         A3
#         ...
# 6707    Baa1
# 6708    Baa1
# 6709    Baa1
# 6710      A3
# 6711      A3
# Name: Moody's Rating, Length: 6711, dtype: object

# %%
clf2 = mord.LogisticAT(alpha=1)
clf2.fit(X, newy)
print('Mean Absolute Error of LogisticAT %s' %
      metrics.mean_absolute_error(clf2.predict(X), newy))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-49507f2e54ed> in <module>
# ----> 1 clf2 = mord.LogisticAT(alpha=1)
#       2 clf2.fit(X, newy)
#       3 print('Mean Absolute Error of LogisticAT %s' %
#       4       metrics.mean_absolute_error(clf2.predict(X), newy))
#
# NameError: name 'mord' is not defined

# %%
clf3 = mord.LogisticIT(alpha=6, verbose=100, max_iter=1000000)
clf3.fit(X, newy)
print('Mean Absolute Error of LogisticIT %s' %
      metrics.mean_absolute_error(clf3.predict(X), newy))
# Out:
# Mean Absolute Error of LogisticIT 2.431447225244831

# %%
# Actual class predictions
rf_predictions = clf3.predict(X)
# Probabilities for each class
rf_probs = clf3.predict_proba(X)[:, 1]

# %%
rf_predictions
# Out:
# array([7, 8, 8, ..., 8, 8, 8])

# %%
rf_probs
# Out:
# array([2.25706036e-12, 5.60207591e-15, 3.10752302e-14, ...,
#        1.30596095e-15, 4.42286458e-13, 3.39394023e-13])

# %%
# from sklearn.metrics import roc_auc_score

# # Calculate roc auc
# roc_value = roc_auc_score(y, rf_probs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-325-6398ac24249b> in <module>
#       2
#       3 # Calculate roc auc
# ----> 4 roc_value = roc_auc_score(y, rf_probs)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      71     y_type = type_of_target(y_true)
#      72     if y_type not in ("binary", "multilabel-indicator"):
# ---> 73         raise ValueError("{0} format is not supported".format(y_type))
#      74
# ...

# %%
clf4 = mord.LogisticSE(alpha=10.)
clf4.fit(X, newy)
print('Mean Absolute Error of LogisticSE %s' %
      metrics.mean_absolute_error(clf4.predict(X), newy))
# Out:
# Mean Absolute Error of LogisticSE 2.488030467899891

# %%
clf1 = linear_model.LogisticRegression(
    solver='lbfgs',
    multi_class='multinomial')
clf1.fit(X, newy)

print('Mean Absolute Error of LogisticRegression: %s' %
      metrics.mean_absolute_error(clf1.predict(X), newy))
# Out:
# Mean Absolute Error of LogisticRegression: 4.237758433079434
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
import numpy as np


MAE = make_scorer(mean_absolute_error)
folds = 5

MAE_ordinal = cross_val_score(model_ordinal,
    X,
    newy,
    cv=folds,
    scoring=MAE,
                             )
print('Ordered logistic regression: ', np.mean(MAE_ordinal))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-282-70355739f175> in <module>
#      12     newy,
#      13     cv=folds,
# ---> 14     scoring=MAE,
#      15                              )
#      16 print('Ordered logistic regression: ', np.mean(MAE_ordinal))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
# ...

# %%
def acc_fun(target_true, target_fit):
    target_fit = np.round(target_fit)
    target_fit.astype('int')
    return accuracy_score(target_true, target_fit)

acc = make_scorer(acc_fun)
folds = 5

# %%
acc_ordinal = cross_val_score(model_ordinal,
    X,
    newy,
    cv=folds,
    scoring=acc)
print('Ordered logistic regression: ', np.mean(acc_ordinal))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-285-4c3221b40894> in <module>
#       3     newy,
#       4     cv=folds,
# ----> 5     scoring=acc)
#       6 print('Ordered logistic regression: ', np.mean(acc_ordinal))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     389                                 fit_params=fit_params,
# ...
