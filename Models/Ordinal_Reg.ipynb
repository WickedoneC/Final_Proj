# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/CSV_Files/cleaned_df2.csv')

# %%
df
# Out:
#       Unnamed: 0  Coupon     Yield Moody's Rating      Names Ticker  \
# 0              0   3.250  3.580000             A3  aflac inc    AFL
# 1              1   4.000  3.440000             A3  aflac inc    AFL
# 2              2   6.450  2.411028             A3  aflac inc    AFL
# 3              3   3.625  2.130000             A3  aflac inc    AFL
# 4              4   2.875  2.480000             A3  aflac inc    AFL
# ...          ...     ...       ...            ...        ...    ...
# 1833        1833   3.450  2.460000           Baa1   ebay inc   EBAY
# 1834        1834   2.600  2.270000           Baa1   ebay inc   EBAY
# 1835        1835   4.000  4.160000           Baa1   ebay inc   EBAY
# 1836        1836   2.875  2.060000           Baa1   ebay inc   EBAY
# 1837        1837   2.600  2.270000           Baa1   ebay inc   EBAY
#
#       Weight (%)  Price    Shares  Market Value  ...  Shares Outstanding 5  \
# 0           0.12  52.81  543134.0   28682906.54  ...                726.79
# 1           0.12  52.81  543134.0   28682906.54  ...                726.79
# 2           0.12  52.81  543134.0   28682906.54  ...                726.79
# 3           0.12  52.81  543134.0   28682906.54  ...                726.79
# 4           0.12  52.81  543134.0   28682906.54  ...                726.79
# ...          ...    ...       ...           ...  ...                   ...
# 1833        0.09  38.14  575844.0   21962690.16  ...                813.52
# 1834        0.09  38.14  575844.0   21962690.16  ...                813.52
# 1835        0.09  38.14  575844.0   21962690.16  ...                813.52
# 1836        0.09  38.14  575844.0   21962690.16  ...                813.52
# 1837        0.09  38.14  575844.0   21962690.16  ...                813.52
#
#      Profit Margin Operating Margin (ttm)  Return on Assets (ttm)  \
# 0            14.81                  19.93                    1.90
# 1            14.81                  19.93                    1.90
# 2            14.81                  19.93                    1.90
# 3            14.81                  19.93                    1.90
# 4            14.81                  19.93                    1.90
# ...            ...                    ...                     ...
# 1833         16.54                  22.20                    7.31
# 1834         16.54                  22.20                    7.31
# 1835         16.54                  22.20                    7.31
# 1836         16.54                  22.20                    7.31
# 1837         16.54                  22.20                    7.31
#
#       Revenue Per Share (ttm)  Quarterly Revenue Growth (yoy)  \
# 0                       30.05                             9.3
# 1                       30.05                             9.3
# 2                       30.05                             9.3
# 3                       30.05                             9.3
# 4                       30.05                             9.3
# ...                       ...                             ...
# 1833                    12.72                            -1.9
# 1834                    12.72                            -1.9
# 1835                    12.72                            -1.9
# 1836                    12.72                            -1.9
# 1837                    12.72                            -1.9
#
#       Total Cash Per Share (mrq)  Total Debt (mrq)  \
# 0                      45.032679              6.57
# 1                      45.032679              6.57
# 2                      45.032679              6.57
# 3                      45.032679              6.57
# 4                      45.032679              6.57
# ...                          ...               ...
# 1833                    3.550000              8.42
# 1834                    3.550000              8.42
# 1835                    3.550000              8.42
# 1836                    3.550000              8.42
# 1837                    3.550000              8.42
#
#       Book Value Per Share (mrq)  Days_to_Maturity
# 0                          39.85            1858.0
# 1                          39.85            9740.0
# 2                          39.85            7488.0
# 3                          39.85            1736.0
# 4                          39.85            2435.0
# ...                          ...               ...
# 1833                        3.61            1630.0
# 1834                        3.61             882.0
# 1835                        3.61            8187.0
# 1836                        3.61             534.0
# 1837                        3.61             882.0
#
# [1838 rows x 34 columns]

# %%
cols_drop = ['Unnamed: 0']
df.drop(columns=cols_drop, inplace=True)
names_drop = ["Names", "Ticker"]
df.drop(columns=names_drop, inplace=True)
sectors = names_drop = ["Sector", "Exchange"]
df.drop(columns=sectors, inplace=True)

# %%
mdf = df[["Moody's Rating"]]

# %%
ndf = pd.read_csv('/Users/wickedbear/Coding/Projects/Final_Proj/Models/names_df.csv')
ndf.drop(columns=cols_drop, inplace=True)

# %%
nmdf = pd.concat([mdf, ndf], axis=1)

# %%
nmdf.head()
# Out:
#   Moody's Rating      Names Ticker
# 0             A3  aflac inc    AFL
# 1             A3  aflac inc    AFL
# 2             A3  aflac inc    AFL
# 3             A3  aflac inc    AFL
# 4             A3  aflac inc    AFL

# %%
df.head()
# Out:
#    Coupon     Yield Moody's Rating  Weight (%)  Price    Shares  Market Value  \
# 0   3.250  3.580000             A3        0.12  52.81  543134.0   28682906.54
# 1   4.000  3.440000             A3        0.12  52.81  543134.0   28682906.54
# 2   6.450  2.411028             A3        0.12  52.81  543134.0   28682906.54
# 3   3.625  2.130000             A3        0.12  52.81  543134.0   28682906.54
# 4   2.875  2.480000             A3        0.12  52.81  543134.0   28682906.54
#
#    Notional Value  Market Cap (intraday) 5  Trailing P/E  ...  \
# 0     28682906.54                    37.47         11.64  ...
# 1     28682906.54                    37.47         11.64  ...
# 2     28682906.54                    37.47         11.64  ...
# 3     28682906.54                    37.47         11.64  ...
# 4     28682906.54                    37.47         11.64  ...
#
#    Shares Outstanding 5  Profit Margin  Operating Margin (ttm)  \
# 0                726.79          14.81                   19.93
# 1                726.79          14.81                   19.93
# 2                726.79          14.81                   19.93
# 3                726.79          14.81                   19.93
# 4                726.79          14.81                   19.93
#
#    Return on Assets (ttm)  Revenue Per Share (ttm)  \
# 0                     1.9                    30.05
# 1                     1.9                    30.05
# 2                     1.9                    30.05
# 3                     1.9                    30.05
# 4                     1.9                    30.05
#
#    Quarterly Revenue Growth (yoy)  Total Cash Per Share (mrq)  \
# 0                             9.3                   45.032679
# 1                             9.3                   45.032679
# 2                             9.3                   45.032679
# 3                             9.3                   45.032679
# 4                             9.3                   45.032679
#
#    Total Debt (mrq)  Book Value Per Share (mrq)  Days_to_Maturity
# 0              6.57                       39.85            1858.0
# 1              6.57                       39.85            9740.0
# 2              6.57                       39.85            7488.0
# 3              6.57                       39.85            1736.0
# 4              6.57                       39.85            2435.0
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1838 entries, 0 to 1837
# Data columns (total 29 columns):
# Coupon                            1838 non-null float64
# Yield                             1838 non-null float64
# Moody's Rating                    1838 non-null object
# Weight (%)                        1838 non-null float64
# Price                             1838 non-null float64
# Shares                            1838 non-null float64
# Market Value                      1838 non-null float64
# Notional Value                    1838 non-null float64
# Market Cap (intraday) 5           1838 non-null float64
# Trailing P/E                      1838 non-null float64
# Forward P/E 1                     1838 non-null float64
# PEG Ratio (5 yr expected) 1       1838 non-null float64
# Price/Sales (ttm)                 1838 non-null float64
# Price/Book (mrq)                  1838 non-null float64
# Beta (5Y Monthly)                 1838 non-null float64
# % Held by Insiders 1              1838 non-null float64
# % Held by Institutions 1          1838 non-null float64
# Avg Vol (10 day) 3                1838 non-null float64
# Avg Vol (3 month) 3               1838 non-null float64
# Shares Outstanding 5              1838 non-null float64
# Profit Margin                     1838 non-null float64
# Operating Margin (ttm)            1838 non-null float64
# Return on Assets (ttm)            1838 non-null float64
# Revenue Per Share (ttm)           1838 non-null float64
# Quarterly Revenue Growth (yoy)    1838 non-null float64
# Total Cash Per Share (mrq)        1838 non-null float64
# Total Debt (mrq)                  1838 non-null float64
# Book Value Per Share (mrq)        1838 non-null float64
# Days_to_Maturity                  1838 non-null float64
# dtypes: float64(28), object(1)
# memory usage: 416.5+ KB

# %%
# choose models
from sklearn.linear_model import LinearRegression, LogisticRegression
from mord import LogisticAT

# instantiate models
model_linear = LinearRegression()
model_1vR = LogisticRegression(multi_class='ovr',
    class_weight='balanced')
model_multi = LogisticRegression(multi_class='multinomial',
    solver='lbfgs',
    class_weight='balanced')
model_ordinal = LogisticAT(alpha=0)  # alpha parameter set to zero to perform no regularisation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-d14e2f9c3da6> in <module>
#       1 # choose models
#       2 from sklearn.linear_model import LinearRegression, LogisticRegression
# ----> 3 from mord import LogisticAT
#       4
#       5 # instantiate models
#
# ModuleNotFoundError: No module named 'mord'

# %%
y = df["Moody's Rating"]
X = df.drop("Moody's Rating", axis=1)
