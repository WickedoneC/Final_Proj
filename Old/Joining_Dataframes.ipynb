# %%
import pandas as pd

# %%
russ = pd.read_csv('Russ_1000.csv')
fins = pd.read_csv('financials_df.csv')
bonds = pd.read_csv('bond_df.csv')

# %%
russ.head()
# Out:
#   Ticker                  Name Asset Class  Weight (%)     Price  \
# 0   AAPL             APPLE INC      Equity        4.62    324.95
# 1   MSFT        MICROSOFT CORP      Equity        4.49    185.35
# 2   AMZN        AMAZON COM INC      Equity        2.83  2,134.87
# 3     FB  FACEBOOK CLASS A INC      Equity        1.64    214.18
# 4   GOOG  ALPHABET INC CLASS C      Equity        1.46  1,520.74
#
#          Shares      Market Value    Notional Value                  Sector  \
# 0  3,327,521.00  1,081,277,948.95  1,081,277,948.95  Information Technology
# 1  5,661,995.00  1,049,450,773.25  1,049,450,773.25  Information Technology
# 2    309,633.00    661,026,202.71    661,026,202.71  Consumer Discretionary
# 3  1,788,162.00    382,988,537.16    382,988,537.16           Communication
# 4    224,375.00    341,216,037.50    341,216,037.50           Communication
#
#      SEDOL          ISIN Exchange
# 0  2046251  US0378331005   NASDAQ
# 1  2588173  US5949181045   NASDAQ
# ...

# %%
fins.head()
# Out:
#    Unnamed: 0 Market Cap (intraday) 5 Enterprise Value 3  Trailing P/E  \
# 0           1                    1.4T              1.43T         25.44
# 1           1                   1.41T              1.38T         32.06
# 2           1                   1.07T              1.09T         93.40
# 3           1                  613.9B            576.16B         33.49
# 4           1                   1.04T            945.56B         30.84
#
#    Forward P/E 1  PEG Ratio (5 yr expected) 1  Price/Sales (ttm)  \
# 0          20.45                         1.91               5.24
# 1          29.21                         2.20              10.53
# 2          53.46                         2.49               3.81
# 3          19.74                         1.81               8.68
# 4          24.19                         1.78               6.43
#
#    Price/Book (mrq)  Enterprise Value/Revenue 3  Enterprise Value/EBITDA 6  \
# ...

# %%
fins.shape
# Out:
# (403, 76)

# %%
russ.shape
# Out:
# (1001, 12)

# %%
fins['Ticker'] = fins['Tickers']

# %%
fins = fins.drop(columns='Tickers')

# %%
fins
# Out:
#      Unnamed: 0 Market Cap (intraday) 5 Enterprise Value 3  Trailing P/E  \
# 0             1                    1.4T              1.43T         25.44
# 1             1                   1.41T              1.38T         32.06
# 2             1                   1.07T              1.09T         93.40
# 3             1                  613.9B            576.16B         33.49
# 4             1                   1.04T            945.56B         30.84
# ..          ...                     ...                ...           ...
# 398           1                  13.54B             14.98B           NaN
# 399           1                  17.46B             14.58B         21.49
# 400           1                  14.07B             16.73B         29.98
# 401           1                  12.98B             28.91B         20.50
# 402           1                  14.47B             18.53B         18.28
#
#      Forward P/E 1  PEG Ratio (5 yr expected) 1  Price/Sales (ttm)  \
# ...

# %%
df = pd.merge(russ, fins, on='Ticker')

# %%
df
# Out:
#     Ticker                          Name Asset Class  Weight (%)     Price  \
# 0     AAPL                     APPLE INC      Equity        4.62    324.95
# 1     MSFT                MICROSOFT CORP      Equity        4.49    185.35
# 2     AMZN                AMAZON COM INC      Equity        2.83  2,134.87
# 3       FB          FACEBOOK CLASS A INC      Equity        1.64    214.18
# 4     GOOG          ALPHABET INC CLASS C      Equity        1.46  1,520.74
# ..     ...                           ...         ...         ...       ...
# 398      J  JACOBS ENGINEERING GROUP INC      Equity        0.04    100.66
# 399   ANET           ARISTA NETWORKS INC      Equity        0.04    223.47
# 400    FMC                      FMC CORP      Equity        0.04    105.47
# 401    CNP        CENTERPOINT ENERGY INC      Equity        0.04     27.18
# 402    GPC                 GENUINE PARTS      Equity        0.04     96.47
#
# ...

# %%
df1 = df.Name.str.title()

# %%
df['Names'] = df1

# %%
df
# Out:
#     Ticker                          Name Asset Class  Weight (%)     Price  \
# 0     AAPL                     APPLE INC      Equity        4.62    324.95
# 1     MSFT                MICROSOFT CORP      Equity        4.49    185.35
# 2     AMZN                AMAZON COM INC      Equity        2.83  2,134.87
# 3       FB          FACEBOOK CLASS A INC      Equity        1.64    214.18
# 4     GOOG          ALPHABET INC CLASS C      Equity        1.46  1,520.74
# ..     ...                           ...         ...         ...       ...
# 398      J  JACOBS ENGINEERING GROUP INC      Equity        0.04    100.66
# 399   ANET           ARISTA NETWORKS INC      Equity        0.04    223.47
# 400    FMC                      FMC CORP      Equity        0.04    105.47
# 401    CNP        CENTERPOINT ENERGY INC      Equity        0.04     27.18
# 402    GPC                 GENUINE PARTS      Equity        0.04     96.47
#
# ...

# %%
df['Names'] = df['Names'].str.replace('.', '')

# %%
df['Names'] = df['Names'].str.replace('-', '')

# %%
lowercasing = df['Name'].str.lower()

# %%
df['Names'] = lowercasing

# %%
df
# Out:
#     Ticker                          Name Asset Class  Weight (%)     Price  \
# 0     AAPL                     APPLE INC      Equity        4.62    324.95
# 1     MSFT                MICROSOFT CORP      Equity        4.49    185.35
# 2     AMZN                AMAZON COM INC      Equity        2.83  2,134.87
# 3       FB          FACEBOOK CLASS A INC      Equity        1.64    214.18
# 4     GOOG          ALPHABET INC CLASS C      Equity        1.46  1,520.74
# ..     ...                           ...         ...         ...       ...
# 398      J  JACOBS ENGINEERING GROUP INC      Equity        0.04    100.66
# 399   ANET           ARISTA NETWORKS INC      Equity        0.04    223.47
# 400    FMC                      FMC CORP      Equity        0.04    105.47
# 401    CNP        CENTERPOINT ENERGY INC      Equity        0.04     27.18
# 402    GPC                 GENUINE PARTS      Equity        0.04     96.47
#
# ...

# %%
df
# Out:
#     Ticker                          Name Asset Class  Weight (%)     Price  \
# 0     AAPL                     APPLE INC      Equity        4.62    324.95
# 1     MSFT                MICROSOFT CORP      Equity        4.49    185.35
# 2     AMZN                AMAZON COM INC      Equity        2.83  2,134.87
# 3       FB          FACEBOOK CLASS A INC      Equity        1.64    214.18
# 4     GOOG          ALPHABET INC CLASS C      Equity        1.46  1,520.74
# ..     ...                           ...         ...         ...       ...
# 398      J  JACOBS ENGINEERING GROUP INC      Equity        0.04    100.66
# 399   ANET           ARISTA NETWORKS INC      Equity        0.04    223.47
# 400    FMC                      FMC CORP      Equity        0.04    105.47
# 401    CNP        CENTERPOINT ENERGY INC      Equity        0.04     27.18
# 402    GPC                 GENUINE PARTS      Equity        0.04     96.47
#
# ...

# %%
df[['Market Cap (intraday) 5']]
# Out:
#     Market Cap (intraday) 5
# 0                      1.4T
# 1                     1.41T
# 2                     1.07T
# 3                    613.9B
# 4                     1.04T
# ..                      ...
# 398                  13.54B
# 399                  17.46B
# 400                  14.07B
# 401                  12.98B
# 402                  14.47B
#
# [403 rows x 1 columns]

# %%
bonds.head()
# Out:
#    Unnamed: 0                         Issuer Currency   Coupon    Yield  \
# 0           0                         000000      USD  6.5000%        -
# 1           1                         000000      USD  7.7500%  407.08%
# 2           2  21st Century Fox America Inc.      USD  6.5500%    3.26%
# 3           3  21st Century Fox America Inc.      USD  6.1500%    4.24%
# 4           4  21st Century Fox America Inc.      USD  4.7500%    4.16%
#
#   Moody's Rating Maturity Date     Bid     Ask
# 0            Aa2     10/1/2034  130.00       -
# 1            NaN     10/1/2022    3.30   11.75
# 2             WR     3/15/2033  134.49  140.08
# 3             WR      3/1/2037  122.80  133.50
# 4             WR    11/15/2046       -       -

# %%
bonds['Name'] = bonds['Issuer']

# %%
df2 = bonds.Issuer.str.title()

# %%
bonds['Names'] = df2

# %%
bonds
# Out:
#       Unnamed: 0                         Issuer Currency   Coupon    Yield  \
# 0              0                         000000      USD  6.5000%        -
# 1              1                         000000      USD  7.7500%  407.08%
# 2              2  21st Century Fox America Inc.      USD  6.5500%    3.26%
# 3              3  21st Century Fox America Inc.      USD  6.1500%    4.24%
# 4              4  21st Century Fox America Inc.      USD  4.7500%    4.16%
# ...          ...                            ...      ...      ...      ...
# 7000        7000                      eBay Inc.      USD  2.8750%    2.06%
# 7001        7001                      eBay Inc.      USD  2.6000%    2.27%
# 7002        7002                     iStar Inc.      USD  4.7500%    4.08%
# 7003        7003            salesforce.com Inc.      USD  3.7000%    2.39%
# 7004        7004            salesforce.com Inc.      USD  3.2500%    1.98%
#
#      Moody's Rating Maturity Date     Bid     Ask  \
# ...

# %%
bonds['Names'] = bonds['Names'].str.replace('.', '')

# %%
bonds['Names'] = bonds['Names'].str.replace('-', '')

# %%
lowering = bonds['Name'].str.lower()

# %%
bonds['Names'] = lowering

# %%
bonds['Names'] = bonds['Names'].str.replace('.', '')

# %%
bonds
# Out:
#       Unnamed: 0                         Issuer Currency   Coupon    Yield  \
# 0              0                         000000      USD  6.5000%        -
# 1              1                         000000      USD  7.7500%  407.08%
# 2              2  21st Century Fox America Inc.      USD  6.5500%    3.26%
# 3              3  21st Century Fox America Inc.      USD  6.1500%    4.24%
# 4              4  21st Century Fox America Inc.      USD  4.7500%    4.16%
# ...          ...                            ...      ...      ...      ...
# 7000        7000                      eBay Inc.      USD  2.8750%    2.06%
# 7001        7001                      eBay Inc.      USD  2.6000%    2.27%
# 7002        7002                     iStar Inc.      USD  4.7500%    4.08%
# 7003        7003            salesforce.com Inc.      USD  3.7000%    2.39%
# 7004        7004            salesforce.com Inc.      USD  3.2500%    1.98%
#
#      Moody's Rating Maturity Date     Bid     Ask  \
# ...

# %%
df_end = pd.merge(bonds, df, on='Names')

# %%
df_end
# Out:
#       Unnamed: 0_x      Issuer Currency   Coupon  Yield Moody's Rating  \
# 0               49  AFLAC Inc.      USD  3.2500%  3.58%             A3
# 1               50  AFLAC Inc.      USD  4.0000%  3.44%             A3
# 2               51  AFLAC Inc.      USD  6.4500%      -             A3
# 3               52  AFLAC Inc.      USD  3.6250%  2.13%             A3
# 4               53  AFLAC Inc.      USD  2.8750%  2.48%             A3
# ...            ...         ...      ...      ...    ...            ...
# 1835          6997   eBay Inc.      USD  3.4500%  2.46%           Baa1
# 1836          6998   eBay Inc.      USD  2.6000%  2.27%           Baa1
# 1837          6999   eBay Inc.      USD  4.0000%  4.16%           Baa1
# 1838          7000   eBay Inc.      USD  2.8750%  2.06%           Baa1
# 1839          7001   eBay Inc.      USD  2.6000%  2.27%           Baa1
#
#      Maturity Date     Bid     Ask      Name_x  ... Diluted EPS (ttm)  \
# ...

# %%
df_end.Names.unique()
# Out:
# array(['aflac inc', 'abbvie inc', 'abbott laboratories',
#        'activision blizzard inc', 'adobe inc',
#        'advanced micro devices inc', 'agilent technologies inc',
#        'altria group inc', 'ameren corp',
#        'american international group inc', 'amerisourcebergen corp',
#        'amgen inc', 'analog devices inc', 'anthem inc', 'apple inc',
#        'atmos energy corp', 'autozone inc', 'autodesk inc',
#        'automatic data processing inc', 'ball corp',
#        'bank of america corp', 'bank of new york mellon corp',
#        'baxter international inc', 'biogen inc', 'blackrock inc',
#        'booking holdings inc', 'boston scientific corp', 'broadcom inc',
#        'broadridge financial solutions inc', 'cms energy corp',
#        'csx corp', 'cvs health corp', 'capital one financial corp',
#        'cardinal health inc', 'caterpillar inc', 'centene corp',
#        'centerpoint energy inc', 'centurylink inc', 'charles schwab corp',
# ...

# %%
len(df_end.Names.unique())
# Out:
# 171

# %%
# df_end.to_csv('merged_df_messy.csv')
