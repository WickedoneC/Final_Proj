# %%
# %run NYSE_Scrape.ipynb
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
list_of_pages = []
for thing in url_list:
    a = requests.get(thing)
    list_of_pages.append(a)

# %%
len(list_of_pages)
# Out:
# 992

# %%
new_list_of_pages = list_of_pages[:403]

# %%
len(new_list_of_pages)
# Out:
# 403

# %%
len(new_list_of_pages)
# Out:
# 403

# %%
new_ticker_list = ticker_list[:403]

# %%
len(new_ticker_list)
# Out:
# 403

# %%
freq = list(range(0,403))
#             len(new_list_of_datas)

# %%
len(freq)
# Out:
# 403

# %%
new_list_of_datas = []
empty_df = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[0].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df.append(adf)
    new_list_of_datas.append(adf)

# %%
new_list_of_datas[5]
# Out:
# 0 Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                   1.04T            944.31B        30.81         24.22
#
# 0 PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# 1                        5.87              6.44             5.18
#
# 0 Enterprise Value/Revenue 3 Enterprise Value/EBITDA 6
# 1                       5.83                     19.62

# %%
new_list_of_datas_1 = []
empty_df_1 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[1].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_1.append(adf)
    new_list_of_datas_1.append(adf)

# %%
new_list_of_datas_1[5]
# Out:
# 0 Beta (5Y Monthly) 52-Week Change 3 S&P500 52-Week Change 3 52 Week High 3  \
# 1              1.04           36.08%                  21.60%        1530.74
#
# 0 52 Week Low 3 50-Day Moving Average 3 200-Day Moving Average 3
# 1       1027.03                 1457.64                  1304.35

# %%
new_list_of_datas_2 = []
empty_df_2 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[2].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_2.append(adf)
    new_list_of_datas_2.append(adf)
# Out:
# [0 Avg Vol (3 month) 3 Avg Vol (10 day) 3 Shares Outstanding 5  Float  \
#  1              29.95M             26.38M                4.38B  4.37B
#
#  0 % Held by Insiders 1 % Held by Institutions 1 Shares Short (Jan 30, 2020) 4  \
#  1                0.07%                   62.69%                        41.54M
#
#  0 Short Ratio (Jan 30, 2020) 4 Short % of Float (Jan 30, 2020) 4  \
#  1                          1.2                             0.95%
#
#  0 Short % of Shares Outstanding (Jan 30, 2020) 4  \
#  1                                          0.95%
#
#  0 Shares Short (prior month Dec 30, 2019) 4
#  1                                    45.51M  ,
#  0 Avg Vol (3 month) 3 Avg Vol (10 day) 3 Shares Outstanding 5  Float  \
#  1              25.61M             36.03M                7.61B  7.49B
#
#  0 % Held by Insiders 1 % Held by Institutions 1 Shares Short (Jan 30, 2020) 4  \
#  1                1.42%                   75.18%                        56.67M
#
# ...

# %%
new_list_of_datas_2[5]
# Out:
# 0 Avg Vol (3 month) 3 Avg Vol (10 day) 3 Shares Outstanding 5    Float  \
# 1               1.53M              1.41M              299.83M  617.94M
#
# 0 % Held by Insiders 1 % Held by Institutions 1 Shares Short (Jan 30, 2020) 4  \
# 1                0.14%                   82.49%                         2.98M
#
# 0 Short Ratio (Jan 30, 2020) 4 Short % of Float (Jan 30, 2020) 4  \
# 1                          1.9                             1.00%
#
# 0 Short % of Shares Outstanding (Jan 30, 2020) 4  \
# 1                                          0.43%
#
# 0 Shares Short (prior month Dec 30, 2019) 4
# 1                                     3.55M

# %%
new_list_of_datas_3 = []
empty_df_3 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[3].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_3.append(adf)
    new_list_of_datas_3.append(adf)

# %%
new_list_of_datas_3[5]
# Out:
# 0 Forward Annual Dividend Rate 4 Forward Annual Dividend Yield 4  \
# 1                            NaN                             NaN
#
# 0 Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3  \
# 1                             NaN                              NaN
#
# 0 5 Year Average Dividend Yield 4 Payout Ratio 4 Dividend Date 3  \
# 1                             NaN          0.00%             NaN
#
# 0 Ex-Dividend Date 4 Last Split Factor 2 Last Split Date 3
# 1                NaN           1998:1000      Apr 02, 2014

# %%
new_list_of_datas_4 = []
empty_df_4 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[4].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_4.append(adf)
    new_list_of_datas_4.append(adf)

# %%
new_list_of_datas_4[5]
# Out:
# 0 Fiscal Year Ends Most Recent Quarter (mrq)
# 1     Dec 30, 2019              Dec 30, 2019

# %%
new_list_of_datas_5 = []
empty_df_5 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[5].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_5.append(adf)
    new_list_of_datas_5.append(adf)

# %%
new_list_of_datas_5[5]
# Out:
# 0 Profit Margin Operating Margin (ttm)
# 1        21.22%                 22.54%

# %%
new_list_of_datas_6 = []
empty_df_6 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[6].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_6.append(adf)
    new_list_of_datas_6.append(adf)

# %%
new_list_of_datas_6[5]
# Out:
# 0 Return on Assets (ttm) Return on Equity (ttm)
# 1                  8.96%                 18.12%

# %%
new_list_of_datas_7 = []
empty_df_7 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[7].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_7.append(adf)
    new_list_of_datas_7.append(adf)

# %%
new_list_of_datas_7[5]
# Out:
# 0 Revenue (ttm) Revenue Per Share (ttm) Quarterly Revenue Growth (yoy)  \
# 1       161.86B                  233.70                         17.30%
#
# 0 Gross Profit (ttm)  EBITDA Net Income Avi to Common (ttm) Diluted EPS (ttm)  \
# 1             89.96B  48.13B                         34.34B             49.16
#
# 0 Quarterly Earnings Growth (yoy)
# 1                          19.30%

# %%
new_list_of_datas_8 = []
empty_df_8 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[8].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_8.append(adf)
    new_list_of_datas_8.append(adf)

# %%
new_list_of_datas_8[5]
# Out:
# 0 Total Cash (mrq) Total Cash Per Share (mrq) Total Debt (mrq)  \
# 1          119.68B                     174.13           15.97B
#
# 0 Total Debt/Equity (mrq) Current Ratio (mrq) Book Value Per Share (mrq)
# 1                    7.93                3.37                     292.65

# %%
new_list_of_datas_9 = []
empty_df_9 = pd.DataFrame()
for thing in freq:
    adf = pd.read_html(new_list_of_pages[thing].content)[9].T
    adf.columns = adf.iloc[0]
    adf = adf.drop(0)
    empty_df_9.append(adf)
    new_list_of_datas_9.append(adf)

# %%
new_list_of_datas_9[5]
# Out:
# 0 Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                    54.52B                       25.58B

# %%
empty_df_9
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
nine lists of 403 dataframes
need to do .apply to append each row in tables 1-10 to a dataframe
then need to concat the 10 tables

# %%
testing_df = new_list_of_datas_9[0]

# %%
testing_df_2 = new_list_of_datas_9[1]

# %%
testing_df_2
# Out:
# 0 Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                    54.13B                       35.08B

# %%
testing_df.append(testing_df_2)
# Out:
# 0 Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                    73.22B                       45.59B
# 1                    54.13B                       35.08B

# %%
testing_df
# Out:
# 0 Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                    73.22B                       45.59B

# %%
empty_df = pd.DataFrame()
for thing in new_list_of_datas:
    a = thing
    empty_df = empty_df.append(a)

# %%
empty_df
# Out:
# 0  Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                     1.4T              1.43T        25.44         20.45
# 1                    1.41T              1.38T        32.06         29.21
# 1                    1.07T              1.09T        93.40         53.46
# 1                   613.9B            576.16B        33.49         19.74
# 1                    1.04T            945.56B        30.84         24.19
# ..                     ...                ...          ...           ...
# 1                   13.54B             14.98B          NaN         15.83
# 1                   17.46B             14.58B        21.49         22.63
# 1                   14.07B             16.73B        29.98         14.38
# 1                   12.98B             28.91B        20.50         16.36
# 1                   14.47B             18.53B        18.28         16.88
#
# 0  PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
empty_df_1 = pd.DataFrame()
for thing in new_list_of_datas_1:
    a = thing
    empty_df_1 = empty_df_1.append(a)

# %%
empty_df_1
# Out:
# 0  Beta (5Y Monthly) 52-Week Change 3 S&P500 52-Week Change 3 52 Week High 3  \
# 1               1.28           88.12%                  21.60%         327.85
# 1               1.15           74.78%                  21.60%         190.70
# 1               1.62           33.79%                  21.60%        2185.95
# 1               1.08           33.79%                  21.60%         224.20
# 1               1.04           37.07%                  21.60%        1532.11
# ..               ...              ...                     ...            ...
# 1               1.18           37.48%                  21.60%         102.55
# 1               1.50          -16.88%                  21.60%         331.27
# 1               1.51           40.35%                  21.60%         108.77
# 1               0.54          -14.69%                  21.60%          31.42
# 1               0.90           -8.95%                  21.60%         115.20
#
# ...

# %%
empty_df_2 = pd.DataFrame()
for thing in new_list_of_datas_2:
    a = thing
    empty_df_2 = empty_df_2.append(a)
    
empty_df_2
# Out:
#    % Held by Insiders 1 % Held by Institutions 1 Avg Vol (10 day) 3  \
# 1                 0.07%                   62.69%             26.38M
# 1                 1.42%                   75.18%             36.03M
# 1                15.16%                   58.35%              3.61M
# 1                 0.99%                   79.75%             14.94M
# 1                 5.66%                   70.71%              1.16M
# ..                  ...                      ...                ...
# 1                 0.67%                   91.38%            859.56k
# 1                28.20%                   61.80%              1.08M
# 1                 0.75%                   93.43%            709.38k
# 1                 0.20%                   88.00%              3.74M
# 1                 2.90%                   80.97%            725.57k
#
#    Avg Vol (3 month) 3    Float Shares Outstanding 5  \
# 1               29.95M    4.37B                4.38B
# ...

# %%
empty_df_3 = pd.DataFrame()
for thing in new_list_of_datas_3:
    a = thing
    empty_df_3 = empty_df_3.append(a)
    
empty_df_3
# Out:
# 0  Forward Annual Dividend Rate 4 Forward Annual Dividend Yield 4  \
# 1                            3.08                           0.95%
# 1                            2.04                           1.09%
# 1                             NaN                             NaN
# 1                             NaN                             NaN
# 1                             NaN                             NaN
# ..                            ...                             ...
# 1                            0.76                           0.76%
# 1                             NaN                             NaN
# 1                            1.76                           1.65%
# 1                            1.16                           4.39%
# 1                            3.16                           3.18%
#
# 0  Trailing Annual Dividend Rate 3 Trailing Annual Dividend Yield 3  \
# 1                             3.04                            0.94%
# ...

# %%
empty_df_4 = pd.DataFrame()
for thing in new_list_of_datas_4:
    a = thing
    empty_df_4 = empty_df_4.append(a)
    
empty_df_4
# Out:
# 0  Fiscal Year Ends Most Recent Quarter (mrq)
# 1      Sep 27, 2019              Dec 27, 2019
# 1      Jun 29, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# ..              ...                       ...
# 1      Sep 26, 2019              Dec 26, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2019              Dec 30, 2019
# 1      Dec 30, 2018              Sep 29, 2019
# 1      Dec 30, 2018              Sep 29, 2019
#
# [403 rows x 2 columns]

# %%
empty_df_5 = pd.DataFrame()
for thing in new_list_of_datas_5:
    a = thing
    empty_df_5 = empty_df_5.append(a)
    
empty_df_5
# Out:
# 0  Profit Margin Operating Margin (ttm)
# 1         21.49%                 24.71%
# 1         33.02%                 36.74%
# 1          4.13%                  5.14%
# 1         26.15%                 33.93%
# 1         21.22%                 22.54%
# ..           ...                    ...
# 1          7.54%                  6.19%
# 1         35.67%                 33.43%
# 1         10.36%                 23.22%
# 1          6.23%                 10.36%
# 1          4.14%                  5.88%
#
# [403 rows x 2 columns]

# %%
empty_df_6 = pd.DataFrame()
for thing in new_list_of_datas_6:
    a = thing
    empty_df_6 = empty_df_6.append(a)
    
empty_df_6
# Out:
# 0  Return on Assets (ttm) Return on Equity (ttm)
# 1                  11.58%                 55.47%
# 1                  11.38%                 43.83%
# 1                   4.64%                 21.94%
# 1                  13.00%                 19.96%
# 1                   8.96%                 18.12%
# ..                    ...                    ...
# 1                   4.00%                  7.23%
# 1                  13.86%                 34.13%
# 1                   6.74%                 18.83%
# 1                   2.76%                 10.89%
# 1                   5.22%                 21.80%
#
# [403 rows x 2 columns]

# %%
empty_df_7 = pd.DataFrame()
for thing in new_list_of_datas_7:
    a = thing
    empty_df_7 = empty_df_7.append(a)
    
empty_df_7
# Out:
# 0  Revenue (ttm) Revenue Per Share (ttm) Quarterly Revenue Growth (yoy)  \
# 1        267.68B                   58.99                          8.90%
# 1        134.25B                   17.56                         13.70%
# 1        280.52B                  567.86                         20.80%
# 1          70.7B                   24.77                         24.60%
# 1        161.86B                  233.70                         17.30%
# ..           ...                     ...                            ...
# 1         13.01B                   95.94                          9.00%
# 1          2.41B                   31.59                         -7.20%
# 1          4.61B                   35.24                         -1.80%
# 1         12.11B                   24.13                         24.00%
# 1         19.29B                  132.12                          6.20%
#
# 0  Gross Profit (ttm)   EBITDA Net Income Avi to Common (ttm)  \
# ...

# %%
empty_df_8 = pd.DataFrame()
for thing in new_list_of_datas_8:
    a = thing
    empty_df_8 = empty_df_8.append(a)
    
empty_df_8
# Out:
# 0  Total Cash (mrq) Total Cash Per Share (mrq) Total Debt (mrq)  \
# 1           107.16B                      24.49          116.75B
# 1           134.23B                      17.65           87.15B
# 1            55.02B                     110.53           77.54B
# 1            54.86B                      19.24           11.07B
# 1           119.68B                     174.13           15.97B
# ..              ...                        ...              ...
# 1             1.18B                       8.84             2.6B
# 1             2.72B                      35.62           99.07M
# 1            339.1M                       2.61            3.26B
# 1             1.05B                        2.1           14.95B
# 1           451.28M                       3.11            4.52B
#
# 0  Total Debt/Equity (mrq) Current Ratio (mrq) Book Value Per Share (mrq)
# 1                   130.40                1.60                      20.42
# ...

# %%
empty_df_9 = pd.DataFrame()
for thing in new_list_of_datas_9:
    a = thing
    empty_df_9 = empty_df_9.append(a)
    
empty_df_9
# Out:
# 0  Operating Cash Flow (ttm) Levered Free Cash Flow (ttm)
# 1                     73.22B                       45.59B
# 1                     54.13B                       35.08B
# 1                     38.51B                       18.79B
# 1                     36.31B                       15.85B
# 1                     54.52B                       25.58B
# ..                       ...                          ...
# 1                   -278.92M                      723.53M
# 1                    963.03M                       610.2M
# 1                     488.5M                      866.24M
# 1                      1.54B                     -586.63M
# 1                    964.85M                       428.7M
#
# [403 rows x 2 columns]

# %%
master_df = pd.DataFrame()

# %%
master_df = pd.concat([master_df, empty_df], axis = 1)

# %%
master_df
# Out:
# 0  Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                     1.4T              1.43T        25.44         20.45
# 1                    1.41T              1.38T        32.06         29.21
# 1                    1.07T              1.09T        93.40         53.46
# 1                   613.9B            576.16B        33.49         19.74
# 1                    1.04T            945.56B        30.84         24.19
# ..                     ...                ...          ...           ...
# 1                   13.54B             14.98B          NaN         15.83
# 1                   17.46B             14.58B        21.49         22.63
# 1                   14.07B             16.73B        29.98         14.38
# 1                   12.98B             28.91B        20.50         16.36
# 1                   14.47B             18.53B        18.28         16.88
#
# 0  PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
master_df = pd.concat([master_df, empty_df_1], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_2], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_3], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_4], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_5], axis = 1)

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                     1.4T              1.43T        25.44         20.45
# 1                    1.41T              1.38T        32.06         29.21
# 1                    1.07T              1.09T        93.40         53.46
# 1                   613.9B            576.16B        33.49         19.74
# 1                    1.04T            945.56B        30.84         24.19
# ..                     ...                ...          ...           ...
# 1                   13.54B             14.98B          NaN         15.83
# 1                   17.46B             14.58B        21.49         22.63
# 1                   14.07B             16.73B        29.98         14.38
# 1                   12.98B             28.91B        20.50         16.36
# 1                   14.47B             18.53B        18.28         16.88
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
master_df = pd.concat([master_df, empty_df_6], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_7], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_8], axis = 1)

# %%
master_df = pd.concat([master_df, empty_df_9], axis = 1)

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                     1.4T              1.43T        25.44         20.45
# 1                    1.41T              1.38T        32.06         29.21
# 1                    1.07T              1.09T        93.40         53.46
# 1                   613.9B            576.16B        33.49         19.74
# 1                    1.04T            945.56B        30.84         24.19
# ..                     ...                ...          ...           ...
# 1                   13.54B             14.98B          NaN         15.83
# 1                   17.46B             14.58B        21.49         22.63
# 1                   14.07B             16.73B        29.98         14.38
# 1                   12.98B             28.91B        20.50         16.36
# 1                   14.47B             18.53B        18.28         16.88
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
new_ticker_list
# Out:
# ['AAPL',
#  'MSFT',
#  'AMZN',
#  'FB',
#  'GOOG',
#  'GOOGL',
#  'BRKB',
#  'JPM',
#  'JNJ',
#  'V',
#  'PG',
#  'MA',
#  'INTC',
#  'BAC',
#  'UNH',
#  'T',
#  'HD',
#  'XOM',
#  'DIS',
#  'VZ',
#  'KO',
#  'MRK',
#  'CVX',
#  'CMCSA',
#  'PEP',
#  'PFE',
#  'CSCO',
#  'ADBE',
#  'WFC',
#  'BA',
#  'C',
#  'NVDA',
#  'WMT',
#  'MCD',
#  'NFLX',
#  'CRM',
#  'MDT',
#  'BMY',
#  'ABT',
#  'PYPL',
#  'COST',
#  'ABBV',
#  'PM',
#  'NEE',
#  'ACN',
#  'TMO',
#  'AMGN',
#  'IBM',
#  'HON',
#  'UNP',
#  'NKE',
#  'UTX',
#  'TXN',
#  'AVGO',
#  'LLY',
#  'LIN',
#  'ORCL',
#  'TSLA',
#  'AMT',
#  'GE',
#  'LMT',
#  'SBUX',
#  'DHR',
#  'QCOM',
#  'LOW',
#  'FIS',
#  'CVS',
#  'AXP',
#  'MMM',
#  'GILD',
#  'MDLZ',
#  'MO',
#  'BKNG',
#  'CHTR',
#  'CI',
#  'ADP',
#  'USB',
#  'TJX',
#  'SYK',
#  'INTU',
#  'SPGI',
#  'ANTM',
#  'CME',
#  'GS',
#  'CB',
#  'CAT',
#  'UPS',
#  'DUK',
#  'TFC',
#  'SO',
#  'D',
#  'PLD',
#  'BDX',
#  'ISRG',
#  'ZTS',
#  'FISV',
#  'CCI',
#  'PNC',
#  'BLK',
# ...

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403 entries, 1 to 1
# Data columns (total 74 columns):
# Market Cap (intraday) 5                           402 non-null object
# Enterprise Value 3                                402 non-null object
# Trailing P/E                                      360 non-null object
# Forward P/E 1                                     402 non-null object
# PEG Ratio (5 yr expected) 1                       400 non-null object
# Price/Sales (ttm)                                 401 non-null object
# Price/Book (mrq)                                  378 non-null object
# Enterprise Value/Revenue 3                        401 non-null object
# Enterprise Value/EBITDA 6                         375 non-null object
# Beta (5Y Monthly)                                 390 non-null object
# 52-Week Change 3                                  402 non-null object
# S&P500 52-Week Change 3                           403 non-null object
# ...

# %%
master_df['Tickers'] = new_ticker_list

# %%
master_df
# Out:
#    Market Cap (intraday) 5 Enterprise Value 3 Trailing P/E Forward P/E 1  \
# 1                     1.4T              1.43T        25.44         20.45
# 1                    1.41T              1.38T        32.06         29.21
# 1                    1.07T              1.09T        93.40         53.46
# 1                   613.9B            576.16B        33.49         19.74
# 1                    1.04T            945.56B        30.84         24.19
# ..                     ...                ...          ...           ...
# 1                   13.54B             14.98B          NaN         15.83
# 1                   17.46B             14.58B        21.49         22.63
# 1                   14.07B             16.73B        29.98         14.38
# 1                   12.98B             28.91B        20.50         16.36
# 1                   14.47B             18.53B        18.28         16.88
#
#    PEG Ratio (5 yr expected) 1 Price/Sales (ttm) Price/Book (mrq)  \
# ...

# %%
# master_df.to_csv('financials_df.csv')
